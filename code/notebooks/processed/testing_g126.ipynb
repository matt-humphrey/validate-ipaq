# %%
# %load_ext rich
# %load_ext autoreload
# %autoreload 2

# %%
import polars as pl
import pointblank as pb
import odyssey.core as od

from utils import validate_ipaq
from harmonise import harmonise_ipaq
from config import INTERIM_DATA
# Out:
# c:\Users\00113294\Documents\WIP\Validating IPAQ\.venv\Lib\site-packages\requests\__init__.py:86: RequestsDependencyWarning: Unable to find acceptable character detection dependency (chardet or charset_normalizer).
#   warnings.warn(

# %%
prefix = "G126"
data = od.Dataset("G126_Q.sav", INTERIM_DATA)
lf, _meta = data.load_data()
df = lf.select("ID", pl.col("^.*IPAQ.*$")).collect()

# %%
harmonised_df = harmonise_ipaq(prefix, df)
harmonised_validation = validate_ipaq(prefix, harmonised_df)
harmonised_validation
# Out:
# Validate(
#     data=shape: (1_098, 28)
# ┌──────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ ID       ┆ G126_IPAQ ┆ G126_IPAQ ┆ G126_IPAQ ┆ … ┆ G126_IPAQ ┆ G126_IPAQ ┆ G126_IPAQ ┆ IPAQ_ACTI │
# │ ---      ┆ _VIG_W    ┆ _VIG_HPD  ┆ _VIG_MPD  ┆   ┆ _SIT_WE_H ┆ _SIT_WE_M ┆ _SIT_WE_T ┆ VITY      │
# │ f64      ┆ ---       ┆ ---       ┆ ---       ┆   ┆ PD        ┆ PD        ┆ RUNC      ┆ ---       │
# │          ┆ f64       ┆ f64       ┆ f64       ┆   ┆ ---       ┆ ---       ┆ ---       ┆ i32       │
# │          ┆           ┆           ┆           ┆   ┆ f64       ┆ f64       ┆ f64       ┆           │
# ╞══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ 301.0    ┆ 0.0       ┆ null      ┆ null      ┆ … ┆ 5.0       ┆ 0.0       ┆ 300.0     ┆ 1         │
# │ 302.0    ┆ 1.0       ┆ 4.0       ┆ 30.0      ┆ … ┆ 5.0       ┆ 45.0      ┆ 345.0     ┆ 1         │
# ...

# %%
harmonised_validation.get_step_report(i=10, columns_subset=pb.matches(r"ID|VIG"))
# Out:
# GT(
#     _tbl_data=shape: (6, 8)
# ┌───────────┬──────────┬────────────┬────────────┬────────────┬────────────┬───────────┬───────────┐
# │ _row_num_ ┆ ID       ┆ G126_IPAQ_ ┆ G126_IPAQ_ ┆ G126_IPAQ_ ┆ G126_IPAQ_ ┆ G126_IPAQ ┆ G126_IPAQ │
# │ ---       ┆ ---      ┆ VIG_W      ┆ VIG_HPD    ┆ VIG_MPD    ┆ VIG_MINS   ┆ _VIG_D    ┆ _VIG_MET  │
# │ u32       ┆ f64      ┆ ---        ┆ ---        ┆ ---        ┆ ---        ┆ ---       ┆ ---       │
# │           ┆          ┆ f64        ┆ f64        ┆ f64        ┆ f64        ┆ f64       ┆ f64       │
# ╞═══════════╪══════════╪════════════╪════════════╪════════════╪════════════╪═══════════╪═══════════╡
# │ 189       ┆ 86502.0  ┆ 1.0        ┆ 3.0        ┆ 60.0       ┆ 180.0      ┆ 5.0       ┆ 7200.0    │
# │ 288       ┆ 133901.0 ┆ 1.0        ┆ 3.0        ┆ 90.0       ┆ 180.0      ┆ 3.0       ┆ 4320.0    │
# │ 383       ┆ 192701.0 ┆ 1.0        ┆ 1.0        ┆ 75.0       ┆ 135.0      ┆ 1.0       ┆ 1080.0    │
# ...

# %%
harmonised_validation.get_step_report(i=24, columns_subset=pb.matches(r"ID|MOD"))
# Out:
# GT(
#     _tbl_data=shape: (3, 8)
# ┌───────────┬──────────┬────────────┬────────────┬────────────┬────────────┬───────────┬───────────┐
# │ _row_num_ ┆ ID       ┆ G126_IPAQ_ ┆ G126_IPAQ_ ┆ G126_IPAQ_ ┆ G126_IPAQ_ ┆ G126_IPAQ ┆ G126_IPAQ │
# │ ---       ┆ ---      ┆ MOD_W      ┆ MOD_HPD    ┆ MOD_MPD    ┆ MOD_MINS   ┆ _MOD_D    ┆ _MOD_MET  │
# │ u32       ┆ f64      ┆ ---        ┆ ---        ┆ ---        ┆ ---        ┆ ---       ┆ ---       │
# │           ┆          ┆ f64        ┆ f64        ┆ f64        ┆ f64        ┆ f64       ┆ f64       │
# ╞═══════════╪══════════╪════════════╪════════════╪════════════╪════════════╪═══════════╪═══════════╡
# │ 183       ┆ 66402.0  ┆ 1.0        ┆ 2.0        ┆ 60.0       ┆ 180.0      ┆ 1.0       ┆ 720.0     │
# │ 493       ┆ 212201.0 ┆ 1.0        ┆ 8.0        ┆ 240.0      ┆ 180.0      ┆ null      ┆ null      │
# │ 494       ┆ 212202.0 ┆ 1.0        ┆ 6.0        ┆ 60.0       ┆ 180.0      ┆ 7.0       ┆ 5040.0    │
# ...

# %%
harmonised_validation.get_step_report(i=32, columns_subset=pb.matches(r"ID|MOD"))
# Out:
# GT(
#     _tbl_data=shape: (1, 8)
# ┌───────────┬─────────┬────────────┬────────────┬────────────┬────────────┬────────────┬───────────┐
# │ _row_num_ ┆ ID      ┆ G126_IPAQ_ ┆ G126_IPAQ_ ┆ G126_IPAQ_ ┆ G126_IPAQ_ ┆ G126_IPAQ_ ┆ G126_IPAQ │
# │ ---       ┆ ---     ┆ MOD_W      ┆ MOD_HPD    ┆ MOD_MPD    ┆ MOD_MINS   ┆ MOD_D      ┆ _MOD_MET  │
# │ u32       ┆ f64     ┆ ---        ┆ ---        ┆ ---        ┆ ---        ┆ ---        ┆ ---       │
# │           ┆         ┆ f64        ┆ f64        ┆ f64        ┆ f64        ┆ f64        ┆ f64       │
# ╞═══════════╪═════════╪════════════╪════════════╪════════════╪════════════╪════════════╪═══════════╡
# │ 5         ┆ 14402.0 ┆ -1.0       ┆ 999.0      ┆ 999.0      ┆ null       ┆ null       ┆ null      │
# └───────────┴─────────┴────────────┴────────────┴────────────┴────────────┴────────────┴───────────┘,
#     _body=<great_tables._gt_data.Body object at 0x00000168A3F04190>,
# ...

# %%
harmonised_validation.get_step_report(i=33, columns_subset=pb.matches(r"ID|MOD"))
# Out:
# GT(
#     _tbl_data=shape: (1, 8)
# ┌───────────┬─────────┬────────────┬────────────┬────────────┬────────────┬────────────┬───────────┐
# │ _row_num_ ┆ ID      ┆ G126_IPAQ_ ┆ G126_IPAQ_ ┆ G126_IPAQ_ ┆ G126_IPAQ_ ┆ G126_IPAQ_ ┆ G126_IPAQ │
# │ ---       ┆ ---     ┆ MOD_W      ┆ MOD_HPD    ┆ MOD_MPD    ┆ MOD_MINS   ┆ MOD_D      ┆ _MOD_MET  │
# │ u32       ┆ f64     ┆ ---        ┆ ---        ┆ ---        ┆ ---        ┆ ---        ┆ ---       │
# │           ┆         ┆ f64        ┆ f64        ┆ f64        ┆ f64        ┆ f64        ┆ f64       │
# ╞═══════════╪═════════╪════════════╪════════════╪════════════╪════════════╪════════════╪═══════════╡
# │ 5         ┆ 14402.0 ┆ -1.0       ┆ 999.0      ┆ 999.0      ┆ null       ┆ null       ┆ null      │
# └───────────┴─────────┴────────────┴────────────┴────────────┴────────────┴────────────┴───────────┘,
#     _body=<great_tables._gt_data.Body object at 0x00000168A4AB3D90>,
# ...

# %%
harmonised_validation.get_step_report(i=37, columns_subset=pb.matches(r"ID|WALK"))
# Out:
# GT(
#     _tbl_data=shape: (3, 8)
# ┌───────────┬──────────┬────────────┬────────────┬────────────┬────────────┬───────────┬───────────┐
# │ _row_num_ ┆ ID       ┆ G126_IPAQ_ ┆ G126_IPAQ_ ┆ G126_IPAQ_ ┆ G126_IPAQ_ ┆ G126_IPAQ ┆ G126_IPAQ │
# │ ---       ┆ ---      ┆ WALK_W     ┆ WALK_HPD   ┆ WALK_MPD   ┆ WALK_MINS  ┆ _WALK_D   ┆ _WALK_MET │
# │ u32       ┆ f64      ┆ ---        ┆ ---        ┆ ---        ┆ ---        ┆ ---       ┆ ---       │
# │           ┆          ┆ f64        ┆ f64        ┆ f64        ┆ f64        ┆ f64       ┆ f64       │
# ╞═══════════╪══════════╪════════════╪════════════╪════════════╪════════════╪═══════════╪═══════════╡
# │ 504       ┆ 135801.0 ┆ 1.0        ┆ 30.0       ┆ 5.0        ┆ 180.0      ┆ 7.0       ┆ 4158.0    │
# │ 836       ┆ 243102.0 ┆ 1.0        ┆ 999.0      ┆ 999.0      ┆ 180.0      ┆ 7.0       ┆ 4158.0    │
# │ 849       ┆ 246201.0 ┆ 1.0        ┆ 999.0      ┆ 15.0       ┆ 180.0      ┆ 3.0       ┆ 1782.0    │
# ...

# %%
harmonised_validation.get_step_report(i=38, columns_subset=pb.matches(r"ID|WALK"))
# Out:
# GT(
#     _tbl_data=shape: (4, 8)
# ┌───────────┬──────────┬────────────┬────────────┬────────────┬────────────┬───────────┬───────────┐
# │ _row_num_ ┆ ID       ┆ G126_IPAQ_ ┆ G126_IPAQ_ ┆ G126_IPAQ_ ┆ G126_IPAQ_ ┆ G126_IPAQ ┆ G126_IPAQ │
# │ ---       ┆ ---      ┆ WALK_W     ┆ WALK_HPD   ┆ WALK_MPD   ┆ WALK_MINS  ┆ _WALK_D   ┆ _WALK_MET │
# │ u32       ┆ f64      ┆ ---        ┆ ---        ┆ ---        ┆ ---        ┆ ---       ┆ ---       │
# │           ┆          ┆ f64        ┆ f64        ┆ f64        ┆ f64        ┆ f64       ┆ f64       │
# ╞═══════════╪══════════╪════════════╪════════════╪════════════╪════════════╪═══════════╪═══════════╡
# │ 227       ┆ 60302.0  ┆ 1.0        ┆ 3.0        ┆ 60.0       ┆ 180.0      ┆ 7.0       ┆ 4158.0    │
# │ 594       ┆ 165001.0 ┆ 1.0        ┆ 8.0        ┆ 60.0       ┆ 180.0      ┆ 7.0       ┆ 4158.0    │
# │ 746       ┆ 212201.0 ┆ 1.0        ┆ 2.0        ┆ 240.0      ┆ 180.0      ┆ 7.0       ┆ 4158.0    │
# ...

# %%
harmonised_validation.get_step_report(i=46, columns_subset=pb.matches(r"ID|WALK"))
# Out:
# GT(
#     _tbl_data=shape: (2, 8)
# ┌───────────┬──────────┬────────────┬────────────┬────────────┬────────────┬───────────┬───────────┐
# │ _row_num_ ┆ ID       ┆ G126_IPAQ_ ┆ G126_IPAQ_ ┆ G126_IPAQ_ ┆ G126_IPAQ_ ┆ G126_IPAQ ┆ G126_IPAQ │
# │ ---       ┆ ---      ┆ WALK_W     ┆ WALK_HPD   ┆ WALK_MPD   ┆ WALK_MINS  ┆ _WALK_D   ┆ _WALK_MET │
# │ u32       ┆ f64      ┆ ---        ┆ ---        ┆ ---        ┆ ---        ┆ ---       ┆ ---       │
# │           ┆          ┆ f64        ┆ f64        ┆ f64        ┆ f64        ┆ f64       ┆ f64       │
# ╞═══════════╪══════════╪════════════╪════════════╪════════════╪════════════╪═══════════╪═══════════╡
# │ 5         ┆ 14402.0  ┆ -1.0       ┆ 999.0      ┆ 999.0      ┆ null       ┆ null      ┆ null      │
# │ 28        ┆ 151402.0 ┆ -1.0       ┆ 999.0      ┆ 999.0      ┆ null       ┆ null      ┆ null      │
# └───────────┴──────────┴────────────┴────────────┴────────────┴────────────┴───────────┴───────────┘,
# ...

# %%
harmonised_validation.get_step_report(i=47, columns_subset=pb.matches(r"ID|WALK"))
# Out:
# GT(
#     _tbl_data=shape: (2, 8)
# ┌───────────┬──────────┬────────────┬────────────┬────────────┬────────────┬───────────┬───────────┐
# │ _row_num_ ┆ ID       ┆ G126_IPAQ_ ┆ G126_IPAQ_ ┆ G126_IPAQ_ ┆ G126_IPAQ_ ┆ G126_IPAQ ┆ G126_IPAQ │
# │ ---       ┆ ---      ┆ WALK_W     ┆ WALK_HPD   ┆ WALK_MPD   ┆ WALK_MINS  ┆ _WALK_D   ┆ _WALK_MET │
# │ u32       ┆ f64      ┆ ---        ┆ ---        ┆ ---        ┆ ---        ┆ ---       ┆ ---       │
# │           ┆          ┆ f64        ┆ f64        ┆ f64        ┆ f64        ┆ f64       ┆ f64       │
# ╞═══════════╪══════════╪════════════╪════════════╪════════════╪════════════╪═══════════╪═══════════╡
# │ 5         ┆ 14402.0  ┆ -1.0       ┆ 999.0      ┆ 999.0      ┆ null       ┆ null      ┆ null      │
# │ 28        ┆ 151402.0 ┆ -1.0       ┆ 999.0      ┆ 999.0      ┆ null       ┆ null      ┆ null      │
# └───────────┴──────────┴────────────┴────────────┴────────────┴────────────┴───────────┴───────────┘,
# ...
