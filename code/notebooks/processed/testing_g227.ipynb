# %%
# %load_ext rich
# %load_ext autoreload
# %autoreload 2

# %%
import polars as pl
import pointblank as pb
import odyssey.core as od

from utils import validate_ipaq
from harmonise import harmonise_ipaq
from config import INTERIM_DATA
# Out:
# c:\Users\00113294\Documents\WIP\Validating IPAQ\.venv\Lib\site-packages\requests\__init__.py:86: RequestsDependencyWarning: Unable to find acceptable character detection dependency (chardet or charset_normalizer).
#   warnings.warn(

# %%
prefix = "G227"
data = od.Dataset("G227_Q.sav", INTERIM_DATA)
lf, _meta = data.load_data()
df = lf.select("ID", pl.col("^.*IPAQ.*$")).collect()

# %%
harmonised_df = harmonise_ipaq(prefix, df)
harmonised_validation = validate_ipaq(prefix, harmonised_df)
harmonised_validation
# Out:
# Validate(
#     data=shape: (1_149, 24)
# ┌─────────┬────────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ ID      ┆ G227_IPAQ_ ┆ G227_IPAQ ┆ G227_IPAQ ┆ … ┆ G227_IPAQ ┆ G227_IPAQ ┆ G227_IPAQ ┆ IPAQ_ACTI │
# │ ---     ┆ VIG_W      ┆ _VIG_HPD  ┆ _VIG_MPD  ┆   ┆ _WALK_MET ┆ _TOT_MET  ┆ _CAT      ┆ VITY      │
# │ f64     ┆ ---        ┆ ---       ┆ ---       ┆   ┆ ---       ┆ ---       ┆ ---       ┆ ---       │
# │         ┆ f64        ┆ f64       ┆ f64       ┆   ┆ f64       ┆ f64       ┆ i32       ┆ i32       │
# ╞═════════╪════════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ 10020.0 ┆ 1.0        ┆ 0.0       ┆ 20.0      ┆ … ┆ 792.0     ┆ 952.0     ┆ 1         ┆ 1         │
# │ 10100.0 ┆ 1.0        ┆ 2.0       ┆ 30.0      ┆ … ┆ 693.0     ┆ 5133.0    ┆ 2         ┆ 1         │
# │ 10150.0 ┆ 1.0        ┆ 1.0       ┆ 0.0       ┆ … ┆ 165.0     ┆ 885.0     ┆ 1         ┆ 1         │
# │ 10170.0 ┆ 1.0        ┆ 1.0       ┆ 30.0      ┆ … ┆ 495.0     ┆ 2475.0    ┆ 1         ┆ 1         │
# │ 10200.0 ┆ 1.0        ┆ 0.0       ┆ 10.0      ┆ … ┆ 792.0     ┆ 1512.0    ┆ 1         ┆ 1         │
# │ …       ┆ …          ┆ …         ┆ …         ┆ … ┆ …         ┆ …         ┆ …         ┆ …         │
# │ 54520.0 ┆ 1.0        ┆ null      ┆ 30.0      ┆ … ┆ 198.0     ┆ 678.0     ┆ 1         ┆ 1         │
# │ 54540.0 ┆ 1.0        ┆ 4.0       ┆ 30.0      ┆ … ┆ 3564.0    ┆ 10044.0   ┆ 2         ┆ 1         │
# │ 54550.0 ┆ 1.0        ┆ 1.0       ┆ 30.0      ┆ … ┆ 1386.0    ┆ 4266.0    ┆ 2         ┆ 1         │
# │ 54580.0 ┆ 1.0        ┆ 1.0       ┆ 30.0      ┆ … ┆ 990.0     ┆ 3870.0    ┆ 2         ┆ 1         │
# │ 54601.0 ┆ 1.0        ┆ 2.0       ┆ null      ┆ … ┆ 1188.0    ┆ 4308.0    ┆ 2         ┆ 1         │
# └─────────┴────────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴───────────┘,
#     tbl_name=None,
#     label=None,
#     thresholds=Thresholds(warning=None, error=None, critical=None),
#     actions=None,
#     final_actions=None,
#     brief=None,
#     lang='en',
#     locale='en'
# )

# %%
harmonised_validation.get_step_report(i=9, columns_subset=pb.matches(r"ID|VIG"))
# Out:
# GT(
#     _tbl_data=shape: (4, 8)
# ┌───────────┬─────────┬────────────┬────────────┬────────────┬────────────┬────────────┬───────────┐
# │ _row_num_ ┆ ID      ┆ G227_IPAQ_ ┆ G227_IPAQ_ ┆ G227_IPAQ_ ┆ G227_IPAQ_ ┆ G227_IPAQ_ ┆ G227_IPAQ │
# │ ---       ┆ ---     ┆ VIG_W      ┆ VIG_HPD    ┆ VIG_MPD    ┆ VIG_D      ┆ VIG_MINS   ┆ _VIG_MET  │
# │ u32       ┆ f64     ┆ ---        ┆ ---        ┆ ---        ┆ ---        ┆ ---        ┆ ---       │
# │           ┆         ┆ f64        ┆ f64        ┆ f64        ┆ f64        ┆ f64        ┆ f64       │
# ╞═══════════╪═════════╪════════════╪════════════╪════════════╪════════════╪════════════╪═══════════╡
# │ 77        ┆ 13270.0 ┆ 1.0        ┆ 70.0       ┆ null       ┆ 4.0        ┆ 180.0      ┆ 5760.0    │
# │ 185       ┆ 17580.0 ┆ 1.0        ┆ 60.0       ┆ null       ┆ 4.0        ┆ 180.0      ┆ 5760.0    │
# │ 491       ┆ 45150.0 ┆ 1.0        ┆ 45.0       ┆ null       ┆ 3.0        ┆ 180.0      ┆ 4320.0    │
# │ 547       ┆ 47740.0 ┆ 1.0        ┆ 32.0       ┆ 32.0       ┆ 1.0        ┆ 180.0      ┆ 1440.0    │
# └───────────┴─────────┴────────────┴────────────┴────────────┴────────────┴────────────┴───────────┘,
#     _body=<great_tables._gt_data.Body object at 0x0000017581598190>,
#     _boxhead=Boxhead([ColInfo(var='_row_num_', type=<ColInfoTypeEnum.default: 1>, column_label='', column_align='right', column_width='33.4px'), ColInfo(var='ID', type=<ColInfoTypeEnum.default: 1>, column_label=Html(text="<div><div style='white-space: nowrap; text-overflow: ellipsis; overflow: hidden; padding-bottom: 2px; margin-bottom: 2px;'>ID</div><div style='white-space: nowrap; text-overflow: ellipsis; overflow: hidden; padding-top: 2px; margin-top: 2px;'><em>Float64</em></div></div>"), column_align='right', column_width='65px'), ColInfo(var='G227_IPAQ_VIG_W', type=<ColInfoTypeEnum.default: 1>, column_label=Html(text="<div><div style='white-space: nowrap; text-overflow: ellipsis; overflow: hidden; padding-bottom: 2px; margin-bottom: 2px;'>G227_IPAQ_VIG_W</div><div style='white-space: nowrap; text-overflow: ellipsis; overflow: hidden; padding-top: 2px; margin-top: 2px;'><em>Float64</em></div></div>"), column_align='right', column_width='127px'), ColInfo(var='G227_IPAQ_VIG_HPD', type=<ColInfoTypeEnum.default: 1>, column_label=Html(text="<div><div style='white-space: nowrap; text-overflow: ellipsis; overflow: hidden; padding-bottom: 2px; margin-bottom: 2px;'>G227_IPAQ_VIG_HPD</div><div style='white-space: nowrap; text-overflow: ellipsis; overflow: hidden; padding-top: 2px; margin-top: 2px;'><em>Float64</em></div></div>"), column_align='right', column_width='143px'), ColInfo(var='G227_IPAQ_VIG_MPD', type=<ColInfoTypeEnum.default: 1>, column_label=Html(text="<div><div style='white-space: nowrap; text-overflow: ellipsis; overflow: hidden; padding-bottom: 2px; margin-bottom: 2px;'>G227_IPAQ_VIG_MPD</div><div style='white-space: nowrap; text-overflow: ellipsis; overflow: hidden; padding-top: 2px; margin-top: 2px;'><em>Float64</em></div></div>"), column_align='right', column_width='143px'), ColInfo(var='G227_IPAQ_VIG_D', type=<ColInfoTypeEnum.default: 1>, column_label=Html(text="<div><div style='white-space: nowrap; text-overflow: ellipsis; overflow: hidden; padding-bottom: 2px; margin-bottom: 2px;'>G227_IPAQ_VIG_D</div><div style='white-space: nowrap; text-overflow: ellipsis; overflow: hidden; padding-top: 2px; margin-top: 2px;'><em>Float64</em></div></div>"), column_align='right', column_width='127px'), ColInfo(var='G227_IPAQ_VIG_MINS', type=<ColInfoTypeEnum.default: 1>, column_label=Html(text="<div><div style='white-space: nowrap; text-overflow: ellipsis; overflow: hidden; padding-bottom: 2px; margin-bottom: 2px;'>G227_IPAQ_VIG_MINS</div><div style='white-space: nowrap; text-overflow: ellipsis; overflow: hidden; padding-top: 2px; margin-top: 2px;'><em>Float64</em></div></div>"), column_align='right', column_width='150px'), ColInfo(var='G227_IPAQ_VIG_MET', type=<ColInfoTypeEnum.default: 1>, column_label=Html(text="<div><div style='white-space: nowrap; text-overflow: ellipsis; overflow: hidden; padding-bottom: 2px; margin-bottom: 2px;'>G227_IPAQ_VIG_MET</div><div style='white-space: nowrap; text-overflow: ellipsis; overflow: hidden; padding-top: 2px; margin-top: 2px;'><em>Float64</em></div></div>"), column_align='right', column_width='143px')]),
#     _stub=<great_tables._gt_data.Stub object at 0x00000175FD509C70>,
#     _spanners=Spanners([]),
#     _heading=Heading(
#         title=Md(
#             text="<p>Report for Validation Step 9<div style='font-size: 13.6px; '><div style='padding-top: 7px;'>ASSERTION <span style='border-style: solid; border-width: thin; border-color: lightblue; padding-left: 2px; padding-right: 2px;'><code style='color: #303030; background-color: transparent; position: relative; bottom: 1px;'><code style='color: #303030; font-family: monospace; font-size: smaller;'>0 &le; G227_IPAQ_VIG_HPD &le; 18</code></code></span></div><div style='padding-top: 7px;'><strong>4</strong> / <strong>721</strong> TEST UNIT FAILURES IN COLUMN <strong>3</strong> </div><div>EXTRACT OF ALL <strong>4</strong> ROWS (WITH <span style='color: #B22222;'>TEST UNIT FAILURES IN RED</span>):</div></div></p>\n"
#         ),
#         subtitle=None,
#         preheader=None
#     ),
#     _stubhead=None,
#     _source_notes=[],
#     _footnotes=[],
#     _styles=[
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='_row_num_',
#             rownum=0,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='_row_num_',
#             rownum=1,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='_row_num_',
#             rownum=2,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='_row_num_',
#             rownum=3,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='ID',
#             rownum=0,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='ID',
#             rownum=1,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='ID',
#             rownum=2,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='ID',
#             rownum=3,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_VIG_W',
#             rownum=0,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_VIG_W',
#             rownum=1,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_VIG_W',
#             rownum=2,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_VIG_W',
#             rownum=3,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_VIG_HPD',
#             rownum=0,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_VIG_HPD',
#             rownum=1,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_VIG_HPD',
#             rownum=2,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_VIG_HPD',
#             rownum=3,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_VIG_MPD',
#             rownum=0,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_VIG_MPD',
#             rownum=1,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_VIG_MPD',
#             rownum=2,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_VIG_MPD',
#             rownum=3,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_VIG_D',
#             rownum=0,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_VIG_D',
#             rownum=1,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_VIG_D',
#             rownum=2,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_VIG_D',
#             rownum=3,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_VIG_MINS',
#             rownum=0,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_VIG_MINS',
#             rownum=1,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_VIG_MINS',
#             rownum=2,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_VIG_MINS',
#             rownum=3,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_VIG_MET',
#             rownum=0,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_VIG_MET',
#             rownum=1,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_VIG_MET',
#             rownum=2,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_VIG_MET',
#             rownum=3,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='_row_num_',
#             rownum=0,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='_row_num_',
#             rownum=1,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='_row_num_',
#             rownum=2,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='_row_num_',
#             rownum=3,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='ID',
#             rownum=0,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='ID',
#             rownum=1,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='ID',
#             rownum=2,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='ID',
#             rownum=3,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_VIG_W',
#             rownum=0,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_VIG_W',
#             rownum=1,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_VIG_W',
#             rownum=2,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_VIG_W',
#             rownum=3,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_VIG_HPD',
#             rownum=0,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_VIG_HPD',
#             rownum=1,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_VIG_HPD',
#             rownum=2,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_VIG_HPD',
#             rownum=3,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_VIG_MPD',
#             rownum=0,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_VIG_MPD',
#             rownum=1,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_VIG_MPD',
#             rownum=2,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_VIG_MPD',
#             rownum=3,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_VIG_D',
#             rownum=0,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_VIG_D',
#             rownum=1,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_VIG_D',
#             rownum=2,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_VIG_D',
#             rownum=3,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_VIG_MINS',
#             rownum=0,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_VIG_MINS',
#             rownum=1,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_VIG_MINS',
#             rownum=2,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_VIG_MINS',
#             rownum=3,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_VIG_MET',
#             rownum=0,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_VIG_MET',
#             rownum=1,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_VIG_MET',
#             rownum=2,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_VIG_MET',
#             rownum=3,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocColumnLabels(columns=None),
#             grpname=None,
#             colname='_row_num_',
#             rownum=None,
#             colnum=None,
#             styles=[CellStyleText(color='gray20', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocColumnLabels(columns=None),
#             grpname=None,
#             colname='ID',
#             rownum=None,
#             colnum=None,
#             styles=[CellStyleText(color='gray20', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocColumnLabels(columns=None),
#             grpname=None,
#             colname='G227_IPAQ_VIG_W',
#             rownum=None,
#             colnum=None,
#             styles=[CellStyleText(color='gray20', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocColumnLabels(columns=None),
#             grpname=None,
#             colname='G227_IPAQ_VIG_HPD',
#             rownum=None,
#             colnum=None,
#             styles=[CellStyleText(color='gray20', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocColumnLabels(columns=None),
#             grpname=None,
#             colname='G227_IPAQ_VIG_MPD',
#             rownum=None,
#             colnum=None,
#             styles=[CellStyleText(color='gray20', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocColumnLabels(columns=None),
#             grpname=None,
#             colname='G227_IPAQ_VIG_D',
#             rownum=None,
#             colnum=None,
#             styles=[CellStyleText(color='gray20', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocColumnLabels(columns=None),
#             grpname=None,
#             colname='G227_IPAQ_VIG_MINS',
#             rownum=None,
#             colnum=None,
#             styles=[CellStyleText(color='gray20', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocColumnLabels(columns=None),
#             grpname=None,
#             colname='G227_IPAQ_VIG_MET',
#             rownum=None,
#             colnum=None,
#             styles=[CellStyleText(color='gray20', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='_row_num_',
#             rownum=0,
#             colnum=None,
#             styles=[CellStyleBorders(sides=['top', 'bottom'], color='#E9E9E', style='solid', weight='1px')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='_row_num_',
#             rownum=1,
#             colnum=None,
#             styles=[CellStyleBorders(sides=['top', 'bottom'], color='#E9E9E', style='solid', weight='1px')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='_row_num_',
#             rownum=2,
#             colnum=None,
#             styles=[CellStyleBorders(sides=['top', 'bottom'], color='#E9E9E', style='solid', weight='1px')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='_row_num_',
#             rownum=3,
#             colnum=None,
#             styles=[CellStyleBorders(sides=['top', 'bottom'], color='#E9E9E', style='solid', weight='1px')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='ID',
#             rownum=0,
#             colnum=None,
#             styles=[CellStyleBorders(sides=['top', 'bottom'], color='#E9E9E', style='solid', weight='1px')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='ID',
#             rownum=1,
#             colnum=None,
#             styles=[CellStyleBorders(sides=['top', 'bottom'], color='#E9E9E', style='solid', weight='1px')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='ID',
#             rownum=2,
#             colnum=None,
#             styles=[CellStyleBorders(sides=['top', 'bottom'], color='#E9E9E', style='solid', weight='1px')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='ID',
#             rownum=3,
#             colnum=None,
#             styles=[CellStyleBorders(sides=['top', 'bottom'], color='#E9E9E', style='solid', weight='1px')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_VIG_W',
#             rownum=0,
#             colnum=None,
#             styles=[CellStyleBorders(sides=['top', 'bottom'], color='#E9E9E', style='solid', weight='1px')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_VIG_W',
#             rownum=1,
#             colnum=None,
#             styles=[CellStyleBorders(sides=['top', 'bottom'], color='#E9E9E', style='solid', weight='1px')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_VIG_W',
#             rownum=2,
#             colnum=None,
#             styles=[CellStyleBorders(sides=['top', 'bottom'], color='#E9E9E', style='solid', weight='1px')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_VIG_W',
#             rownum=3,
#             colnum=None,
#             styles=[CellStyleBorders(sides=['top', 'bottom'], color='#E9E9E', style='solid', weight='1px')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_VIG_HPD',
#             rownum=0,
#             colnum=None,
#             styles=[CellStyleBorders(sides=['top', 'bottom'], color='#E9E9E', style='solid', weight='1px')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_VIG_HPD',
#             rownum=1,
#             colnum=None,
#             styles=[CellStyleBorders(sides=['top', 'bottom'], color='#E9E9E', style='solid', weight='1px')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_VIG_HPD',
#             rownum=2,
#             colnum=None,
#             styles=[CellStyleBorders(sides=['top', 'bottom'], color='#E9E9E', style='solid', weight='1px')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_VIG_HPD',
#             rownum=3,
#             colnum=None,
#             styles=[CellStyleBorders(sides=['top', 'bottom'], color='#E9E9E', style='solid', weight='1px')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_VIG_MPD',
#             rownum=0,
#             colnum=None,
#             styles=[CellStyleBorders(sides=['top', 'bottom'], color='#E9E9E', style='solid', weight='1px')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_VIG_MPD',
#             rownum=1,
#             colnum=None,
#             styles=[CellStyleBorders(sides=['top', 'bottom'], color='#E9E9E', style='solid', weight='1px')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_VIG_MPD',
#             rownum=2,
#             colnum=None,
#             styles=[CellStyleBorders(sides=['top', 'bottom'], color='#E9E9E', style='solid', weight='1px')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_VIG_MPD',
#             rownum=3,
#             colnum=None,
#             styles=[CellStyleBorders(sides=['top', 'bottom'], color='#E9E9E', style='solid', weight='1px')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_VIG_D',
#             rownum=0,
#             colnum=None,
#             styles=[CellStyleBorders(sides=['top', 'bottom'], color='#E9E9E', style='solid', weight='1px')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_VIG_D',
#             rownum=1,
#             colnum=None,
#             styles=[CellStyleBorders(sides=['top', 'bottom'], color='#E9E9E', style='solid', weight='1px')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_VIG_D',
#             rownum=2,
#             colnum=None,
#             styles=[CellStyleBorders(sides=['top', 'bottom'], color='#E9E9E', style='solid', weight='1px')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_VIG_D',
#             rownum=3,
#             colnum=None,
#             styles=[CellStyleBorders(sides=['top', 'bottom'], color='#E9E9E', style='solid', weight='1px')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_VIG_MINS',
#             rownum=0,
#             colnum=None,
#             styles=[CellStyleBorders(sides=['top', 'bottom'], color='#E9E9E', style='solid', weight='1px')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_VIG_MINS',
#             rownum=1,
#             colnum=None,
#             styles=[CellStyleBorders(sides=['top', 'bottom'], color='#E9E9E', style='solid', weight='1px')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_VIG_MINS',
#             rownum=2,
#             colnum=None,
#             styles=[CellStyleBorders(sides=['top', 'bottom'], color='#E9E9E', style='solid', weight='1px')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_VIG_MINS',
#             rownum=3,
#             colnum=None,
#             styles=[CellStyleBorders(sides=['top', 'bottom'], color='#E9E9E', style='solid', weight='1px')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_VIG_MET',
#             rownum=0,
#             colnum=None,
#             styles=[CellStyleBorders(sides=['top', 'bottom'], color='#E9E9E', style='solid', weight='1px')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_VIG_MET',
#             rownum=1,
#             colnum=None,
#             styles=[CellStyleBorders(sides=['top', 'bottom'], color='#E9E9E', style='solid', weight='1px')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_VIG_MET',
#             rownum=2,
#             colnum=None,
#             styles=[CellStyleBorders(sides=['top', 'bottom'], color='#E9E9E', style='solid', weight='1px')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_VIG_MET',
#             rownum=3,
#             colnum=None,
#             styles=[CellStyleBorders(sides=['top', 'bottom'], color='#E9E9E', style='solid', weight='1px')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns='_row_num_', rows=None, mask=None),
#             grpname=None,
#             colname='_row_num_',
#             rownum=0,
#             colnum=None,
#             styles=[
#                 CellStyleText(color='gray', font='IBM Plex Mono', size='10px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None),
#                 CellStyleBorders(sides='right', color='#6699CC80', style='solid', weight='2px')
#             ]
#         ),
#         StyleInfo(
#             locname=LocBody(columns='_row_num_', rows=None, mask=None),
#             grpname=None,
#             colname='_row_num_',
#             rownum=1,
#             colnum=None,
#             styles=[
#                 CellStyleText(color='gray', font='IBM Plex Mono', size='10px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None),
#                 CellStyleBorders(sides='right', color='#6699CC80', style='solid', weight='2px')
#             ]
#         ),
#         StyleInfo(
#             locname=LocBody(columns='_row_num_', rows=None, mask=None),
#             grpname=None,
#             colname='_row_num_',
#             rownum=2,
#             colnum=None,
#             styles=[
#                 CellStyleText(color='gray', font='IBM Plex Mono', size='10px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None),
#                 CellStyleBorders(sides='right', color='#6699CC80', style='solid', weight='2px')
#             ]
#         ),
#         StyleInfo(
#             locname=LocBody(columns='_row_num_', rows=None, mask=None),
#             grpname=None,
#             colname='_row_num_',
#             rownum=3,
#             colnum=None,
#             styles=[
#                 CellStyleText(color='gray', font='IBM Plex Mono', size='10px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None),
#                 CellStyleBorders(sides='right', color='#6699CC80', style='solid', weight='2px')
#             ]
#         ),
#         StyleInfo(
#             locname=LocBody(columns='G227_IPAQ_VIG_HPD', rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_VIG_HPD',
#             rownum=0,
#             colnum=None,
#             styles=[
#                 CellStyleText(color='#B22222', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None),
#                 CellStyleFill(color='#FFC1C159'),
#                 CellStyleBorders(sides=['left', 'right'], color='black', style='solid', weight='2px')
#             ]
#         ),
#         StyleInfo(
#             locname=LocBody(columns='G227_IPAQ_VIG_HPD', rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_VIG_HPD',
#             rownum=1,
#             colnum=None,
#             styles=[
#                 CellStyleText(color='#B22222', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None),
#                 CellStyleFill(color='#FFC1C159'),
#                 CellStyleBorders(sides=['left', 'right'], color='black', style='solid', weight='2px')
#             ]
#         ),
#         StyleInfo(
#             locname=LocBody(columns='G227_IPAQ_VIG_HPD', rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_VIG_HPD',
#             rownum=2,
#             colnum=None,
#             styles=[
#                 CellStyleText(color='#B22222', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None),
#                 CellStyleFill(color='#FFC1C159'),
#                 CellStyleBorders(sides=['left', 'right'], color='black', style='solid', weight='2px')
#             ]
#         ),
#         StyleInfo(
#             locname=LocBody(columns='G227_IPAQ_VIG_HPD', rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_VIG_HPD',
#             rownum=3,
#             colnum=None,
#             styles=[
#                 CellStyleText(color='#B22222', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None),
#                 CellStyleFill(color='#FFC1C159'),
#                 CellStyleBorders(sides=['left', 'right'], color='black', style='solid', weight='2px')
#             ]
#         ),
#         StyleInfo(
#             locname=LocColumnLabels(columns='G227_IPAQ_VIG_HPD'),
#             grpname=None,
#             colname='G227_IPAQ_VIG_HPD',
#             rownum=None,
#             colnum=None,
#             styles=[CellStyleBorders(sides=['left', 'right'], color='black', style='solid', weight='2px')]
#         )
#     ],
#     _locale=<great_tables._gt_data.Locale object at 0x0000017581598F50>,
#     _formats=[<great_tables._gt_data.FormatInfo object at 0x00000175FE7A94F0>],
#     _substitutions=[],
#     _options=Options(
#         table_id=OptionsInfo(scss=True, category='table', type='value', value='pb_preview_tbl'),
#         table_caption=OptionsInfo(scss=False, category='table', type='value', value=None),
#         table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'),
#         table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'),
#         table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'),
#         table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'),
#         table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'),
#         table_additional_css=OptionsInfo(
#             scss=False,
#             category='table',
#             type='values',
#             value=[
#                 "@import url('https://fonts.googleapis.com/css2?family=IBM+Plex+Sans&display=swap');",
#                 "@import url('https://fonts.googleapis.com/css2?family=IBM+Plex+Mono&display=swap');",
#                 "@import url('https://fonts.googleapis.com/css2?family=IBM+Plex+Mono&display=swap');",
#                 "@import url('https://fonts.googleapis.com/css2?family=IBM+Plex+Mono&display=swap');"
#             ]
#         ),
#         table_font_names=OptionsInfo(
#             scss=False,
#             category='table',
#             type='values',
#             value=['IBM Plex Sans', '-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']
#         ),
#         table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'),
#         table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'),
#         table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'),
#         table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'),
#         table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'),
#         table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True),
#         table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'),
#         table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'),
#         table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'),
#         table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'),
#         table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'),
#         table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'),
#         table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True),
#         table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'),
#         table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'),
#         table_border_bottom_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'),
#         table_border_left_style=OptionsInfo(scss=True, category='table', type='value', value='none'),
#         table_border_left_width=OptionsInfo(scss=True, category='table', type='px', value='2px'),
#         table_border_left_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'),
#         heading_background_color=OptionsInfo(scss=True, category='heading', type='value', value=None),
#         heading_align=OptionsInfo(scss=True, category='heading', type='value', value='left'),
#         heading_title_font_size=OptionsInfo(scss=True, category='heading', type='px', value='125%'),
#         heading_title_font_weight=OptionsInfo(scss=True, category='heading', type='value', value='initial'),
#         heading_subtitle_font_size=OptionsInfo(scss=True, category='heading', type='px', value='85%'),
#         heading_subtitle_font_weight=OptionsInfo(scss=True, category='heading', type='value', value='initial'),
#         heading_padding=OptionsInfo(scss=True, category='heading', type='px', value='4px'),
#         heading_padding_horizontal=OptionsInfo(scss=True, category='heading', type='px', value='5px'),
#         heading_border_bottom_style=OptionsInfo(scss=True, category='heading', type='value', value='solid'),
#         heading_border_bottom_width=OptionsInfo(scss=True, category='heading', type='px', value='2px'),
#         heading_border_bottom_color=OptionsInfo(scss=True, category='heading', type='value', value='#D3D3D3'),
#         heading_border_lr_style=OptionsInfo(scss=True, category='heading', type='value', value='none'),
#         heading_border_lr_width=OptionsInfo(scss=True, category='heading', type='px', value='1px'),
#         heading_border_lr_color=OptionsInfo(scss=True, category='heading', type='value', value='#D3D3D3'),
#         column_labels_background_color=OptionsInfo(scss=True, category='column_labels', type='value', value=None),
#         column_labels_font_size=OptionsInfo(scss=True, category='column_labels', type='px', value='100%'),
#         column_labels_font_weight=OptionsInfo(scss=True, category='column_labels', type='value', value='normal'),
#         column_labels_text_transform=OptionsInfo(scss=True, category='column_labels', type='value', value='inherit'),
#         column_labels_padding=OptionsInfo(scss=True, category='column_labels', type='px', value='5px'),
#         column_labels_padding_horizontal=OptionsInfo(scss=True, category='column_labels', type='px', value='5px'),
#         column_labels_vlines_style=OptionsInfo(scss=True, category='table_body', type='value', value='solid'),
#         column_labels_vlines_width=OptionsInfo(scss=True, category='table_body', type='px', value='1px'),
#         column_labels_vlines_color=OptionsInfo(scss=True, category='table_body', type='value', value='#F2F2F2'),
#         column_labels_border_top_style=OptionsInfo(scss=True, category='column_labels', type='value', value='solid'),
#         column_labels_border_top_width=OptionsInfo(scss=True, category='column_labels', type='px', value='2px'),
#         column_labels_border_top_color=OptionsInfo(scss=True, category='column_labels', type='value', value='#D3D3D3'),
#         column_labels_border_bottom_style=OptionsInfo(scss=True, category='column_labels', type='value', value='solid'),
#         column_labels_border_bottom_width=OptionsInfo(scss=True, category='column_labels', type='px', value='2px'),
#         column_labels_border_bottom_color=OptionsInfo(scss=True, category='column_labels', type='value', value='#D3D3D3'),
#         column_labels_border_lr_style=OptionsInfo(scss=True, category='column_labels', type='value', value='none'),
#         column_labels_border_lr_width=OptionsInfo(scss=True, category='column_labels', type='px', value='1px'),
#         column_labels_border_lr_color=OptionsInfo(scss=True, category='column_labels', type='value', value='#D3D3D3'),
#         column_labels_hidden=OptionsInfo(scss=False, category='column_labels', type='boolean', value=False),
#         row_group_background_color=OptionsInfo(scss=True, category='row_group', type='value', value=None),
#         row_group_font_size=OptionsInfo(scss=True, category='row_group', type='px', value='100%'),
#         row_group_font_weight=OptionsInfo(scss=True, category='row_group', type='value', value='initial'),
#         row_group_text_transform=OptionsInfo(scss=True, category='row_group', type='value', value='inherit'),
#         row_group_padding=OptionsInfo(scss=True, category='row_group', type='px', value='8px'),
#         row_group_padding_horizontal=OptionsInfo(scss=True, category='row_group', type='px', value='5px'),
#         row_group_border_top_style=OptionsInfo(scss=True, category='row_group', type='value', value='solid'),
#         row_group_border_top_width=OptionsInfo(scss=True, category='row_group', type='px', value='2px'),
#         row_group_border_top_color=OptionsInfo(scss=True, category='row_group', type='value', value='#D3D3D3'),
#         row_group_border_right_style=OptionsInfo(scss=True, category='row_group', type='value', value='none'),
#         row_group_border_right_width=OptionsInfo(scss=True, category='row_group', type='px', value='1px'),
#         row_group_border_right_color=OptionsInfo(scss=True, category='row_group', type='value', value='#D3D3D3'),
#         row_group_border_bottom_style=OptionsInfo(scss=True, category='row_group', type='value', value='solid'),
#         row_group_border_bottom_width=OptionsInfo(scss=True, category='row_group', type='px', value='2px'),
#         row_group_border_bottom_color=OptionsInfo(scss=True, category='row_group', type='value', value='#D3D3D3'),
#         row_group_border_left_style=OptionsInfo(scss=True, category='row_group', type='value', value='none'),
#         row_group_border_left_width=OptionsInfo(scss=True, category='row_group', type='px', value='1px'),
#         row_group_border_left_color=OptionsInfo(scss=True, category='row_group', type='value', value='#D3D3D3'),
#         row_group_as_column=OptionsInfo(scss=False, category='row_group', type='boolean', value=False),
#         table_body_hlines_style=OptionsInfo(scss=True, category='table_body', type='value', value='solid'),
#         table_body_hlines_width=OptionsInfo(scss=True, category='table_body', type='px', value='1px'),
#         table_body_hlines_color=OptionsInfo(scss=True, category='table_body', type='value', value='#D3D3D3'),
#         table_body_vlines_style=OptionsInfo(scss=True, category='table_body', type='value', value='solid'),
#         table_body_vlines_width=OptionsInfo(scss=True, category='table_body', type='px', value='1px'),
#         table_body_vlines_color=OptionsInfo(scss=True, category='table_body', type='value', value='#E9E9E9'),
#         table_body_border_top_style=OptionsInfo(scss=True, category='table_body', type='value', value='solid'),
#         table_body_border_top_width=OptionsInfo(scss=True, category='table_body', type='px', value='2px'),
#         table_body_border_top_color=OptionsInfo(scss=True, category='table_body', type='value', value='#D3D3D3'),
#         table_body_border_bottom_style=OptionsInfo(scss=True, category='table_body', type='value', value='solid'),
#         table_body_border_bottom_width=OptionsInfo(scss=True, category='table_body', type='px', value='2px'),
#         table_body_border_bottom_color=OptionsInfo(scss=True, category='table_body', type='value', value='#D3D3D3'),
#         data_row_padding=OptionsInfo(scss=True, category='data_row', type='px', value='8px'),
#         data_row_padding_horizontal=OptionsInfo(scss=True, category='data_row', type='px', value='5px'),
#         stub_background_color=OptionsInfo(scss=True, category='stub', type='value', value=None),
#         stub_font_size=OptionsInfo(scss=True, category='stub', type='px', value='100%'),
#         stub_font_weight=OptionsInfo(scss=True, category='stub', type='value', value='initial'),
#         stub_text_transform=OptionsInfo(scss=True, category='stub', type='value', value='inherit'),
#         stub_border_style=OptionsInfo(scss=True, category='stub', type='value', value='solid'),
#         stub_border_width=OptionsInfo(scss=True, category='stub', type='px', value='2px'),
#         stub_border_color=OptionsInfo(scss=True, category='stub', type='value', value='#D3D3D3'),
#         stub_row_group_background_color=OptionsInfo(scss=True, category='stub', type='value', value=None),
#         stub_row_group_font_size=OptionsInfo(scss=True, category='stub', type='px', value='100%'),
#         stub_row_group_font_weight=OptionsInfo(scss=True, category='stub', type='value', value='initial'),
#         stub_row_group_text_transform=OptionsInfo(scss=True, category='stub', type='value', value='inherit'),
#         stub_row_group_border_style=OptionsInfo(scss=True, category='stub', type='value', value='solid'),
#         stub_row_group_border_width=OptionsInfo(scss=True, category='stub', type='px', value='2px'),
#         stub_row_group_border_color=OptionsInfo(scss=True, category='stub', type='value', value='#D3D3D3'),
#         source_notes_padding=OptionsInfo(scss=True, category='source_notes', type='px', value='4px'),
#         source_notes_padding_horizontal=OptionsInfo(scss=True, category='source_notes', type='px', value='5px'),
#         source_notes_background_color=OptionsInfo(scss=True, category='source_notes', type='value', value=None),
#         source_notes_font_size=OptionsInfo(scss=True, category='source_notes', type='px', value='90%'),
#         source_notes_border_bottom_style=OptionsInfo(scss=True, category='source_notes', type='value', value='none'),
#         source_notes_border_bottom_width=OptionsInfo(scss=True, category='source_notes', type='px', value='2px'),
#         source_notes_border_bottom_color=OptionsInfo(scss=True, category='source_notes', type='value', value='#D3D3D3'),
#         source_notes_border_lr_style=OptionsInfo(scss=True, category='source_notes', type='value', value='none'),
#         source_notes_border_lr_width=OptionsInfo(scss=True, category='source_notes', type='px', value='2px'),
#         source_notes_border_lr_color=OptionsInfo(scss=True, category='source_notes', type='value', value='#D3D3D3'),
#         source_notes_multiline=OptionsInfo(scss=False, category='source_notes', type='boolean', value=True),
#         source_notes_sep=OptionsInfo(scss=False, category='source_notes', type='value', value=' '),
#         row_striping_background_color=OptionsInfo(scss=True, category='row', type='value', value='rgba(128,128,128,0.05)'),
#         row_striping_include_stub=OptionsInfo(scss=False, category='row', type='boolean', value=False),
#         row_striping_include_table_body=OptionsInfo(scss=False, category='row', type='boolean', value=False),
#         container_width=OptionsInfo(scss=False, category='container', type='px', value='auto'),
#         container_height=OptionsInfo(scss=False, category='container', type='px', value='auto'),
#         container_padding_x=OptionsInfo(scss=False, category='container', type='px', value='0px'),
#         container_padding_y=OptionsInfo(scss=False, category='container', type='px', value='10px'),
#         container_overflow_x=OptionsInfo(scss=False, category='container', type='overflow', value='auto'),
#         container_overflow_y=OptionsInfo(scss=False, category='container', type='overflow', value='auto'),
#         quarto_disable_processing=OptionsInfo(scss=False, category='quarto', type='logical', value=True),
#         quarto_use_bootstrap=OptionsInfo(scss=False, category='quarto', type='logical', value=False)
#     ),
#     _has_built=False
# )

# %%
harmonised_validation.get_step_report(i=10, columns_subset=pb.matches(r"ID|VIG"))
# Out:
# GT(
#     _tbl_data=shape: (8, 8)
# ┌───────────┬─────────┬────────────┬────────────┬────────────┬────────────┬────────────┬───────────┐
# │ _row_num_ ┆ ID      ┆ G227_IPAQ_ ┆ G227_IPAQ_ ┆ G227_IPAQ_ ┆ G227_IPAQ_ ┆ G227_IPAQ_ ┆ G227_IPAQ │
# │ ---       ┆ ---     ┆ VIG_W      ┆ VIG_HPD    ┆ VIG_MPD    ┆ VIG_D      ┆ VIG_MINS   ┆ _VIG_MET  │
# │ u32       ┆ f64     ┆ ---        ┆ ---        ┆ ---        ┆ ---        ┆ ---        ┆ ---       │
# │           ┆         ┆ f64        ┆ f64        ┆ f64        ┆ f64        ┆ f64        ┆ f64       │
# ╞═══════════╪═════════╪════════════╪════════════╪════════════╪════════════╪════════════╪═══════════╡
# │ 211       ┆ 18810.0 ┆ 1.0        ┆ null       ┆ 60.0       ┆ 4.0        ┆ 60.0       ┆ 1920.0    │
# │ 271       ┆ 21230.0 ┆ 1.0        ┆ null       ┆ 60.0       ┆ 2.0        ┆ 60.0       ┆ 960.0     │
# │ 426       ┆ 42750.0 ┆ 1.0        ┆ null       ┆ 80.0       ┆ 4.0        ┆ 80.0       ┆ 2560.0    │
# │ 476       ┆ 44720.0 ┆ 1.0        ┆ null       ┆ 60.0       ┆ 3.0        ┆ 60.0       ┆ 1440.0    │
# │ 486       ┆ 44950.0 ┆ 1.0        ┆ null       ┆ 60.0       ┆ 6.0        ┆ 60.0       ┆ 2880.0    │
# │ 488       ┆ 45050.0 ┆ 1.0        ┆ null       ┆ 70.0       ┆ 4.0        ┆ 70.0       ┆ 2240.0    │
# │ 519       ┆ 46260.0 ┆ 1.0        ┆ null       ┆ 60.0       ┆ 5.0        ┆ 60.0       ┆ 2400.0    │
# │ 540       ┆ 47290.0 ┆ 1.0        ┆ null       ┆ 90.0       ┆ 3.0        ┆ 90.0       ┆ 2160.0    │
# └───────────┴─────────┴────────────┴────────────┴────────────┴────────────┴────────────┴───────────┘,
#     _body=<great_tables._gt_data.Body object at 0x0000017581B70A50>,
#     _boxhead=Boxhead([ColInfo(var='_row_num_', type=<ColInfoTypeEnum.default: 1>, column_label='', column_align='right', column_width='33.4px'), ColInfo(var='ID', type=<ColInfoTypeEnum.default: 1>, column_label=Html(text="<div><div style='white-space: nowrap; text-overflow: ellipsis; overflow: hidden; padding-bottom: 2px; margin-bottom: 2px;'>ID</div><div style='white-space: nowrap; text-overflow: ellipsis; overflow: hidden; padding-top: 2px; margin-top: 2px;'><em>Float64</em></div></div>"), column_align='right', column_width='65px'), ColInfo(var='G227_IPAQ_VIG_W', type=<ColInfoTypeEnum.default: 1>, column_label=Html(text="<div><div style='white-space: nowrap; text-overflow: ellipsis; overflow: hidden; padding-bottom: 2px; margin-bottom: 2px;'>G227_IPAQ_VIG_W</div><div style='white-space: nowrap; text-overflow: ellipsis; overflow: hidden; padding-top: 2px; margin-top: 2px;'><em>Float64</em></div></div>"), column_align='right', column_width='127px'), ColInfo(var='G227_IPAQ_VIG_HPD', type=<ColInfoTypeEnum.default: 1>, column_label=Html(text="<div><div style='white-space: nowrap; text-overflow: ellipsis; overflow: hidden; padding-bottom: 2px; margin-bottom: 2px;'>G227_IPAQ_VIG_HPD</div><div style='white-space: nowrap; text-overflow: ellipsis; overflow: hidden; padding-top: 2px; margin-top: 2px;'><em>Float64</em></div></div>"), column_align='right', column_width='143px'), ColInfo(var='G227_IPAQ_VIG_MPD', type=<ColInfoTypeEnum.default: 1>, column_label=Html(text="<div><div style='white-space: nowrap; text-overflow: ellipsis; overflow: hidden; padding-bottom: 2px; margin-bottom: 2px;'>G227_IPAQ_VIG_MPD</div><div style='white-space: nowrap; text-overflow: ellipsis; overflow: hidden; padding-top: 2px; margin-top: 2px;'><em>Float64</em></div></div>"), column_align='right', column_width='143px'), ColInfo(var='G227_IPAQ_VIG_D', type=<ColInfoTypeEnum.default: 1>, column_label=Html(text="<div><div style='white-space: nowrap; text-overflow: ellipsis; overflow: hidden; padding-bottom: 2px; margin-bottom: 2px;'>G227_IPAQ_VIG_D</div><div style='white-space: nowrap; text-overflow: ellipsis; overflow: hidden; padding-top: 2px; margin-top: 2px;'><em>Float64</em></div></div>"), column_align='right', column_width='127px'), ColInfo(var='G227_IPAQ_VIG_MINS', type=<ColInfoTypeEnum.default: 1>, column_label=Html(text="<div><div style='white-space: nowrap; text-overflow: ellipsis; overflow: hidden; padding-bottom: 2px; margin-bottom: 2px;'>G227_IPAQ_VIG_MINS</div><div style='white-space: nowrap; text-overflow: ellipsis; overflow: hidden; padding-top: 2px; margin-top: 2px;'><em>Float64</em></div></div>"), column_align='right', column_width='150px'), ColInfo(var='G227_IPAQ_VIG_MET', type=<ColInfoTypeEnum.default: 1>, column_label=Html(text="<div><div style='white-space: nowrap; text-overflow: ellipsis; overflow: hidden; padding-bottom: 2px; margin-bottom: 2px;'>G227_IPAQ_VIG_MET</div><div style='white-space: nowrap; text-overflow: ellipsis; overflow: hidden; padding-top: 2px; margin-top: 2px;'><em>Float64</em></div></div>"), column_align='right', column_width='143px')]),
#     _stub=<great_tables._gt_data.Stub object at 0x00000175FE9ADEB0>,
#     _spanners=Spanners([]),
#     _heading=Heading(
#         title=Md(
#             text="<p>Report for Validation Step 10<div style='font-size: 13.6px; '><div style='padding-top: 7px;'>ASSERTION <span style='border-style: solid; border-width: thin; border-color: lightblue; padding-left: 2px; padding-right: 2px;'><code style='color: #303030; background-color: transparent; position: relative; bottom: 1px;'><code style='color: #303030; font-family: monospace; font-size: smaller;'>0 &le; G227_IPAQ_VIG_MPD &le; 59</code></code></span></div><div style='padding-top: 7px;'><strong>8</strong> / <strong>721</strong> TEST UNIT FAILURES IN COLUMN <strong>4</strong> </div><div>EXTRACT OF ALL <strong>8</strong> ROWS (WITH <span style='color: #B22222;'>TEST UNIT FAILURES IN RED</span>):</div></div></p>\n"
#         ),
#         subtitle=None,
#         preheader=None
#     ),
#     _stubhead=None,
#     _source_notes=[],
#     _footnotes=[],
#     _styles=[
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='_row_num_',
#             rownum=0,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='_row_num_',
#             rownum=1,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='_row_num_',
#             rownum=2,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='_row_num_',
#             rownum=3,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='_row_num_',
#             rownum=4,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='_row_num_',
#             rownum=5,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='_row_num_',
#             rownum=6,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='_row_num_',
#             rownum=7,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='ID',
#             rownum=0,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='ID',
#             rownum=1,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='ID',
#             rownum=2,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='ID',
#             rownum=3,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='ID',
#             rownum=4,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='ID',
#             rownum=5,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='ID',
#             rownum=6,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='ID',
#             rownum=7,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_VIG_W',
#             rownum=0,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_VIG_W',
#             rownum=1,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_VIG_W',
#             rownum=2,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_VIG_W',
#             rownum=3,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_VIG_W',
#             rownum=4,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_VIG_W',
#             rownum=5,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_VIG_W',
#             rownum=6,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_VIG_W',
#             rownum=7,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_VIG_HPD',
#             rownum=0,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_VIG_HPD',
#             rownum=1,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_VIG_HPD',
#             rownum=2,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_VIG_HPD',
#             rownum=3,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_VIG_HPD',
#             rownum=4,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_VIG_HPD',
#             rownum=5,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_VIG_HPD',
#             rownum=6,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_VIG_HPD',
#             rownum=7,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_VIG_MPD',
#             rownum=0,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_VIG_MPD',
#             rownum=1,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_VIG_MPD',
#             rownum=2,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_VIG_MPD',
#             rownum=3,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_VIG_MPD',
#             rownum=4,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_VIG_MPD',
#             rownum=5,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_VIG_MPD',
#             rownum=6,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_VIG_MPD',
#             rownum=7,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_VIG_D',
#             rownum=0,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_VIG_D',
#             rownum=1,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_VIG_D',
#             rownum=2,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_VIG_D',
#             rownum=3,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_VIG_D',
#             rownum=4,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_VIG_D',
#             rownum=5,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_VIG_D',
#             rownum=6,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_VIG_D',
#             rownum=7,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_VIG_MINS',
#             rownum=0,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_VIG_MINS',
#             rownum=1,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_VIG_MINS',
#             rownum=2,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_VIG_MINS',
#             rownum=3,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_VIG_MINS',
#             rownum=4,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_VIG_MINS',
#             rownum=5,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_VIG_MINS',
#             rownum=6,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_VIG_MINS',
#             rownum=7,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_VIG_MET',
#             rownum=0,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_VIG_MET',
#             rownum=1,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_VIG_MET',
#             rownum=2,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_VIG_MET',
#             rownum=3,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_VIG_MET',
#             rownum=4,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_VIG_MET',
#             rownum=5,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_VIG_MET',
#             rownum=6,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_VIG_MET',
#             rownum=7,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='_row_num_',
#             rownum=0,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='_row_num_',
#             rownum=1,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='_row_num_',
#             rownum=2,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='_row_num_',
#             rownum=3,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='_row_num_',
#             rownum=4,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='_row_num_',
#             rownum=5,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='_row_num_',
#             rownum=6,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='_row_num_',
#             rownum=7,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='ID',
#             rownum=0,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='ID',
#             rownum=1,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='ID',
#             rownum=2,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='ID',
#             rownum=3,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='ID',
#             rownum=4,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='ID',
#             rownum=5,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='ID',
#             rownum=6,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='ID',
#             rownum=7,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_VIG_W',
#             rownum=0,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_VIG_W',
#             rownum=1,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_VIG_W',
#             rownum=2,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_VIG_W',
#             rownum=3,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_VIG_W',
#             rownum=4,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_VIG_W',
#             rownum=5,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_VIG_W',
#             rownum=6,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_VIG_W',
#             rownum=7,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_VIG_HPD',
#             rownum=0,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_VIG_HPD',
#             rownum=1,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_VIG_HPD',
#             rownum=2,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_VIG_HPD',
#             rownum=3,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_VIG_HPD',
#             rownum=4,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_VIG_HPD',
#             rownum=5,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_VIG_HPD',
#             rownum=6,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_VIG_HPD',
#             rownum=7,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_VIG_MPD',
#             rownum=0,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_VIG_MPD',
#             rownum=1,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_VIG_MPD',
#             rownum=2,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_VIG_MPD',
#             rownum=3,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_VIG_MPD',
#             rownum=4,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_VIG_MPD',
#             rownum=5,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_VIG_MPD',
#             rownum=6,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_VIG_MPD',
#             rownum=7,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_VIG_D',
#             rownum=0,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_VIG_D',
#             rownum=1,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_VIG_D',
#             rownum=2,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_VIG_D',
#             rownum=3,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_VIG_D',
#             rownum=4,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_VIG_D',
#             rownum=5,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_VIG_D',
#             rownum=6,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_VIG_D',
#             rownum=7,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_VIG_MINS',
#             rownum=0,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_VIG_MINS',
#             rownum=1,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_VIG_MINS',
#             rownum=2,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
# ...
#                 CellStyleFill(color='#FFC1C159'),
#                 CellStyleBorders(sides=['left', 'right'], color='black', style='solid', weight='2px')
#             ]
#         ),
#         StyleInfo(
#             locname=LocBody(columns='G227_IPAQ_VIG_MPD', rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_VIG_MPD',
#             rownum=7,
#             colnum=None,
#             styles=[
#                 CellStyleText(color='#B22222', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None),
#                 CellStyleFill(color='#FFC1C159'),
#                 CellStyleBorders(sides=['left', 'right'], color='black', style='solid', weight='2px')
#             ]
#         ),
#         StyleInfo(
#             locname=LocColumnLabels(columns='G227_IPAQ_VIG_MPD'),
#             grpname=None,
#             colname='G227_IPAQ_VIG_MPD',
#             rownum=None,
#             colnum=None,
#             styles=[CellStyleBorders(sides=['left', 'right'], color='black', style='solid', weight='2px')]
#         )
#     ],
#     _locale=<great_tables._gt_data.Locale object at 0x0000017581B70FF0>,
#     _formats=[<great_tables._gt_data.FormatInfo object at 0x00000175FE6877D0>],
#     _substitutions=[],
#     _options=Options(
#         table_id=OptionsInfo(scss=True, category='table', type='value', value='pb_preview_tbl'),
#         table_caption=OptionsInfo(scss=False, category='table', type='value', value=None),
#         table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'),
#         table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'),
#         table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'),
#         table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'),
#         table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'),
#         table_additional_css=OptionsInfo(
#             scss=False,
#             category='table',
#             type='values',
#             value=[
#                 "@import url('https://fonts.googleapis.com/css2?family=IBM+Plex+Sans&display=swap');",
#                 "@import url('https://fonts.googleapis.com/css2?family=IBM+Plex+Mono&display=swap');",
#                 "@import url('https://fonts.googleapis.com/css2?family=IBM+Plex+Mono&display=swap');",
#                 "@import url('https://fonts.googleapis.com/css2?family=IBM+Plex+Mono&display=swap');"
#             ]
#         ),
#         table_font_names=OptionsInfo(
#             scss=False,
#             category='table',
#             type='values',
#             value=['IBM Plex Sans', '-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']
#         ),
#         table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'),
#         table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'),
#         table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'),
#         table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'),
#         table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'),
#         table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True),
#         table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'),
#         table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'),
#         table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'),
#         table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'),
#         table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'),
#         table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'),
#         table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True),
#         table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'),
#         table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'),
#         table_border_bottom_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'),
#         table_border_left_style=OptionsInfo(scss=True, category='table', type='value', value='none'),
#         table_border_left_width=OptionsInfo(scss=True, category='table', type='px', value='2px'),
#         table_border_left_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'),
#         heading_background_color=OptionsInfo(scss=True, category='heading', type='value', value=None),
#         heading_align=OptionsInfo(scss=True, category='heading', type='value', value='left'),
#         heading_title_font_size=OptionsInfo(scss=True, category='heading', type='px', value='125%'),
#         heading_title_font_weight=OptionsInfo(scss=True, category='heading', type='value', value='initial'),
#         heading_subtitle_font_size=OptionsInfo(scss=True, category='heading', type='px', value='85%'),
#         heading_subtitle_font_weight=OptionsInfo(scss=True, category='heading', type='value', value='initial'),
#         heading_padding=OptionsInfo(scss=True, category='heading', type='px', value='4px'),
#         heading_padding_horizontal=OptionsInfo(scss=True, category='heading', type='px', value='5px'),
#         heading_border_bottom_style=OptionsInfo(scss=True, category='heading', type='value', value='solid'),
#         heading_border_bottom_width=OptionsInfo(scss=True, category='heading', type='px', value='2px'),
#         heading_border_bottom_color=OptionsInfo(scss=True, category='heading', type='value', value='#D3D3D3'),
#         heading_border_lr_style=OptionsInfo(scss=True, category='heading', type='value', value='none'),
#         heading_border_lr_width=OptionsInfo(scss=True, category='heading', type='px', value='1px'),
#         heading_border_lr_color=OptionsInfo(scss=True, category='heading', type='value', value='#D3D3D3'),
#         column_labels_background_color=OptionsInfo(scss=True, category='column_labels', type='value', value=None),
#         column_labels_font_size=OptionsInfo(scss=True, category='column_labels', type='px', value='100%'),
#         column_labels_font_weight=OptionsInfo(scss=True, category='column_labels', type='value', value='normal'),
#         column_labels_text_transform=OptionsInfo(scss=True, category='column_labels', type='value', value='inherit'),
#         column_labels_padding=OptionsInfo(scss=True, category='column_labels', type='px', value='5px'),
#         column_labels_padding_horizontal=OptionsInfo(scss=True, category='column_labels', type='px', value='5px'),
#         column_labels_vlines_style=OptionsInfo(scss=True, category='table_body', type='value', value='solid'),
#         column_labels_vlines_width=OptionsInfo(scss=True, category='table_body', type='px', value='1px'),
#         column_labels_vlines_color=OptionsInfo(scss=True, category='table_body', type='value', value='#F2F2F2'),
#         column_labels_border_top_style=OptionsInfo(scss=True, category='column_labels', type='value', value='solid'),
#         column_labels_border_top_width=OptionsInfo(scss=True, category='column_labels', type='px', value='2px'),
#         column_labels_border_top_color=OptionsInfo(scss=True, category='column_labels', type='value', value='#D3D3D3'),
#         column_labels_border_bottom_style=OptionsInfo(scss=True, category='column_labels', type='value', value='solid'),
#         column_labels_border_bottom_width=OptionsInfo(scss=True, category='column_labels', type='px', value='2px'),
#         column_labels_border_bottom_color=OptionsInfo(scss=True, category='column_labels', type='value', value='#D3D3D3'),
#         column_labels_border_lr_style=OptionsInfo(scss=True, category='column_labels', type='value', value='none'),
#         column_labels_border_lr_width=OptionsInfo(scss=True, category='column_labels', type='px', value='1px'),
#         column_labels_border_lr_color=OptionsInfo(scss=True, category='column_labels', type='value', value='#D3D3D3'),
#         column_labels_hidden=OptionsInfo(scss=False, category='column_labels', type='boolean', value=False),
#         row_group_background_color=OptionsInfo(scss=True, category='row_group', type='value', value=None),
#         row_group_font_size=OptionsInfo(scss=True, category='row_group', type='px', value='100%'),
#         row_group_font_weight=OptionsInfo(scss=True, category='row_group', type='value', value='initial'),
#         row_group_text_transform=OptionsInfo(scss=True, category='row_group', type='value', value='inherit'),
#         row_group_padding=OptionsInfo(scss=True, category='row_group', type='px', value='8px'),
#         row_group_padding_horizontal=OptionsInfo(scss=True, category='row_group', type='px', value='5px'),
#         row_group_border_top_style=OptionsInfo(scss=True, category='row_group', type='value', value='solid'),
#         row_group_border_top_width=OptionsInfo(scss=True, category='row_group', type='px', value='2px'),
#         row_group_border_top_color=OptionsInfo(scss=True, category='row_group', type='value', value='#D3D3D3'),
#         row_group_border_right_style=OptionsInfo(scss=True, category='row_group', type='value', value='none'),
#         row_group_border_right_width=OptionsInfo(scss=True, category='row_group', type='px', value='1px'),
#         row_group_border_right_color=OptionsInfo(scss=True, category='row_group', type='value', value='#D3D3D3'),
#         row_group_border_bottom_style=OptionsInfo(scss=True, category='row_group', type='value', value='solid'),
#         row_group_border_bottom_width=OptionsInfo(scss=True, category='row_group', type='px', value='2px'),
#         row_group_border_bottom_color=OptionsInfo(scss=True, category='row_group', type='value', value='#D3D3D3'),
#         row_group_border_left_style=OptionsInfo(scss=True, category='row_group', type='value', value='none'),
#         row_group_border_left_width=OptionsInfo(scss=True, category='row_group', type='px', value='1px'),
#         row_group_border_left_color=OptionsInfo(scss=True, category='row_group', type='value', value='#D3D3D3'),
#         row_group_as_column=OptionsInfo(scss=False, category='row_group', type='boolean', value=False),
#         table_body_hlines_style=OptionsInfo(scss=True, category='table_body', type='value', value='solid'),
#         table_body_hlines_width=OptionsInfo(scss=True, category='table_body', type='px', value='1px'),
#         table_body_hlines_color=OptionsInfo(scss=True, category='table_body', type='value', value='#D3D3D3'),
#         table_body_vlines_style=OptionsInfo(scss=True, category='table_body', type='value', value='solid'),
#         table_body_vlines_width=OptionsInfo(scss=True, category='table_body', type='px', value='1px'),
#         table_body_vlines_color=OptionsInfo(scss=True, category='table_body', type='value', value='#E9E9E9'),
#         table_body_border_top_style=OptionsInfo(scss=True, category='table_body', type='value', value='solid'),
#         table_body_border_top_width=OptionsInfo(scss=True, category='table_body', type='px', value='2px'),
#         table_body_border_top_color=OptionsInfo(scss=True, category='table_body', type='value', value='#D3D3D3'),
#         table_body_border_bottom_style=OptionsInfo(scss=True, category='table_body', type='value', value='solid'),
#         table_body_border_bottom_width=OptionsInfo(scss=True, category='table_body', type='px', value='2px'),
#         table_body_border_bottom_color=OptionsInfo(scss=True, category='table_body', type='value', value='#D3D3D3'),
#         data_row_padding=OptionsInfo(scss=True, category='data_row', type='px', value='8px'),
#         data_row_padding_horizontal=OptionsInfo(scss=True, category='data_row', type='px', value='5px'),
#         stub_background_color=OptionsInfo(scss=True, category='stub', type='value', value=None),
#         stub_font_size=OptionsInfo(scss=True, category='stub', type='px', value='100%'),
#         stub_font_weight=OptionsInfo(scss=True, category='stub', type='value', value='initial'),
#         stub_text_transform=OptionsInfo(scss=True, category='stub', type='value', value='inherit'),
#         stub_border_style=OptionsInfo(scss=True, category='stub', type='value', value='solid'),
#         stub_border_width=OptionsInfo(scss=True, category='stub', type='px', value='2px'),
#         stub_border_color=OptionsInfo(scss=True, category='stub', type='value', value='#D3D3D3'),
#         stub_row_group_background_color=OptionsInfo(scss=True, category='stub', type='value', value=None),
#         stub_row_group_font_size=OptionsInfo(scss=True, category='stub', type='px', value='100%'),
#         stub_row_group_font_weight=OptionsInfo(scss=True, category='stub', type='value', value='initial'),
#         stub_row_group_text_transform=OptionsInfo(scss=True, category='stub', type='value', value='inherit'),
#         stub_row_group_border_style=OptionsInfo(scss=True, category='stub', type='value', value='solid'),
#         stub_row_group_border_width=OptionsInfo(scss=True, category='stub', type='px', value='2px'),
#         stub_row_group_border_color=OptionsInfo(scss=True, category='stub', type='value', value='#D3D3D3'),
#         source_notes_padding=OptionsInfo(scss=True, category='source_notes', type='px', value='4px'),
#         source_notes_padding_horizontal=OptionsInfo(scss=True, category='source_notes', type='px', value='5px'),
#         source_notes_background_color=OptionsInfo(scss=True, category='source_notes', type='value', value=None),
#         source_notes_font_size=OptionsInfo(scss=True, category='source_notes', type='px', value='90%'),
#         source_notes_border_bottom_style=OptionsInfo(scss=True, category='source_notes', type='value', value='none'),
#         source_notes_border_bottom_width=OptionsInfo(scss=True, category='source_notes', type='px', value='2px'),
#         source_notes_border_bottom_color=OptionsInfo(scss=True, category='source_notes', type='value', value='#D3D3D3'),
#         source_notes_border_lr_style=OptionsInfo(scss=True, category='source_notes', type='value', value='none'),
#         source_notes_border_lr_width=OptionsInfo(scss=True, category='source_notes', type='px', value='2px'),
#         source_notes_border_lr_color=OptionsInfo(scss=True, category='source_notes', type='value', value='#D3D3D3'),
#         source_notes_multiline=OptionsInfo(scss=False, category='source_notes', type='boolean', value=True),
#         source_notes_sep=OptionsInfo(scss=False, category='source_notes', type='value', value=' '),
#         row_striping_background_color=OptionsInfo(scss=True, category='row', type='value', value='rgba(128,128,128,0.05)'),
#         row_striping_include_stub=OptionsInfo(scss=False, category='row', type='boolean', value=False),
#         row_striping_include_table_body=OptionsInfo(scss=False, category='row', type='boolean', value=False),
#         container_width=OptionsInfo(scss=False, category='container', type='px', value='auto'),
#         container_height=OptionsInfo(scss=False, category='container', type='px', value='auto'),
#         container_padding_x=OptionsInfo(scss=False, category='container', type='px', value='0px'),
#         container_padding_y=OptionsInfo(scss=False, category='container', type='px', value='10px'),
#         container_overflow_x=OptionsInfo(scss=False, category='container', type='overflow', value='auto'),
#         container_overflow_y=OptionsInfo(scss=False, category='container', type='overflow', value='auto'),
#         quarto_disable_processing=OptionsInfo(scss=False, category='quarto', type='logical', value=True),
#         quarto_use_bootstrap=OptionsInfo(scss=False, category='quarto', type='logical', value=False)
#     ),
#     _has_built=False
# )

# %%
harmonised_validation.get_step_report(i=23, columns_subset=pb.matches(r"ID|MOD"))
# Out:
# GT(
#     _tbl_data=shape: (10, 8)
# ┌───────────┬─────────┬────────────┬────────────┬────────────┬────────────┬────────────┬───────────┐
# │ _row_num_ ┆ ID      ┆ G227_IPAQ_ ┆ G227_IPAQ_ ┆ G227_IPAQ_ ┆ G227_IPAQ_ ┆ G227_IPAQ_ ┆ G227_IPAQ │
# │ ---       ┆ ---     ┆ MOD_W      ┆ MOD_HPD    ┆ MOD_MPD    ┆ MOD_D      ┆ MOD_MINS   ┆ _MOD_MET  │
# │ u32       ┆ f64     ┆ ---        ┆ ---        ┆ ---        ┆ ---        ┆ ---        ┆ ---       │
# │           ┆         ┆ f64        ┆ f64        ┆ f64        ┆ f64        ┆ f64        ┆ f64       │
# ╞═══════════╪═════════╪════════════╪════════════╪════════════╪════════════╪════════════╪═══════════╡
# │ 71        ┆ 13270.0 ┆ 1.0        ┆ 20.0       ┆ null       ┆ 7.0        ┆ 180.0      ┆ 5040.0    │
# │ 121       ┆ 15120.0 ┆ 1.0        ┆ 30.0       ┆ null       ┆ 1.0        ┆ 180.0      ┆ 720.0     │
# │ 134       ┆ 15720.0 ┆ 1.0        ┆ 30.0       ┆ null       ┆ 3.0        ┆ 180.0      ┆ 2160.0    │
# │ 194       ┆ 17580.0 ┆ 1.0        ┆ 60.0       ┆ null       ┆ 5.0        ┆ 180.0      ┆ 3600.0    │
# │ 314       ┆ 22220.0 ┆ 1.0        ┆ 45.0       ┆ null       ┆ 2.0        ┆ 180.0      ┆ 1440.0    │
# │ 333       ┆ 23030.0 ┆ 1.0        ┆ 30.0       ┆ null       ┆ 2.0        ┆ 180.0      ┆ 1440.0    │
# │ 459       ┆ 43100.0 ┆ 1.0        ┆ 20.0       ┆ null       ┆ 4.0        ┆ 180.0      ┆ 2880.0    │
# │ 580       ┆ 47740.0 ┆ 1.0        ┆ 33.0       ┆ null       ┆ 3.0        ┆ 180.0      ┆ 2160.0    │
# │ 631       ┆ 49390.0 ┆ 1.0        ┆ 20.0       ┆ null       ┆ 4.0        ┆ 180.0      ┆ 2880.0    │
# │ 649       ┆ 50030.0 ┆ 1.0        ┆ 20.0       ┆ null       ┆ 5.0        ┆ 180.0      ┆ 3600.0    │
# └───────────┴─────────┴────────────┴────────────┴────────────┴────────────┴────────────┴───────────┘,
#     _body=<great_tables._gt_data.Body object at 0x00000175FFFD3C50>,
#     _boxhead=Boxhead([ColInfo(var='_row_num_', type=<ColInfoTypeEnum.default: 1>, column_label='', column_align='right', column_width='33.4px'), ColInfo(var='ID', type=<ColInfoTypeEnum.default: 1>, column_label=Html(text="<div><div style='white-space: nowrap; text-overflow: ellipsis; overflow: hidden; padding-bottom: 2px; margin-bottom: 2px;'>ID</div><div style='white-space: nowrap; text-overflow: ellipsis; overflow: hidden; padding-top: 2px; margin-top: 2px;'><em>Float64</em></div></div>"), column_align='right', column_width='65px'), ColInfo(var='G227_IPAQ_MOD_W', type=<ColInfoTypeEnum.default: 1>, column_label=Html(text="<div><div style='white-space: nowrap; text-overflow: ellipsis; overflow: hidden; padding-bottom: 2px; margin-bottom: 2px;'>G227_IPAQ_MOD_W</div><div style='white-space: nowrap; text-overflow: ellipsis; overflow: hidden; padding-top: 2px; margin-top: 2px;'><em>Float64</em></div></div>"), column_align='right', column_width='127px'), ColInfo(var='G227_IPAQ_MOD_HPD', type=<ColInfoTypeEnum.default: 1>, column_label=Html(text="<div><div style='white-space: nowrap; text-overflow: ellipsis; overflow: hidden; padding-bottom: 2px; margin-bottom: 2px;'>G227_IPAQ_MOD_HPD</div><div style='white-space: nowrap; text-overflow: ellipsis; overflow: hidden; padding-top: 2px; margin-top: 2px;'><em>Float64</em></div></div>"), column_align='right', column_width='143px'), ColInfo(var='G227_IPAQ_MOD_MPD', type=<ColInfoTypeEnum.default: 1>, column_label=Html(text="<div><div style='white-space: nowrap; text-overflow: ellipsis; overflow: hidden; padding-bottom: 2px; margin-bottom: 2px;'>G227_IPAQ_MOD_MPD</div><div style='white-space: nowrap; text-overflow: ellipsis; overflow: hidden; padding-top: 2px; margin-top: 2px;'><em>Float64</em></div></div>"), column_align='right', column_width='143px'), ColInfo(var='G227_IPAQ_MOD_D', type=<ColInfoTypeEnum.default: 1>, column_label=Html(text="<div><div style='white-space: nowrap; text-overflow: ellipsis; overflow: hidden; padding-bottom: 2px; margin-bottom: 2px;'>G227_IPAQ_MOD_D</div><div style='white-space: nowrap; text-overflow: ellipsis; overflow: hidden; padding-top: 2px; margin-top: 2px;'><em>Float64</em></div></div>"), column_align='right', column_width='127px'), ColInfo(var='G227_IPAQ_MOD_MINS', type=<ColInfoTypeEnum.default: 1>, column_label=Html(text="<div><div style='white-space: nowrap; text-overflow: ellipsis; overflow: hidden; padding-bottom: 2px; margin-bottom: 2px;'>G227_IPAQ_MOD_MINS</div><div style='white-space: nowrap; text-overflow: ellipsis; overflow: hidden; padding-top: 2px; margin-top: 2px;'><em>Float64</em></div></div>"), column_align='right', column_width='150px'), ColInfo(var='G227_IPAQ_MOD_MET', type=<ColInfoTypeEnum.default: 1>, column_label=Html(text="<div><div style='white-space: nowrap; text-overflow: ellipsis; overflow: hidden; padding-bottom: 2px; margin-bottom: 2px;'>G227_IPAQ_MOD_MET</div><div style='white-space: nowrap; text-overflow: ellipsis; overflow: hidden; padding-top: 2px; margin-top: 2px;'><em>Float64</em></div></div>"), column_align='right', column_width='143px')]),
#     _stub=<great_tables._gt_data.Stub object at 0x00000175D8A5A1B0>,
#     _spanners=Spanners([]),
#     _heading=Heading(
#         title=Md(
#             text="<p>Report for Validation Step 23<div style='font-size: 13.6px; '><div style='padding-top: 7px;'>ASSERTION <span style='border-style: solid; border-width: thin; border-color: lightblue; padding-left: 2px; padding-right: 2px;'><code style='color: #303030; background-color: transparent; position: relative; bottom: 1px;'><code style='color: #303030; font-family: monospace; font-size: smaller;'>0 &le; G227_IPAQ_MOD_HPD &le; 18</code></code></span></div><div style='padding-top: 7px;'><strong>12</strong> / <strong>765</strong> TEST UNIT FAILURES IN COLUMN <strong>8</strong> </div><div>EXTRACT OF FIRST <strong>10</strong> ROWS (WITH <span style='color: #B22222;'>TEST UNIT FAILURES IN RED</span>):</div></div></p>\n"
#         ),
#         subtitle=None,
#         preheader=None
#     ),
#     _stubhead=None,
#     _source_notes=[],
#     _footnotes=[],
#     _styles=[
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='_row_num_',
#             rownum=0,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='_row_num_',
#             rownum=1,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='_row_num_',
#             rownum=2,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='_row_num_',
#             rownum=3,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='_row_num_',
#             rownum=4,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='_row_num_',
#             rownum=5,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='_row_num_',
#             rownum=6,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='_row_num_',
#             rownum=7,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='_row_num_',
#             rownum=8,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='_row_num_',
#             rownum=9,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='ID',
#             rownum=0,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='ID',
#             rownum=1,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='ID',
#             rownum=2,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='ID',
#             rownum=3,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='ID',
#             rownum=4,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='ID',
#             rownum=5,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='ID',
#             rownum=6,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='ID',
#             rownum=7,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='ID',
#             rownum=8,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='ID',
#             rownum=9,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_MOD_W',
#             rownum=0,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_MOD_W',
#             rownum=1,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_MOD_W',
#             rownum=2,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_MOD_W',
#             rownum=3,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_MOD_W',
#             rownum=4,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_MOD_W',
#             rownum=5,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_MOD_W',
#             rownum=6,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_MOD_W',
#             rownum=7,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_MOD_W',
#             rownum=8,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_MOD_W',
#             rownum=9,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_MOD_HPD',
#             rownum=0,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_MOD_HPD',
#             rownum=1,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_MOD_HPD',
#             rownum=2,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_MOD_HPD',
#             rownum=3,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_MOD_HPD',
#             rownum=4,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_MOD_HPD',
#             rownum=5,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_MOD_HPD',
#             rownum=6,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_MOD_HPD',
#             rownum=7,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_MOD_HPD',
#             rownum=8,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_MOD_HPD',
#             rownum=9,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_MOD_MPD',
#             rownum=0,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_MOD_MPD',
#             rownum=1,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_MOD_MPD',
#             rownum=2,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_MOD_MPD',
#             rownum=3,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_MOD_MPD',
#             rownum=4,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_MOD_MPD',
#             rownum=5,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_MOD_MPD',
#             rownum=6,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_MOD_MPD',
#             rownum=7,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_MOD_MPD',
#             rownum=8,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_MOD_MPD',
#             rownum=9,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_MOD_D',
#             rownum=0,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_MOD_D',
#             rownum=1,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_MOD_D',
#             rownum=2,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_MOD_D',
#             rownum=3,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_MOD_D',
#             rownum=4,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_MOD_D',
#             rownum=5,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_MOD_D',
#             rownum=6,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_MOD_D',
#             rownum=7,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_MOD_D',
#             rownum=8,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_MOD_D',
#             rownum=9,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_MOD_MINS',
#             rownum=0,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_MOD_MINS',
#             rownum=1,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_MOD_MINS',
#             rownum=2,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_MOD_MINS',
#             rownum=3,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_MOD_MINS',
#             rownum=4,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_MOD_MINS',
#             rownum=5,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_MOD_MINS',
#             rownum=6,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_MOD_MINS',
#             rownum=7,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_MOD_MINS',
#             rownum=8,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_MOD_MINS',
#             rownum=9,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_MOD_MET',
#             rownum=0,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_MOD_MET',
#             rownum=1,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_MOD_MET',
#             rownum=2,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_MOD_MET',
#             rownum=3,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_MOD_MET',
#             rownum=4,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_MOD_MET',
#             rownum=5,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_MOD_MET',
#             rownum=6,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_MOD_MET',
#             rownum=7,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_MOD_MET',
#             rownum=8,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_MOD_MET',
#             rownum=9,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='_row_num_',
#             rownum=0,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='_row_num_',
#             rownum=1,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='_row_num_',
#             rownum=2,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='_row_num_',
#             rownum=3,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='_row_num_',
#             rownum=4,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='_row_num_',
#             rownum=5,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='_row_num_',
#             rownum=6,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='_row_num_',
#             rownum=7,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='_row_num_',
#             rownum=8,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='_row_num_',
#             rownum=9,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='ID',
#             rownum=0,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='ID',
#             rownum=1,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='ID',
#             rownum=2,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='ID',
#             rownum=3,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='ID',
#             rownum=4,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='ID',
#             rownum=5,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='ID',
#             rownum=6,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='ID',
#             rownum=7,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='ID',
#             rownum=8,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='ID',
#             rownum=9,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_MOD_W',
#             rownum=0,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_MOD_W',
#             rownum=1,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_MOD_W',
#             rownum=2,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_MOD_W',
#             rownum=3,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_MOD_W',
#             rownum=4,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_MOD_W',
#             rownum=5,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_MOD_W',
#             rownum=6,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_MOD_W',
#             rownum=7,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_MOD_W',
#             rownum=8,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_MOD_W',
#             rownum=9,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_MOD_HPD',
#             rownum=0,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_MOD_HPD',
#             rownum=1,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_MOD_HPD',
#             rownum=2,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_MOD_HPD',
#             rownum=3,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_MOD_HPD',
#             rownum=4,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_MOD_HPD',
#             rownum=5,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_MOD_HPD',
#             rownum=6,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
# ...
#                 CellStyleFill(color='#FFC1C159'),
#                 CellStyleBorders(sides=['left', 'right'], color='black', style='solid', weight='2px')
#             ]
#         ),
#         StyleInfo(
#             locname=LocBody(columns='G227_IPAQ_MOD_HPD', rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_MOD_HPD',
#             rownum=9,
#             colnum=None,
#             styles=[
#                 CellStyleText(color='#B22222', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None),
#                 CellStyleFill(color='#FFC1C159'),
#                 CellStyleBorders(sides=['left', 'right'], color='black', style='solid', weight='2px')
#             ]
#         ),
#         StyleInfo(
#             locname=LocColumnLabels(columns='G227_IPAQ_MOD_HPD'),
#             grpname=None,
#             colname='G227_IPAQ_MOD_HPD',
#             rownum=None,
#             colnum=None,
#             styles=[CellStyleBorders(sides=['left', 'right'], color='black', style='solid', weight='2px')]
#         )
#     ],
#     _locale=<great_tables._gt_data.Locale object at 0x00000175FFDA79D0>,
#     _formats=[<great_tables._gt_data.FormatInfo object at 0x00000175FE8535F0>],
#     _substitutions=[],
#     _options=Options(
#         table_id=OptionsInfo(scss=True, category='table', type='value', value='pb_preview_tbl'),
#         table_caption=OptionsInfo(scss=False, category='table', type='value', value=None),
#         table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'),
#         table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'),
#         table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'),
#         table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'),
#         table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'),
#         table_additional_css=OptionsInfo(
#             scss=False,
#             category='table',
#             type='values',
#             value=[
#                 "@import url('https://fonts.googleapis.com/css2?family=IBM+Plex+Sans&display=swap');",
#                 "@import url('https://fonts.googleapis.com/css2?family=IBM+Plex+Mono&display=swap');",
#                 "@import url('https://fonts.googleapis.com/css2?family=IBM+Plex+Mono&display=swap');",
#                 "@import url('https://fonts.googleapis.com/css2?family=IBM+Plex+Mono&display=swap');"
#             ]
#         ),
#         table_font_names=OptionsInfo(
#             scss=False,
#             category='table',
#             type='values',
#             value=['IBM Plex Sans', '-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']
#         ),
#         table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'),
#         table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'),
#         table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'),
#         table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'),
#         table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'),
#         table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True),
#         table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'),
#         table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'),
#         table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'),
#         table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'),
#         table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'),
#         table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'),
#         table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True),
#         table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'),
#         table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'),
#         table_border_bottom_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'),
#         table_border_left_style=OptionsInfo(scss=True, category='table', type='value', value='none'),
#         table_border_left_width=OptionsInfo(scss=True, category='table', type='px', value='2px'),
#         table_border_left_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'),
#         heading_background_color=OptionsInfo(scss=True, category='heading', type='value', value=None),
#         heading_align=OptionsInfo(scss=True, category='heading', type='value', value='left'),
#         heading_title_font_size=OptionsInfo(scss=True, category='heading', type='px', value='125%'),
#         heading_title_font_weight=OptionsInfo(scss=True, category='heading', type='value', value='initial'),
#         heading_subtitle_font_size=OptionsInfo(scss=True, category='heading', type='px', value='85%'),
#         heading_subtitle_font_weight=OptionsInfo(scss=True, category='heading', type='value', value='initial'),
#         heading_padding=OptionsInfo(scss=True, category='heading', type='px', value='4px'),
#         heading_padding_horizontal=OptionsInfo(scss=True, category='heading', type='px', value='5px'),
#         heading_border_bottom_style=OptionsInfo(scss=True, category='heading', type='value', value='solid'),
#         heading_border_bottom_width=OptionsInfo(scss=True, category='heading', type='px', value='2px'),
#         heading_border_bottom_color=OptionsInfo(scss=True, category='heading', type='value', value='#D3D3D3'),
#         heading_border_lr_style=OptionsInfo(scss=True, category='heading', type='value', value='none'),
#         heading_border_lr_width=OptionsInfo(scss=True, category='heading', type='px', value='1px'),
#         heading_border_lr_color=OptionsInfo(scss=True, category='heading', type='value', value='#D3D3D3'),
#         column_labels_background_color=OptionsInfo(scss=True, category='column_labels', type='value', value=None),
#         column_labels_font_size=OptionsInfo(scss=True, category='column_labels', type='px', value='100%'),
#         column_labels_font_weight=OptionsInfo(scss=True, category='column_labels', type='value', value='normal'),
#         column_labels_text_transform=OptionsInfo(scss=True, category='column_labels', type='value', value='inherit'),
#         column_labels_padding=OptionsInfo(scss=True, category='column_labels', type='px', value='5px'),
#         column_labels_padding_horizontal=OptionsInfo(scss=True, category='column_labels', type='px', value='5px'),
#         column_labels_vlines_style=OptionsInfo(scss=True, category='table_body', type='value', value='solid'),
#         column_labels_vlines_width=OptionsInfo(scss=True, category='table_body', type='px', value='1px'),
#         column_labels_vlines_color=OptionsInfo(scss=True, category='table_body', type='value', value='#F2F2F2'),
#         column_labels_border_top_style=OptionsInfo(scss=True, category='column_labels', type='value', value='solid'),
#         column_labels_border_top_width=OptionsInfo(scss=True, category='column_labels', type='px', value='2px'),
#         column_labels_border_top_color=OptionsInfo(scss=True, category='column_labels', type='value', value='#D3D3D3'),
#         column_labels_border_bottom_style=OptionsInfo(scss=True, category='column_labels', type='value', value='solid'),
#         column_labels_border_bottom_width=OptionsInfo(scss=True, category='column_labels', type='px', value='2px'),
#         column_labels_border_bottom_color=OptionsInfo(scss=True, category='column_labels', type='value', value='#D3D3D3'),
#         column_labels_border_lr_style=OptionsInfo(scss=True, category='column_labels', type='value', value='none'),
#         column_labels_border_lr_width=OptionsInfo(scss=True, category='column_labels', type='px', value='1px'),
#         column_labels_border_lr_color=OptionsInfo(scss=True, category='column_labels', type='value', value='#D3D3D3'),
#         column_labels_hidden=OptionsInfo(scss=False, category='column_labels', type='boolean', value=False),
#         row_group_background_color=OptionsInfo(scss=True, category='row_group', type='value', value=None),
#         row_group_font_size=OptionsInfo(scss=True, category='row_group', type='px', value='100%'),
#         row_group_font_weight=OptionsInfo(scss=True, category='row_group', type='value', value='initial'),
#         row_group_text_transform=OptionsInfo(scss=True, category='row_group', type='value', value='inherit'),
#         row_group_padding=OptionsInfo(scss=True, category='row_group', type='px', value='8px'),
#         row_group_padding_horizontal=OptionsInfo(scss=True, category='row_group', type='px', value='5px'),
#         row_group_border_top_style=OptionsInfo(scss=True, category='row_group', type='value', value='solid'),
#         row_group_border_top_width=OptionsInfo(scss=True, category='row_group', type='px', value='2px'),
#         row_group_border_top_color=OptionsInfo(scss=True, category='row_group', type='value', value='#D3D3D3'),
#         row_group_border_right_style=OptionsInfo(scss=True, category='row_group', type='value', value='none'),
#         row_group_border_right_width=OptionsInfo(scss=True, category='row_group', type='px', value='1px'),
#         row_group_border_right_color=OptionsInfo(scss=True, category='row_group', type='value', value='#D3D3D3'),
#         row_group_border_bottom_style=OptionsInfo(scss=True, category='row_group', type='value', value='solid'),
#         row_group_border_bottom_width=OptionsInfo(scss=True, category='row_group', type='px', value='2px'),
#         row_group_border_bottom_color=OptionsInfo(scss=True, category='row_group', type='value', value='#D3D3D3'),
#         row_group_border_left_style=OptionsInfo(scss=True, category='row_group', type='value', value='none'),
#         row_group_border_left_width=OptionsInfo(scss=True, category='row_group', type='px', value='1px'),
#         row_group_border_left_color=OptionsInfo(scss=True, category='row_group', type='value', value='#D3D3D3'),
#         row_group_as_column=OptionsInfo(scss=False, category='row_group', type='boolean', value=False),
#         table_body_hlines_style=OptionsInfo(scss=True, category='table_body', type='value', value='solid'),
#         table_body_hlines_width=OptionsInfo(scss=True, category='table_body', type='px', value='1px'),
#         table_body_hlines_color=OptionsInfo(scss=True, category='table_body', type='value', value='#D3D3D3'),
#         table_body_vlines_style=OptionsInfo(scss=True, category='table_body', type='value', value='solid'),
#         table_body_vlines_width=OptionsInfo(scss=True, category='table_body', type='px', value='1px'),
#         table_body_vlines_color=OptionsInfo(scss=True, category='table_body', type='value', value='#E9E9E9'),
#         table_body_border_top_style=OptionsInfo(scss=True, category='table_body', type='value', value='solid'),
#         table_body_border_top_width=OptionsInfo(scss=True, category='table_body', type='px', value='2px'),
#         table_body_border_top_color=OptionsInfo(scss=True, category='table_body', type='value', value='#D3D3D3'),
#         table_body_border_bottom_style=OptionsInfo(scss=True, category='table_body', type='value', value='solid'),
#         table_body_border_bottom_width=OptionsInfo(scss=True, category='table_body', type='px', value='2px'),
#         table_body_border_bottom_color=OptionsInfo(scss=True, category='table_body', type='value', value='#D3D3D3'),
#         data_row_padding=OptionsInfo(scss=True, category='data_row', type='px', value='8px'),
#         data_row_padding_horizontal=OptionsInfo(scss=True, category='data_row', type='px', value='5px'),
#         stub_background_color=OptionsInfo(scss=True, category='stub', type='value', value=None),
#         stub_font_size=OptionsInfo(scss=True, category='stub', type='px', value='100%'),
#         stub_font_weight=OptionsInfo(scss=True, category='stub', type='value', value='initial'),
#         stub_text_transform=OptionsInfo(scss=True, category='stub', type='value', value='inherit'),
#         stub_border_style=OptionsInfo(scss=True, category='stub', type='value', value='solid'),
#         stub_border_width=OptionsInfo(scss=True, category='stub', type='px', value='2px'),
#         stub_border_color=OptionsInfo(scss=True, category='stub', type='value', value='#D3D3D3'),
#         stub_row_group_background_color=OptionsInfo(scss=True, category='stub', type='value', value=None),
#         stub_row_group_font_size=OptionsInfo(scss=True, category='stub', type='px', value='100%'),
#         stub_row_group_font_weight=OptionsInfo(scss=True, category='stub', type='value', value='initial'),
#         stub_row_group_text_transform=OptionsInfo(scss=True, category='stub', type='value', value='inherit'),
#         stub_row_group_border_style=OptionsInfo(scss=True, category='stub', type='value', value='solid'),
#         stub_row_group_border_width=OptionsInfo(scss=True, category='stub', type='px', value='2px'),
#         stub_row_group_border_color=OptionsInfo(scss=True, category='stub', type='value', value='#D3D3D3'),
#         source_notes_padding=OptionsInfo(scss=True, category='source_notes', type='px', value='4px'),
#         source_notes_padding_horizontal=OptionsInfo(scss=True, category='source_notes', type='px', value='5px'),
#         source_notes_background_color=OptionsInfo(scss=True, category='source_notes', type='value', value=None),
#         source_notes_font_size=OptionsInfo(scss=True, category='source_notes', type='px', value='90%'),
#         source_notes_border_bottom_style=OptionsInfo(scss=True, category='source_notes', type='value', value='none'),
#         source_notes_border_bottom_width=OptionsInfo(scss=True, category='source_notes', type='px', value='2px'),
#         source_notes_border_bottom_color=OptionsInfo(scss=True, category='source_notes', type='value', value='#D3D3D3'),
#         source_notes_border_lr_style=OptionsInfo(scss=True, category='source_notes', type='value', value='none'),
#         source_notes_border_lr_width=OptionsInfo(scss=True, category='source_notes', type='px', value='2px'),
#         source_notes_border_lr_color=OptionsInfo(scss=True, category='source_notes', type='value', value='#D3D3D3'),
#         source_notes_multiline=OptionsInfo(scss=False, category='source_notes', type='boolean', value=True),
#         source_notes_sep=OptionsInfo(scss=False, category='source_notes', type='value', value=' '),
#         row_striping_background_color=OptionsInfo(scss=True, category='row', type='value', value='rgba(128,128,128,0.05)'),
#         row_striping_include_stub=OptionsInfo(scss=False, category='row', type='boolean', value=False),
#         row_striping_include_table_body=OptionsInfo(scss=False, category='row', type='boolean', value=False),
#         container_width=OptionsInfo(scss=False, category='container', type='px', value='auto'),
#         container_height=OptionsInfo(scss=False, category='container', type='px', value='auto'),
#         container_padding_x=OptionsInfo(scss=False, category='container', type='px', value='0px'),
#         container_padding_y=OptionsInfo(scss=False, category='container', type='px', value='10px'),
#         container_overflow_x=OptionsInfo(scss=False, category='container', type='overflow', value='auto'),
#         container_overflow_y=OptionsInfo(scss=False, category='container', type='overflow', value='auto'),
#         quarto_disable_processing=OptionsInfo(scss=False, category='quarto', type='logical', value=True),
#         quarto_use_bootstrap=OptionsInfo(scss=False, category='quarto', type='logical', value=False)
#     ),
#     _has_built=False
# )

# %%
harmonised_validation.get_step_report(i=24, columns_subset=pb.matches(r"ID|MOD"))
# Out:
# GT(
#     _tbl_data=shape: (8, 8)
# ┌───────────┬─────────┬────────────┬────────────┬────────────┬────────────┬────────────┬───────────┐
# │ _row_num_ ┆ ID      ┆ G227_IPAQ_ ┆ G227_IPAQ_ ┆ G227_IPAQ_ ┆ G227_IPAQ_ ┆ G227_IPAQ_ ┆ G227_IPAQ │
# │ ---       ┆ ---     ┆ MOD_W      ┆ MOD_HPD    ┆ MOD_MPD    ┆ MOD_D      ┆ MOD_MINS   ┆ _MOD_MET  │
# │ u32       ┆ f64     ┆ ---        ┆ ---        ┆ ---        ┆ ---        ┆ ---        ┆ ---       │
# │           ┆         ┆ f64        ┆ f64        ┆ f64        ┆ f64        ┆ f64        ┆ f64       │
# ╞═══════════╪═════════╪════════════╪════════════╪════════════╪════════════╪════════════╪═══════════╡
# │ 195       ┆ 17650.0 ┆ 1.0        ┆ null       ┆ 60.0       ┆ 3.0        ┆ 60.0       ┆ 720.0     │
# │ 227       ┆ 18810.0 ┆ 1.0        ┆ null       ┆ 60.0       ┆ 1.0        ┆ 60.0       ┆ 240.0     │
# │ 316       ┆ 22260.0 ┆ 1.0        ┆ null       ┆ 180.0      ┆ 5.0        ┆ 180.0      ┆ 3600.0    │
# │ 486       ┆ 44190.0 ┆ 1.0        ┆ null       ┆ 60.0       ┆ 5.0        ┆ 60.0       ┆ 1200.0    │
# │ 509       ┆ 44810.0 ┆ 1.0        ┆ 1.0        ┆ 60.0       ┆ 4.0        ┆ 120.0      ┆ 1920.0    │
# │ 593       ┆ 47980.0 ┆ 1.0        ┆ null       ┆ 60.0       ┆ 2.0        ┆ 60.0       ┆ 480.0     │
# │ 642       ┆ 49820.0 ┆ 1.0        ┆ 3.0        ┆ 180.0      ┆ 3.0        ┆ 180.0      ┆ 2160.0    │
# │ 681       ┆ 51210.0 ┆ 1.0        ┆ null       ┆ 60.0       ┆ 4.0        ┆ 60.0       ┆ 960.0     │
# └───────────┴─────────┴────────────┴────────────┴────────────┴────────────┴────────────┴───────────┘,
#     _body=<great_tables._gt_data.Body object at 0x00000175FFD94230>,
#     _boxhead=Boxhead([ColInfo(var='_row_num_', type=<ColInfoTypeEnum.default: 1>, column_label='', column_align='right', column_width='33.4px'), ColInfo(var='ID', type=<ColInfoTypeEnum.default: 1>, column_label=Html(text="<div><div style='white-space: nowrap; text-overflow: ellipsis; overflow: hidden; padding-bottom: 2px; margin-bottom: 2px;'>ID</div><div style='white-space: nowrap; text-overflow: ellipsis; overflow: hidden; padding-top: 2px; margin-top: 2px;'><em>Float64</em></div></div>"), column_align='right', column_width='65px'), ColInfo(var='G227_IPAQ_MOD_W', type=<ColInfoTypeEnum.default: 1>, column_label=Html(text="<div><div style='white-space: nowrap; text-overflow: ellipsis; overflow: hidden; padding-bottom: 2px; margin-bottom: 2px;'>G227_IPAQ_MOD_W</div><div style='white-space: nowrap; text-overflow: ellipsis; overflow: hidden; padding-top: 2px; margin-top: 2px;'><em>Float64</em></div></div>"), column_align='right', column_width='127px'), ColInfo(var='G227_IPAQ_MOD_HPD', type=<ColInfoTypeEnum.default: 1>, column_label=Html(text="<div><div style='white-space: nowrap; text-overflow: ellipsis; overflow: hidden; padding-bottom: 2px; margin-bottom: 2px;'>G227_IPAQ_MOD_HPD</div><div style='white-space: nowrap; text-overflow: ellipsis; overflow: hidden; padding-top: 2px; margin-top: 2px;'><em>Float64</em></div></div>"), column_align='right', column_width='143px'), ColInfo(var='G227_IPAQ_MOD_MPD', type=<ColInfoTypeEnum.default: 1>, column_label=Html(text="<div><div style='white-space: nowrap; text-overflow: ellipsis; overflow: hidden; padding-bottom: 2px; margin-bottom: 2px;'>G227_IPAQ_MOD_MPD</div><div style='white-space: nowrap; text-overflow: ellipsis; overflow: hidden; padding-top: 2px; margin-top: 2px;'><em>Float64</em></div></div>"), column_align='right', column_width='143px'), ColInfo(var='G227_IPAQ_MOD_D', type=<ColInfoTypeEnum.default: 1>, column_label=Html(text="<div><div style='white-space: nowrap; text-overflow: ellipsis; overflow: hidden; padding-bottom: 2px; margin-bottom: 2px;'>G227_IPAQ_MOD_D</div><div style='white-space: nowrap; text-overflow: ellipsis; overflow: hidden; padding-top: 2px; margin-top: 2px;'><em>Float64</em></div></div>"), column_align='right', column_width='127px'), ColInfo(var='G227_IPAQ_MOD_MINS', type=<ColInfoTypeEnum.default: 1>, column_label=Html(text="<div><div style='white-space: nowrap; text-overflow: ellipsis; overflow: hidden; padding-bottom: 2px; margin-bottom: 2px;'>G227_IPAQ_MOD_MINS</div><div style='white-space: nowrap; text-overflow: ellipsis; overflow: hidden; padding-top: 2px; margin-top: 2px;'><em>Float64</em></div></div>"), column_align='right', column_width='150px'), ColInfo(var='G227_IPAQ_MOD_MET', type=<ColInfoTypeEnum.default: 1>, column_label=Html(text="<div><div style='white-space: nowrap; text-overflow: ellipsis; overflow: hidden; padding-bottom: 2px; margin-bottom: 2px;'>G227_IPAQ_MOD_MET</div><div style='white-space: nowrap; text-overflow: ellipsis; overflow: hidden; padding-top: 2px; margin-top: 2px;'><em>Float64</em></div></div>"), column_align='right', column_width='143px')]),
#     _stub=<great_tables._gt_data.Stub object at 0x00000175FE9ADF70>,
#     _spanners=Spanners([]),
#     _heading=Heading(
#         title=Md(
#             text="<p>Report for Validation Step 24<div style='font-size: 13.6px; '><div style='padding-top: 7px;'>ASSERTION <span style='border-style: solid; border-width: thin; border-color: lightblue; padding-left: 2px; padding-right: 2px;'><code style='color: #303030; background-color: transparent; position: relative; bottom: 1px;'><code style='color: #303030; font-family: monospace; font-size: smaller;'>0 &le; G227_IPAQ_MOD_MPD &le; 59</code></code></span></div><div style='padding-top: 7px;'><strong>8</strong> / <strong>765</strong> TEST UNIT FAILURES IN COLUMN <strong>9</strong> </div><div>EXTRACT OF ALL <strong>8</strong> ROWS (WITH <span style='color: #B22222;'>TEST UNIT FAILURES IN RED</span>):</div></div></p>\n"
#         ),
#         subtitle=None,
#         preheader=None
#     ),
#     _stubhead=None,
#     _source_notes=[],
#     _footnotes=[],
#     _styles=[
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='_row_num_',
#             rownum=0,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='_row_num_',
#             rownum=1,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='_row_num_',
#             rownum=2,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='_row_num_',
#             rownum=3,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='_row_num_',
#             rownum=4,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='_row_num_',
#             rownum=5,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='_row_num_',
#             rownum=6,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='_row_num_',
#             rownum=7,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='ID',
#             rownum=0,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='ID',
#             rownum=1,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='ID',
#             rownum=2,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='ID',
#             rownum=3,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='ID',
#             rownum=4,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='ID',
#             rownum=5,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='ID',
#             rownum=6,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='ID',
#             rownum=7,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_MOD_W',
#             rownum=0,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_MOD_W',
#             rownum=1,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_MOD_W',
#             rownum=2,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_MOD_W',
#             rownum=3,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_MOD_W',
#             rownum=4,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_MOD_W',
#             rownum=5,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_MOD_W',
#             rownum=6,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_MOD_W',
#             rownum=7,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_MOD_HPD',
#             rownum=0,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_MOD_HPD',
#             rownum=1,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_MOD_HPD',
#             rownum=2,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_MOD_HPD',
#             rownum=3,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_MOD_HPD',
#             rownum=4,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_MOD_HPD',
#             rownum=5,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_MOD_HPD',
#             rownum=6,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_MOD_HPD',
#             rownum=7,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_MOD_MPD',
#             rownum=0,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_MOD_MPD',
#             rownum=1,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_MOD_MPD',
#             rownum=2,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_MOD_MPD',
#             rownum=3,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_MOD_MPD',
#             rownum=4,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_MOD_MPD',
#             rownum=5,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_MOD_MPD',
#             rownum=6,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_MOD_MPD',
#             rownum=7,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_MOD_D',
#             rownum=0,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_MOD_D',
#             rownum=1,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_MOD_D',
#             rownum=2,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_MOD_D',
#             rownum=3,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_MOD_D',
#             rownum=4,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_MOD_D',
#             rownum=5,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_MOD_D',
#             rownum=6,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_MOD_D',
#             rownum=7,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_MOD_MINS',
#             rownum=0,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_MOD_MINS',
#             rownum=1,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_MOD_MINS',
#             rownum=2,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_MOD_MINS',
#             rownum=3,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_MOD_MINS',
#             rownum=4,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_MOD_MINS',
#             rownum=5,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_MOD_MINS',
#             rownum=6,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_MOD_MINS',
#             rownum=7,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_MOD_MET',
#             rownum=0,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_MOD_MET',
#             rownum=1,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_MOD_MET',
#             rownum=2,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_MOD_MET',
#             rownum=3,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_MOD_MET',
#             rownum=4,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_MOD_MET',
#             rownum=5,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_MOD_MET',
#             rownum=6,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_MOD_MET',
#             rownum=7,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='_row_num_',
#             rownum=0,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='_row_num_',
#             rownum=1,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='_row_num_',
#             rownum=2,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='_row_num_',
#             rownum=3,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='_row_num_',
#             rownum=4,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='_row_num_',
#             rownum=5,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='_row_num_',
#             rownum=6,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='_row_num_',
#             rownum=7,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='ID',
#             rownum=0,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='ID',
#             rownum=1,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='ID',
#             rownum=2,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='ID',
#             rownum=3,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='ID',
#             rownum=4,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='ID',
#             rownum=5,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='ID',
#             rownum=6,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='ID',
#             rownum=7,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_MOD_W',
#             rownum=0,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_MOD_W',
#             rownum=1,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_MOD_W',
#             rownum=2,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_MOD_W',
#             rownum=3,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_MOD_W',
#             rownum=4,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_MOD_W',
#             rownum=5,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_MOD_W',
#             rownum=6,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_MOD_W',
#             rownum=7,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_MOD_HPD',
#             rownum=0,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_MOD_HPD',
#             rownum=1,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_MOD_HPD',
#             rownum=2,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_MOD_HPD',
#             rownum=3,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_MOD_HPD',
#             rownum=4,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_MOD_HPD',
#             rownum=5,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_MOD_HPD',
#             rownum=6,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_MOD_HPD',
#             rownum=7,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_MOD_MPD',
#             rownum=0,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_MOD_MPD',
#             rownum=1,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_MOD_MPD',
#             rownum=2,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_MOD_MPD',
#             rownum=3,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_MOD_MPD',
#             rownum=4,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_MOD_MPD',
#             rownum=5,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_MOD_MPD',
#             rownum=6,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_MOD_MPD',
#             rownum=7,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_MOD_D',
#             rownum=0,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_MOD_D',
#             rownum=1,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_MOD_D',
#             rownum=2,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_MOD_D',
#             rownum=3,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_MOD_D',
#             rownum=4,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_MOD_D',
#             rownum=5,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_MOD_D',
#             rownum=6,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_MOD_D',
#             rownum=7,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_MOD_MINS',
#             rownum=0,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_MOD_MINS',
#             rownum=1,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_MOD_MINS',
#             rownum=2,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
# ...
#                 CellStyleFill(color='#FFC1C159'),
#                 CellStyleBorders(sides=['left', 'right'], color='black', style='solid', weight='2px')
#             ]
#         ),
#         StyleInfo(
#             locname=LocBody(columns='G227_IPAQ_MOD_MPD', rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_MOD_MPD',
#             rownum=7,
#             colnum=None,
#             styles=[
#                 CellStyleText(color='#B22222', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None),
#                 CellStyleFill(color='#FFC1C159'),
#                 CellStyleBorders(sides=['left', 'right'], color='black', style='solid', weight='2px')
#             ]
#         ),
#         StyleInfo(
#             locname=LocColumnLabels(columns='G227_IPAQ_MOD_MPD'),
#             grpname=None,
#             colname='G227_IPAQ_MOD_MPD',
#             rownum=None,
#             colnum=None,
#             styles=[CellStyleBorders(sides=['left', 'right'], color='black', style='solid', weight='2px')]
#         )
#     ],
#     _locale=<great_tables._gt_data.Locale object at 0x00000175FFF57D90>,
#     _formats=[<great_tables._gt_data.FormatInfo object at 0x00000175FD5ECEF0>],
#     _substitutions=[],
#     _options=Options(
#         table_id=OptionsInfo(scss=True, category='table', type='value', value='pb_preview_tbl'),
#         table_caption=OptionsInfo(scss=False, category='table', type='value', value=None),
#         table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'),
#         table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'),
#         table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'),
#         table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'),
#         table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'),
#         table_additional_css=OptionsInfo(
#             scss=False,
#             category='table',
#             type='values',
#             value=[
#                 "@import url('https://fonts.googleapis.com/css2?family=IBM+Plex+Sans&display=swap');",
#                 "@import url('https://fonts.googleapis.com/css2?family=IBM+Plex+Mono&display=swap');",
#                 "@import url('https://fonts.googleapis.com/css2?family=IBM+Plex+Mono&display=swap');",
#                 "@import url('https://fonts.googleapis.com/css2?family=IBM+Plex+Mono&display=swap');"
#             ]
#         ),
#         table_font_names=OptionsInfo(
#             scss=False,
#             category='table',
#             type='values',
#             value=['IBM Plex Sans', '-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']
#         ),
#         table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'),
#         table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'),
#         table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'),
#         table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'),
#         table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'),
#         table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True),
#         table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'),
#         table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'),
#         table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'),
#         table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'),
#         table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'),
#         table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'),
#         table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True),
#         table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'),
#         table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'),
#         table_border_bottom_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'),
#         table_border_left_style=OptionsInfo(scss=True, category='table', type='value', value='none'),
#         table_border_left_width=OptionsInfo(scss=True, category='table', type='px', value='2px'),
#         table_border_left_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'),
#         heading_background_color=OptionsInfo(scss=True, category='heading', type='value', value=None),
#         heading_align=OptionsInfo(scss=True, category='heading', type='value', value='left'),
#         heading_title_font_size=OptionsInfo(scss=True, category='heading', type='px', value='125%'),
#         heading_title_font_weight=OptionsInfo(scss=True, category='heading', type='value', value='initial'),
#         heading_subtitle_font_size=OptionsInfo(scss=True, category='heading', type='px', value='85%'),
#         heading_subtitle_font_weight=OptionsInfo(scss=True, category='heading', type='value', value='initial'),
#         heading_padding=OptionsInfo(scss=True, category='heading', type='px', value='4px'),
#         heading_padding_horizontal=OptionsInfo(scss=True, category='heading', type='px', value='5px'),
#         heading_border_bottom_style=OptionsInfo(scss=True, category='heading', type='value', value='solid'),
#         heading_border_bottom_width=OptionsInfo(scss=True, category='heading', type='px', value='2px'),
#         heading_border_bottom_color=OptionsInfo(scss=True, category='heading', type='value', value='#D3D3D3'),
#         heading_border_lr_style=OptionsInfo(scss=True, category='heading', type='value', value='none'),
#         heading_border_lr_width=OptionsInfo(scss=True, category='heading', type='px', value='1px'),
#         heading_border_lr_color=OptionsInfo(scss=True, category='heading', type='value', value='#D3D3D3'),
#         column_labels_background_color=OptionsInfo(scss=True, category='column_labels', type='value', value=None),
#         column_labels_font_size=OptionsInfo(scss=True, category='column_labels', type='px', value='100%'),
#         column_labels_font_weight=OptionsInfo(scss=True, category='column_labels', type='value', value='normal'),
#         column_labels_text_transform=OptionsInfo(scss=True, category='column_labels', type='value', value='inherit'),
#         column_labels_padding=OptionsInfo(scss=True, category='column_labels', type='px', value='5px'),
#         column_labels_padding_horizontal=OptionsInfo(scss=True, category='column_labels', type='px', value='5px'),
#         column_labels_vlines_style=OptionsInfo(scss=True, category='table_body', type='value', value='solid'),
#         column_labels_vlines_width=OptionsInfo(scss=True, category='table_body', type='px', value='1px'),
#         column_labels_vlines_color=OptionsInfo(scss=True, category='table_body', type='value', value='#F2F2F2'),
#         column_labels_border_top_style=OptionsInfo(scss=True, category='column_labels', type='value', value='solid'),
#         column_labels_border_top_width=OptionsInfo(scss=True, category='column_labels', type='px', value='2px'),
#         column_labels_border_top_color=OptionsInfo(scss=True, category='column_labels', type='value', value='#D3D3D3'),
#         column_labels_border_bottom_style=OptionsInfo(scss=True, category='column_labels', type='value', value='solid'),
#         column_labels_border_bottom_width=OptionsInfo(scss=True, category='column_labels', type='px', value='2px'),
#         column_labels_border_bottom_color=OptionsInfo(scss=True, category='column_labels', type='value', value='#D3D3D3'),
#         column_labels_border_lr_style=OptionsInfo(scss=True, category='column_labels', type='value', value='none'),
#         column_labels_border_lr_width=OptionsInfo(scss=True, category='column_labels', type='px', value='1px'),
#         column_labels_border_lr_color=OptionsInfo(scss=True, category='column_labels', type='value', value='#D3D3D3'),
#         column_labels_hidden=OptionsInfo(scss=False, category='column_labels', type='boolean', value=False),
#         row_group_background_color=OptionsInfo(scss=True, category='row_group', type='value', value=None),
#         row_group_font_size=OptionsInfo(scss=True, category='row_group', type='px', value='100%'),
#         row_group_font_weight=OptionsInfo(scss=True, category='row_group', type='value', value='initial'),
#         row_group_text_transform=OptionsInfo(scss=True, category='row_group', type='value', value='inherit'),
#         row_group_padding=OptionsInfo(scss=True, category='row_group', type='px', value='8px'),
#         row_group_padding_horizontal=OptionsInfo(scss=True, category='row_group', type='px', value='5px'),
#         row_group_border_top_style=OptionsInfo(scss=True, category='row_group', type='value', value='solid'),
#         row_group_border_top_width=OptionsInfo(scss=True, category='row_group', type='px', value='2px'),
#         row_group_border_top_color=OptionsInfo(scss=True, category='row_group', type='value', value='#D3D3D3'),
#         row_group_border_right_style=OptionsInfo(scss=True, category='row_group', type='value', value='none'),
#         row_group_border_right_width=OptionsInfo(scss=True, category='row_group', type='px', value='1px'),
#         row_group_border_right_color=OptionsInfo(scss=True, category='row_group', type='value', value='#D3D3D3'),
#         row_group_border_bottom_style=OptionsInfo(scss=True, category='row_group', type='value', value='solid'),
#         row_group_border_bottom_width=OptionsInfo(scss=True, category='row_group', type='px', value='2px'),
#         row_group_border_bottom_color=OptionsInfo(scss=True, category='row_group', type='value', value='#D3D3D3'),
#         row_group_border_left_style=OptionsInfo(scss=True, category='row_group', type='value', value='none'),
#         row_group_border_left_width=OptionsInfo(scss=True, category='row_group', type='px', value='1px'),
#         row_group_border_left_color=OptionsInfo(scss=True, category='row_group', type='value', value='#D3D3D3'),
#         row_group_as_column=OptionsInfo(scss=False, category='row_group', type='boolean', value=False),
#         table_body_hlines_style=OptionsInfo(scss=True, category='table_body', type='value', value='solid'),
#         table_body_hlines_width=OptionsInfo(scss=True, category='table_body', type='px', value='1px'),
#         table_body_hlines_color=OptionsInfo(scss=True, category='table_body', type='value', value='#D3D3D3'),
#         table_body_vlines_style=OptionsInfo(scss=True, category='table_body', type='value', value='solid'),
#         table_body_vlines_width=OptionsInfo(scss=True, category='table_body', type='px', value='1px'),
#         table_body_vlines_color=OptionsInfo(scss=True, category='table_body', type='value', value='#E9E9E9'),
#         table_body_border_top_style=OptionsInfo(scss=True, category='table_body', type='value', value='solid'),
#         table_body_border_top_width=OptionsInfo(scss=True, category='table_body', type='px', value='2px'),
#         table_body_border_top_color=OptionsInfo(scss=True, category='table_body', type='value', value='#D3D3D3'),
#         table_body_border_bottom_style=OptionsInfo(scss=True, category='table_body', type='value', value='solid'),
#         table_body_border_bottom_width=OptionsInfo(scss=True, category='table_body', type='px', value='2px'),
#         table_body_border_bottom_color=OptionsInfo(scss=True, category='table_body', type='value', value='#D3D3D3'),
#         data_row_padding=OptionsInfo(scss=True, category='data_row', type='px', value='8px'),
#         data_row_padding_horizontal=OptionsInfo(scss=True, category='data_row', type='px', value='5px'),
#         stub_background_color=OptionsInfo(scss=True, category='stub', type='value', value=None),
#         stub_font_size=OptionsInfo(scss=True, category='stub', type='px', value='100%'),
#         stub_font_weight=OptionsInfo(scss=True, category='stub', type='value', value='initial'),
#         stub_text_transform=OptionsInfo(scss=True, category='stub', type='value', value='inherit'),
#         stub_border_style=OptionsInfo(scss=True, category='stub', type='value', value='solid'),
#         stub_border_width=OptionsInfo(scss=True, category='stub', type='px', value='2px'),
#         stub_border_color=OptionsInfo(scss=True, category='stub', type='value', value='#D3D3D3'),
#         stub_row_group_background_color=OptionsInfo(scss=True, category='stub', type='value', value=None),
#         stub_row_group_font_size=OptionsInfo(scss=True, category='stub', type='px', value='100%'),
#         stub_row_group_font_weight=OptionsInfo(scss=True, category='stub', type='value', value='initial'),
#         stub_row_group_text_transform=OptionsInfo(scss=True, category='stub', type='value', value='inherit'),
#         stub_row_group_border_style=OptionsInfo(scss=True, category='stub', type='value', value='solid'),
#         stub_row_group_border_width=OptionsInfo(scss=True, category='stub', type='px', value='2px'),
#         stub_row_group_border_color=OptionsInfo(scss=True, category='stub', type='value', value='#D3D3D3'),
#         source_notes_padding=OptionsInfo(scss=True, category='source_notes', type='px', value='4px'),
#         source_notes_padding_horizontal=OptionsInfo(scss=True, category='source_notes', type='px', value='5px'),
#         source_notes_background_color=OptionsInfo(scss=True, category='source_notes', type='value', value=None),
#         source_notes_font_size=OptionsInfo(scss=True, category='source_notes', type='px', value='90%'),
#         source_notes_border_bottom_style=OptionsInfo(scss=True, category='source_notes', type='value', value='none'),
#         source_notes_border_bottom_width=OptionsInfo(scss=True, category='source_notes', type='px', value='2px'),
#         source_notes_border_bottom_color=OptionsInfo(scss=True, category='source_notes', type='value', value='#D3D3D3'),
#         source_notes_border_lr_style=OptionsInfo(scss=True, category='source_notes', type='value', value='none'),
#         source_notes_border_lr_width=OptionsInfo(scss=True, category='source_notes', type='px', value='2px'),
#         source_notes_border_lr_color=OptionsInfo(scss=True, category='source_notes', type='value', value='#D3D3D3'),
#         source_notes_multiline=OptionsInfo(scss=False, category='source_notes', type='boolean', value=True),
#         source_notes_sep=OptionsInfo(scss=False, category='source_notes', type='value', value=' '),
#         row_striping_background_color=OptionsInfo(scss=True, category='row', type='value', value='rgba(128,128,128,0.05)'),
#         row_striping_include_stub=OptionsInfo(scss=False, category='row', type='boolean', value=False),
#         row_striping_include_table_body=OptionsInfo(scss=False, category='row', type='boolean', value=False),
#         container_width=OptionsInfo(scss=False, category='container', type='px', value='auto'),
#         container_height=OptionsInfo(scss=False, category='container', type='px', value='auto'),
#         container_padding_x=OptionsInfo(scss=False, category='container', type='px', value='0px'),
#         container_padding_y=OptionsInfo(scss=False, category='container', type='px', value='10px'),
#         container_overflow_x=OptionsInfo(scss=False, category='container', type='overflow', value='auto'),
#         container_overflow_y=OptionsInfo(scss=False, category='container', type='overflow', value='auto'),
#         quarto_disable_processing=OptionsInfo(scss=False, category='quarto', type='logical', value=True),
#         quarto_use_bootstrap=OptionsInfo(scss=False, category='quarto', type='logical', value=False)
#     ),
#     _has_built=False
# )

# %%
harmonised_validation.get_step_report(i=37, columns_subset=pb.matches(r"ID|WALK"))
# Out:
# GT(
#     _tbl_data=shape: (10, 8)
# ┌───────────┬─────────┬────────────┬────────────┬────────────┬────────────┬────────────┬───────────┐
# │ _row_num_ ┆ ID      ┆ G227_IPAQ_ ┆ G227_IPAQ_ ┆ G227_IPAQ_ ┆ G227_IPAQ_ ┆ G227_IPAQ_ ┆ G227_IPAQ │
# │ ---       ┆ ---     ┆ WALK_W     ┆ WALK_HPD   ┆ WALK_MPD   ┆ WALK_D     ┆ WALK_MINS  ┆ _WALK_MET │
# │ u32       ┆ f64     ┆ ---        ┆ ---        ┆ ---        ┆ ---        ┆ ---        ┆ ---       │
# │           ┆         ┆ f64        ┆ f64        ┆ f64        ┆ f64        ┆ f64        ┆ f64       │
# ╞═══════════╪═════════╪════════════╪════════════╪════════════╪════════════╪════════════╪═══════════╡
# │ 28        ┆ 10780.0 ┆ 1.0        ┆ 20.0       ┆ null       ┆ 4.0        ┆ 180.0      ┆ 2376.0    │
# │ 53        ┆ 11720.0 ┆ 1.0        ┆ 30.0       ┆ null       ┆ 4.0        ┆ 180.0      ┆ 2376.0    │
# │ 100       ┆ 13270.0 ┆ 1.0        ┆ 45.0       ┆ null       ┆ 7.0        ┆ 180.0      ┆ 4158.0    │
# │ 278       ┆ 18250.0 ┆ 1.0        ┆ 30.0       ┆ null       ┆ 5.0        ┆ 180.0      ┆ 2970.0    │
# │ 296       ┆ 18830.0 ┆ 1.0        ┆ 60.0       ┆ null       ┆ 7.0        ┆ 180.0      ┆ 4158.0    │
# │ 446       ┆ 22740.0 ┆ 1.0        ┆ 20.0       ┆ null       ┆ 3.0        ┆ 180.0      ┆ 1782.0    │
# │ 457       ┆ 23000.0 ┆ 1.0        ┆ 90.0       ┆ null       ┆ 7.0        ┆ 180.0      ┆ 4158.0    │
# │ 496       ┆ 23942.0 ┆ 1.0        ┆ 30.0       ┆ null       ┆ 5.0        ┆ 180.0      ┆ 2970.0    │
# │ 550       ┆ 40870.0 ┆ 1.0        ┆ 20.0       ┆ null       ┆ 5.0        ┆ 180.0      ┆ 2970.0    │
# │ 646       ┆ 43570.0 ┆ 1.0        ┆ 40.0       ┆ null       ┆ 2.0        ┆ 180.0      ┆ 1188.0    │
# └───────────┴─────────┴────────────┴────────────┴────────────┴────────────┴────────────┴───────────┘,
#     _body=<great_tables._gt_data.Body object at 0x0000017582028EB0>,
#     _boxhead=Boxhead([ColInfo(var='_row_num_', type=<ColInfoTypeEnum.default: 1>, column_label='', column_align='right', column_width='33.4px'), ColInfo(var='ID', type=<ColInfoTypeEnum.default: 1>, column_label=Html(text="<div><div style='white-space: nowrap; text-overflow: ellipsis; overflow: hidden; padding-bottom: 2px; margin-bottom: 2px;'>ID</div><div style='white-space: nowrap; text-overflow: ellipsis; overflow: hidden; padding-top: 2px; margin-top: 2px;'><em>Float64</em></div></div>"), column_align='right', column_width='65px'), ColInfo(var='G227_IPAQ_WALK_W', type=<ColInfoTypeEnum.default: 1>, column_label=Html(text="<div><div style='white-space: nowrap; text-overflow: ellipsis; overflow: hidden; padding-bottom: 2px; margin-bottom: 2px;'>G227_IPAQ_WALK_W</div><div style='white-space: nowrap; text-overflow: ellipsis; overflow: hidden; padding-top: 2px; margin-top: 2px;'><em>Float64</em></div></div>"), column_align='right', column_width='135px'), ColInfo(var='G227_IPAQ_WALK_HPD', type=<ColInfoTypeEnum.default: 1>, column_label=Html(text="<div><div style='white-space: nowrap; text-overflow: ellipsis; overflow: hidden; padding-bottom: 2px; margin-bottom: 2px;'>G227_IPAQ_WALK_HPD</div><div style='white-space: nowrap; text-overflow: ellipsis; overflow: hidden; padding-top: 2px; margin-top: 2px;'><em>Float64</em></div></div>"), column_align='right', column_width='150px'), ColInfo(var='G227_IPAQ_WALK_MPD', type=<ColInfoTypeEnum.default: 1>, column_label=Html(text="<div><div style='white-space: nowrap; text-overflow: ellipsis; overflow: hidden; padding-bottom: 2px; margin-bottom: 2px;'>G227_IPAQ_WALK_MPD</div><div style='white-space: nowrap; text-overflow: ellipsis; overflow: hidden; padding-top: 2px; margin-top: 2px;'><em>Float64</em></div></div>"), column_align='right', column_width='150px'), ColInfo(var='G227_IPAQ_WALK_D', type=<ColInfoTypeEnum.default: 1>, column_label=Html(text="<div><div style='white-space: nowrap; text-overflow: ellipsis; overflow: hidden; padding-bottom: 2px; margin-bottom: 2px;'>G227_IPAQ_WALK_D</div><div style='white-space: nowrap; text-overflow: ellipsis; overflow: hidden; padding-top: 2px; margin-top: 2px;'><em>Float64</em></div></div>"), column_align='right', column_width='135px'), ColInfo(var='G227_IPAQ_WALK_MINS', type=<ColInfoTypeEnum.default: 1>, column_label=Html(text="<div><div style='white-space: nowrap; text-overflow: ellipsis; overflow: hidden; padding-bottom: 2px; margin-bottom: 2px;'>G227_IPAQ_WALK_MINS</div><div style='white-space: nowrap; text-overflow: ellipsis; overflow: hidden; padding-top: 2px; margin-top: 2px;'><em>Float64</em></div></div>"), column_align='right', column_width='158px'), ColInfo(var='G227_IPAQ_WALK_MET', type=<ColInfoTypeEnum.default: 1>, column_label=Html(text="<div><div style='white-space: nowrap; text-overflow: ellipsis; overflow: hidden; padding-bottom: 2px; margin-bottom: 2px;'>G227_IPAQ_WALK_MET</div><div style='white-space: nowrap; text-overflow: ellipsis; overflow: hidden; padding-top: 2px; margin-top: 2px;'><em>Float64</em></div></div>"), column_align='right', column_width='150px')]),
#     _stub=<great_tables._gt_data.Stub object at 0x00000175FE845F10>,
#     _spanners=Spanners([]),
#     _heading=Heading(
#         title=Md(
#             text="<p>Report for Validation Step 37<div style='font-size: 13.6px; '><div style='padding-top: 7px;'>ASSERTION <span style='border-style: solid; border-width: thin; border-color: lightblue; padding-left: 2px; padding-right: 2px;'><code style='color: #303030; background-color: transparent; position: relative; bottom: 1px;'><code style='color: #303030; font-family: monospace; font-size: smaller;'>0 &le; G227_IPAQ_WALK_HPD &le; 18</code></code></span></div><div style='padding-top: 7px;'><strong>15</strong> / <strong>1048</strong> TEST UNIT FAILURES IN COLUMN <strong>13</strong> </div><div>EXTRACT OF FIRST <strong>10</strong> ROWS (WITH <span style='color: #B22222;'>TEST UNIT FAILURES IN RED</span>):</div></div></p>\n"
#         ),
#         subtitle=None,
#         preheader=None
#     ),
#     _stubhead=None,
#     _source_notes=[],
#     _footnotes=[],
#     _styles=[
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='_row_num_',
#             rownum=0,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='_row_num_',
#             rownum=1,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='_row_num_',
#             rownum=2,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='_row_num_',
#             rownum=3,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='_row_num_',
#             rownum=4,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='_row_num_',
#             rownum=5,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='_row_num_',
#             rownum=6,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='_row_num_',
#             rownum=7,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='_row_num_',
#             rownum=8,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='_row_num_',
#             rownum=9,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='ID',
#             rownum=0,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='ID',
#             rownum=1,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='ID',
#             rownum=2,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='ID',
#             rownum=3,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='ID',
#             rownum=4,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='ID',
#             rownum=5,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='ID',
#             rownum=6,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='ID',
#             rownum=7,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='ID',
#             rownum=8,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='ID',
#             rownum=9,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_W',
#             rownum=0,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_W',
#             rownum=1,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_W',
#             rownum=2,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_W',
#             rownum=3,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_W',
#             rownum=4,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_W',
#             rownum=5,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_W',
#             rownum=6,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_W',
#             rownum=7,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_W',
#             rownum=8,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_W',
#             rownum=9,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_HPD',
#             rownum=0,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_HPD',
#             rownum=1,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_HPD',
#             rownum=2,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_HPD',
#             rownum=3,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_HPD',
#             rownum=4,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_HPD',
#             rownum=5,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_HPD',
#             rownum=6,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_HPD',
#             rownum=7,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_HPD',
#             rownum=8,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_HPD',
#             rownum=9,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_MPD',
#             rownum=0,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_MPD',
#             rownum=1,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_MPD',
#             rownum=2,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_MPD',
#             rownum=3,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_MPD',
#             rownum=4,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_MPD',
#             rownum=5,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_MPD',
#             rownum=6,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_MPD',
#             rownum=7,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_MPD',
#             rownum=8,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_MPD',
#             rownum=9,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_D',
#             rownum=0,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_D',
#             rownum=1,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_D',
#             rownum=2,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_D',
#             rownum=3,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_D',
#             rownum=4,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_D',
#             rownum=5,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_D',
#             rownum=6,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_D',
#             rownum=7,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_D',
#             rownum=8,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_D',
#             rownum=9,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_MINS',
#             rownum=0,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_MINS',
#             rownum=1,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_MINS',
#             rownum=2,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_MINS',
#             rownum=3,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_MINS',
#             rownum=4,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_MINS',
#             rownum=5,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_MINS',
#             rownum=6,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_MINS',
#             rownum=7,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_MINS',
#             rownum=8,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_MINS',
#             rownum=9,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_MET',
#             rownum=0,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_MET',
#             rownum=1,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_MET',
#             rownum=2,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_MET',
#             rownum=3,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_MET',
#             rownum=4,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_MET',
#             rownum=5,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_MET',
#             rownum=6,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_MET',
#             rownum=7,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_MET',
#             rownum=8,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_MET',
#             rownum=9,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='_row_num_',
#             rownum=0,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='_row_num_',
#             rownum=1,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='_row_num_',
#             rownum=2,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='_row_num_',
#             rownum=3,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='_row_num_',
#             rownum=4,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='_row_num_',
#             rownum=5,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='_row_num_',
#             rownum=6,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='_row_num_',
#             rownum=7,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='_row_num_',
#             rownum=8,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='_row_num_',
#             rownum=9,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='ID',
#             rownum=0,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='ID',
#             rownum=1,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='ID',
#             rownum=2,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='ID',
#             rownum=3,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='ID',
#             rownum=4,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='ID',
#             rownum=5,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='ID',
#             rownum=6,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='ID',
#             rownum=7,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='ID',
#             rownum=8,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='ID',
#             rownum=9,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_W',
#             rownum=0,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_W',
#             rownum=1,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_W',
#             rownum=2,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_W',
#             rownum=3,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_W',
#             rownum=4,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_W',
#             rownum=5,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_W',
#             rownum=6,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_W',
#             rownum=7,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_W',
#             rownum=8,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_W',
#             rownum=9,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_HPD',
#             rownum=0,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_HPD',
#             rownum=1,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_HPD',
#             rownum=2,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_HPD',
#             rownum=3,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_HPD',
#             rownum=4,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_HPD',
#             rownum=5,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_HPD',
#             rownum=6,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
# ...
#                 CellStyleFill(color='#FFC1C159'),
#                 CellStyleBorders(sides=['left', 'right'], color='black', style='solid', weight='2px')
#             ]
#         ),
#         StyleInfo(
#             locname=LocBody(columns='G227_IPAQ_WALK_HPD', rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_HPD',
#             rownum=9,
#             colnum=None,
#             styles=[
#                 CellStyleText(color='#B22222', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None),
#                 CellStyleFill(color='#FFC1C159'),
#                 CellStyleBorders(sides=['left', 'right'], color='black', style='solid', weight='2px')
#             ]
#         ),
#         StyleInfo(
#             locname=LocColumnLabels(columns='G227_IPAQ_WALK_HPD'),
#             grpname=None,
#             colname='G227_IPAQ_WALK_HPD',
#             rownum=None,
#             colnum=None,
#             styles=[CellStyleBorders(sides=['left', 'right'], color='black', style='solid', weight='2px')]
#         )
#     ],
#     _locale=<great_tables._gt_data.Locale object at 0x00000175820280F0>,
#     _formats=[<great_tables._gt_data.FormatInfo object at 0x00000175FE846150>],
#     _substitutions=[],
#     _options=Options(
#         table_id=OptionsInfo(scss=True, category='table', type='value', value='pb_preview_tbl'),
#         table_caption=OptionsInfo(scss=False, category='table', type='value', value=None),
#         table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'),
#         table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'),
#         table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'),
#         table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'),
#         table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'),
#         table_additional_css=OptionsInfo(
#             scss=False,
#             category='table',
#             type='values',
#             value=[
#                 "@import url('https://fonts.googleapis.com/css2?family=IBM+Plex+Sans&display=swap');",
#                 "@import url('https://fonts.googleapis.com/css2?family=IBM+Plex+Mono&display=swap');",
#                 "@import url('https://fonts.googleapis.com/css2?family=IBM+Plex+Mono&display=swap');",
#                 "@import url('https://fonts.googleapis.com/css2?family=IBM+Plex+Mono&display=swap');"
#             ]
#         ),
#         table_font_names=OptionsInfo(
#             scss=False,
#             category='table',
#             type='values',
#             value=['IBM Plex Sans', '-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']
#         ),
#         table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'),
#         table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'),
#         table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'),
#         table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'),
#         table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'),
#         table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True),
#         table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'),
#         table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'),
#         table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'),
#         table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'),
#         table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'),
#         table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'),
#         table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True),
#         table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'),
#         table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'),
#         table_border_bottom_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'),
#         table_border_left_style=OptionsInfo(scss=True, category='table', type='value', value='none'),
#         table_border_left_width=OptionsInfo(scss=True, category='table', type='px', value='2px'),
#         table_border_left_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'),
#         heading_background_color=OptionsInfo(scss=True, category='heading', type='value', value=None),
#         heading_align=OptionsInfo(scss=True, category='heading', type='value', value='left'),
#         heading_title_font_size=OptionsInfo(scss=True, category='heading', type='px', value='125%'),
#         heading_title_font_weight=OptionsInfo(scss=True, category='heading', type='value', value='initial'),
#         heading_subtitle_font_size=OptionsInfo(scss=True, category='heading', type='px', value='85%'),
#         heading_subtitle_font_weight=OptionsInfo(scss=True, category='heading', type='value', value='initial'),
#         heading_padding=OptionsInfo(scss=True, category='heading', type='px', value='4px'),
#         heading_padding_horizontal=OptionsInfo(scss=True, category='heading', type='px', value='5px'),
#         heading_border_bottom_style=OptionsInfo(scss=True, category='heading', type='value', value='solid'),
#         heading_border_bottom_width=OptionsInfo(scss=True, category='heading', type='px', value='2px'),
#         heading_border_bottom_color=OptionsInfo(scss=True, category='heading', type='value', value='#D3D3D3'),
#         heading_border_lr_style=OptionsInfo(scss=True, category='heading', type='value', value='none'),
#         heading_border_lr_width=OptionsInfo(scss=True, category='heading', type='px', value='1px'),
#         heading_border_lr_color=OptionsInfo(scss=True, category='heading', type='value', value='#D3D3D3'),
#         column_labels_background_color=OptionsInfo(scss=True, category='column_labels', type='value', value=None),
#         column_labels_font_size=OptionsInfo(scss=True, category='column_labels', type='px', value='100%'),
#         column_labels_font_weight=OptionsInfo(scss=True, category='column_labels', type='value', value='normal'),
#         column_labels_text_transform=OptionsInfo(scss=True, category='column_labels', type='value', value='inherit'),
#         column_labels_padding=OptionsInfo(scss=True, category='column_labels', type='px', value='5px'),
#         column_labels_padding_horizontal=OptionsInfo(scss=True, category='column_labels', type='px', value='5px'),
#         column_labels_vlines_style=OptionsInfo(scss=True, category='table_body', type='value', value='solid'),
#         column_labels_vlines_width=OptionsInfo(scss=True, category='table_body', type='px', value='1px'),
#         column_labels_vlines_color=OptionsInfo(scss=True, category='table_body', type='value', value='#F2F2F2'),
#         column_labels_border_top_style=OptionsInfo(scss=True, category='column_labels', type='value', value='solid'),
#         column_labels_border_top_width=OptionsInfo(scss=True, category='column_labels', type='px', value='2px'),
#         column_labels_border_top_color=OptionsInfo(scss=True, category='column_labels', type='value', value='#D3D3D3'),
#         column_labels_border_bottom_style=OptionsInfo(scss=True, category='column_labels', type='value', value='solid'),
#         column_labels_border_bottom_width=OptionsInfo(scss=True, category='column_labels', type='px', value='2px'),
#         column_labels_border_bottom_color=OptionsInfo(scss=True, category='column_labels', type='value', value='#D3D3D3'),
#         column_labels_border_lr_style=OptionsInfo(scss=True, category='column_labels', type='value', value='none'),
#         column_labels_border_lr_width=OptionsInfo(scss=True, category='column_labels', type='px', value='1px'),
#         column_labels_border_lr_color=OptionsInfo(scss=True, category='column_labels', type='value', value='#D3D3D3'),
#         column_labels_hidden=OptionsInfo(scss=False, category='column_labels', type='boolean', value=False),
#         row_group_background_color=OptionsInfo(scss=True, category='row_group', type='value', value=None),
#         row_group_font_size=OptionsInfo(scss=True, category='row_group', type='px', value='100%'),
#         row_group_font_weight=OptionsInfo(scss=True, category='row_group', type='value', value='initial'),
#         row_group_text_transform=OptionsInfo(scss=True, category='row_group', type='value', value='inherit'),
#         row_group_padding=OptionsInfo(scss=True, category='row_group', type='px', value='8px'),
#         row_group_padding_horizontal=OptionsInfo(scss=True, category='row_group', type='px', value='5px'),
#         row_group_border_top_style=OptionsInfo(scss=True, category='row_group', type='value', value='solid'),
#         row_group_border_top_width=OptionsInfo(scss=True, category='row_group', type='px', value='2px'),
#         row_group_border_top_color=OptionsInfo(scss=True, category='row_group', type='value', value='#D3D3D3'),
#         row_group_border_right_style=OptionsInfo(scss=True, category='row_group', type='value', value='none'),
#         row_group_border_right_width=OptionsInfo(scss=True, category='row_group', type='px', value='1px'),
#         row_group_border_right_color=OptionsInfo(scss=True, category='row_group', type='value', value='#D3D3D3'),
#         row_group_border_bottom_style=OptionsInfo(scss=True, category='row_group', type='value', value='solid'),
#         row_group_border_bottom_width=OptionsInfo(scss=True, category='row_group', type='px', value='2px'),
#         row_group_border_bottom_color=OptionsInfo(scss=True, category='row_group', type='value', value='#D3D3D3'),
#         row_group_border_left_style=OptionsInfo(scss=True, category='row_group', type='value', value='none'),
#         row_group_border_left_width=OptionsInfo(scss=True, category='row_group', type='px', value='1px'),
#         row_group_border_left_color=OptionsInfo(scss=True, category='row_group', type='value', value='#D3D3D3'),
#         row_group_as_column=OptionsInfo(scss=False, category='row_group', type='boolean', value=False),
#         table_body_hlines_style=OptionsInfo(scss=True, category='table_body', type='value', value='solid'),
#         table_body_hlines_width=OptionsInfo(scss=True, category='table_body', type='px', value='1px'),
#         table_body_hlines_color=OptionsInfo(scss=True, category='table_body', type='value', value='#D3D3D3'),
#         table_body_vlines_style=OptionsInfo(scss=True, category='table_body', type='value', value='solid'),
#         table_body_vlines_width=OptionsInfo(scss=True, category='table_body', type='px', value='1px'),
#         table_body_vlines_color=OptionsInfo(scss=True, category='table_body', type='value', value='#E9E9E9'),
#         table_body_border_top_style=OptionsInfo(scss=True, category='table_body', type='value', value='solid'),
#         table_body_border_top_width=OptionsInfo(scss=True, category='table_body', type='px', value='2px'),
#         table_body_border_top_color=OptionsInfo(scss=True, category='table_body', type='value', value='#D3D3D3'),
#         table_body_border_bottom_style=OptionsInfo(scss=True, category='table_body', type='value', value='solid'),
#         table_body_border_bottom_width=OptionsInfo(scss=True, category='table_body', type='px', value='2px'),
#         table_body_border_bottom_color=OptionsInfo(scss=True, category='table_body', type='value', value='#D3D3D3'),
#         data_row_padding=OptionsInfo(scss=True, category='data_row', type='px', value='8px'),
#         data_row_padding_horizontal=OptionsInfo(scss=True, category='data_row', type='px', value='5px'),
#         stub_background_color=OptionsInfo(scss=True, category='stub', type='value', value=None),
#         stub_font_size=OptionsInfo(scss=True, category='stub', type='px', value='100%'),
#         stub_font_weight=OptionsInfo(scss=True, category='stub', type='value', value='initial'),
#         stub_text_transform=OptionsInfo(scss=True, category='stub', type='value', value='inherit'),
#         stub_border_style=OptionsInfo(scss=True, category='stub', type='value', value='solid'),
#         stub_border_width=OptionsInfo(scss=True, category='stub', type='px', value='2px'),
#         stub_border_color=OptionsInfo(scss=True, category='stub', type='value', value='#D3D3D3'),
#         stub_row_group_background_color=OptionsInfo(scss=True, category='stub', type='value', value=None),
#         stub_row_group_font_size=OptionsInfo(scss=True, category='stub', type='px', value='100%'),
#         stub_row_group_font_weight=OptionsInfo(scss=True, category='stub', type='value', value='initial'),
#         stub_row_group_text_transform=OptionsInfo(scss=True, category='stub', type='value', value='inherit'),
#         stub_row_group_border_style=OptionsInfo(scss=True, category='stub', type='value', value='solid'),
#         stub_row_group_border_width=OptionsInfo(scss=True, category='stub', type='px', value='2px'),
#         stub_row_group_border_color=OptionsInfo(scss=True, category='stub', type='value', value='#D3D3D3'),
#         source_notes_padding=OptionsInfo(scss=True, category='source_notes', type='px', value='4px'),
#         source_notes_padding_horizontal=OptionsInfo(scss=True, category='source_notes', type='px', value='5px'),
#         source_notes_background_color=OptionsInfo(scss=True, category='source_notes', type='value', value=None),
#         source_notes_font_size=OptionsInfo(scss=True, category='source_notes', type='px', value='90%'),
#         source_notes_border_bottom_style=OptionsInfo(scss=True, category='source_notes', type='value', value='none'),
#         source_notes_border_bottom_width=OptionsInfo(scss=True, category='source_notes', type='px', value='2px'),
#         source_notes_border_bottom_color=OptionsInfo(scss=True, category='source_notes', type='value', value='#D3D3D3'),
#         source_notes_border_lr_style=OptionsInfo(scss=True, category='source_notes', type='value', value='none'),
#         source_notes_border_lr_width=OptionsInfo(scss=True, category='source_notes', type='px', value='2px'),
#         source_notes_border_lr_color=OptionsInfo(scss=True, category='source_notes', type='value', value='#D3D3D3'),
#         source_notes_multiline=OptionsInfo(scss=False, category='source_notes', type='boolean', value=True),
#         source_notes_sep=OptionsInfo(scss=False, category='source_notes', type='value', value=' '),
#         row_striping_background_color=OptionsInfo(scss=True, category='row', type='value', value='rgba(128,128,128,0.05)'),
#         row_striping_include_stub=OptionsInfo(scss=False, category='row', type='boolean', value=False),
#         row_striping_include_table_body=OptionsInfo(scss=False, category='row', type='boolean', value=False),
#         container_width=OptionsInfo(scss=False, category='container', type='px', value='auto'),
#         container_height=OptionsInfo(scss=False, category='container', type='px', value='auto'),
#         container_padding_x=OptionsInfo(scss=False, category='container', type='px', value='0px'),
#         container_padding_y=OptionsInfo(scss=False, category='container', type='px', value='10px'),
#         container_overflow_x=OptionsInfo(scss=False, category='container', type='overflow', value='auto'),
#         container_overflow_y=OptionsInfo(scss=False, category='container', type='overflow', value='auto'),
#         quarto_disable_processing=OptionsInfo(scss=False, category='quarto', type='logical', value=True),
#         quarto_use_bootstrap=OptionsInfo(scss=False, category='quarto', type='logical', value=False)
#     ),
#     _has_built=False
# )

# %%
harmonised_validation.get_step_report(i=38, columns_subset=pb.matches(r"ID|WALK"))
# Out:
# GT(
#     _tbl_data=shape: (5, 8)
# ┌───────────┬─────────┬────────────┬────────────┬────────────┬────────────┬────────────┬───────────┐
# │ _row_num_ ┆ ID      ┆ G227_IPAQ_ ┆ G227_IPAQ_ ┆ G227_IPAQ_ ┆ G227_IPAQ_ ┆ G227_IPAQ_ ┆ G227_IPAQ │
# │ ---       ┆ ---     ┆ WALK_W     ┆ WALK_HPD   ┆ WALK_MPD   ┆ WALK_D     ┆ WALK_MINS  ┆ _WALK_MET │
# │ u32       ┆ f64     ┆ ---        ┆ ---        ┆ ---        ┆ ---        ┆ ---        ┆ ---       │
# │           ┆         ┆ f64        ┆ f64        ┆ f64        ┆ f64        ┆ f64        ┆ f64       │
# ╞═══════════╪═════════╪════════════╪════════════╪════════════╪════════════╪════════════╪═══════════╡
# │ 32        ┆ 10920.0 ┆ 1.0        ┆ null       ┆ 60.0       ┆ null       ┆ 60.0       ┆ null      │
# │ 61        ┆ 12010.0 ┆ 1.0        ┆ null       ┆ 60.0       ┆ 7.0        ┆ 60.0       ┆ 1386.0    │
# │ 429       ┆ 22260.0 ┆ 1.0        ┆ null       ┆ 180.0      ┆ 7.0        ┆ 180.0      ┆ 4158.0    │
# │ 665       ┆ 44190.0 ┆ 1.0        ┆ null       ┆ 60.0       ┆ 7.0        ┆ 60.0       ┆ 1386.0    │
# │ 835       ┆ 48450.0 ┆ 1.0        ┆ null       ┆ 60.0       ┆ 7.0        ┆ 60.0       ┆ 1386.0    │
# └───────────┴─────────┴────────────┴────────────┴────────────┴────────────┴────────────┴───────────┘,
#     _body=<great_tables._gt_data.Body object at 0x0000017581EBE710>,
#     _boxhead=Boxhead([ColInfo(var='_row_num_', type=<ColInfoTypeEnum.default: 1>, column_label='', column_align='right', column_width='33.4px'), ColInfo(var='ID', type=<ColInfoTypeEnum.default: 1>, column_label=Html(text="<div><div style='white-space: nowrap; text-overflow: ellipsis; overflow: hidden; padding-bottom: 2px; margin-bottom: 2px;'>ID</div><div style='white-space: nowrap; text-overflow: ellipsis; overflow: hidden; padding-top: 2px; margin-top: 2px;'><em>Float64</em></div></div>"), column_align='right', column_width='65px'), ColInfo(var='G227_IPAQ_WALK_W', type=<ColInfoTypeEnum.default: 1>, column_label=Html(text="<div><div style='white-space: nowrap; text-overflow: ellipsis; overflow: hidden; padding-bottom: 2px; margin-bottom: 2px;'>G227_IPAQ_WALK_W</div><div style='white-space: nowrap; text-overflow: ellipsis; overflow: hidden; padding-top: 2px; margin-top: 2px;'><em>Float64</em></div></div>"), column_align='right', column_width='135px'), ColInfo(var='G227_IPAQ_WALK_HPD', type=<ColInfoTypeEnum.default: 1>, column_label=Html(text="<div><div style='white-space: nowrap; text-overflow: ellipsis; overflow: hidden; padding-bottom: 2px; margin-bottom: 2px;'>G227_IPAQ_WALK_HPD</div><div style='white-space: nowrap; text-overflow: ellipsis; overflow: hidden; padding-top: 2px; margin-top: 2px;'><em>Float64</em></div></div>"), column_align='right', column_width='150px'), ColInfo(var='G227_IPAQ_WALK_MPD', type=<ColInfoTypeEnum.default: 1>, column_label=Html(text="<div><div style='white-space: nowrap; text-overflow: ellipsis; overflow: hidden; padding-bottom: 2px; margin-bottom: 2px;'>G227_IPAQ_WALK_MPD</div><div style='white-space: nowrap; text-overflow: ellipsis; overflow: hidden; padding-top: 2px; margin-top: 2px;'><em>Float64</em></div></div>"), column_align='right', column_width='150px'), ColInfo(var='G227_IPAQ_WALK_D', type=<ColInfoTypeEnum.default: 1>, column_label=Html(text="<div><div style='white-space: nowrap; text-overflow: ellipsis; overflow: hidden; padding-bottom: 2px; margin-bottom: 2px;'>G227_IPAQ_WALK_D</div><div style='white-space: nowrap; text-overflow: ellipsis; overflow: hidden; padding-top: 2px; margin-top: 2px;'><em>Float64</em></div></div>"), column_align='right', column_width='135px'), ColInfo(var='G227_IPAQ_WALK_MINS', type=<ColInfoTypeEnum.default: 1>, column_label=Html(text="<div><div style='white-space: nowrap; text-overflow: ellipsis; overflow: hidden; padding-bottom: 2px; margin-bottom: 2px;'>G227_IPAQ_WALK_MINS</div><div style='white-space: nowrap; text-overflow: ellipsis; overflow: hidden; padding-top: 2px; margin-top: 2px;'><em>Float64</em></div></div>"), column_align='right', column_width='158px'), ColInfo(var='G227_IPAQ_WALK_MET', type=<ColInfoTypeEnum.default: 1>, column_label=Html(text="<div><div style='white-space: nowrap; text-overflow: ellipsis; overflow: hidden; padding-bottom: 2px; margin-bottom: 2px;'>G227_IPAQ_WALK_MET</div><div style='white-space: nowrap; text-overflow: ellipsis; overflow: hidden; padding-top: 2px; margin-top: 2px;'><em>Float64</em></div></div>"), column_align='right', column_width='150px')]),
#     _stub=<great_tables._gt_data.Stub object at 0x00000175FE862750>,
#     _spanners=Spanners([]),
#     _heading=Heading(
#         title=Md(
#             text="<p>Report for Validation Step 38<div style='font-size: 13.6px; '><div style='padding-top: 7px;'>ASSERTION <span style='border-style: solid; border-width: thin; border-color: lightblue; padding-left: 2px; padding-right: 2px;'><code style='color: #303030; background-color: transparent; position: relative; bottom: 1px;'><code style='color: #303030; font-family: monospace; font-size: smaller;'>0 &le; G227_IPAQ_WALK_MPD &le; 59</code></code></span></div><div style='padding-top: 7px;'><strong>5</strong> / <strong>1048</strong> TEST UNIT FAILURES IN COLUMN <strong>14</strong> </div><div>EXTRACT OF ALL <strong>5</strong> ROWS (WITH <span style='color: #B22222;'>TEST UNIT FAILURES IN RED</span>):</div></div></p>\n"
#         ),
#         subtitle=None,
#         preheader=None
#     ),
#     _stubhead=None,
#     _source_notes=[],
#     _footnotes=[],
#     _styles=[
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='_row_num_',
#             rownum=0,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='_row_num_',
#             rownum=1,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='_row_num_',
#             rownum=2,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='_row_num_',
#             rownum=3,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='_row_num_',
#             rownum=4,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='ID',
#             rownum=0,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='ID',
#             rownum=1,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='ID',
#             rownum=2,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='ID',
#             rownum=3,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='ID',
#             rownum=4,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_W',
#             rownum=0,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_W',
#             rownum=1,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_W',
#             rownum=2,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_W',
#             rownum=3,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_W',
#             rownum=4,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_HPD',
#             rownum=0,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_HPD',
#             rownum=1,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_HPD',
#             rownum=2,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_HPD',
#             rownum=3,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_HPD',
#             rownum=4,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_MPD',
#             rownum=0,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_MPD',
#             rownum=1,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_MPD',
#             rownum=2,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_MPD',
#             rownum=3,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_MPD',
#             rownum=4,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_D',
#             rownum=0,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_D',
#             rownum=1,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_D',
#             rownum=2,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_D',
#             rownum=3,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_D',
#             rownum=4,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_MINS',
#             rownum=0,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_MINS',
#             rownum=1,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_MINS',
#             rownum=2,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_MINS',
#             rownum=3,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_MINS',
#             rownum=4,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_MET',
#             rownum=0,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_MET',
#             rownum=1,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_MET',
#             rownum=2,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_MET',
#             rownum=3,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_MET',
#             rownum=4,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='_row_num_',
#             rownum=0,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='_row_num_',
#             rownum=1,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='_row_num_',
#             rownum=2,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='_row_num_',
#             rownum=3,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='_row_num_',
#             rownum=4,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='ID',
#             rownum=0,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='ID',
#             rownum=1,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='ID',
#             rownum=2,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='ID',
#             rownum=3,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='ID',
#             rownum=4,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_W',
#             rownum=0,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_W',
#             rownum=1,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_W',
#             rownum=2,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_W',
#             rownum=3,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_W',
#             rownum=4,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_HPD',
#             rownum=0,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_HPD',
#             rownum=1,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_HPD',
#             rownum=2,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_HPD',
#             rownum=3,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_HPD',
#             rownum=4,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_MPD',
#             rownum=0,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_MPD',
#             rownum=1,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_MPD',
#             rownum=2,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_MPD',
#             rownum=3,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_MPD',
#             rownum=4,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_D',
#             rownum=0,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_D',
#             rownum=1,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_D',
#             rownum=2,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_D',
#             rownum=3,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_D',
#             rownum=4,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_MINS',
#             rownum=0,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_MINS',
#             rownum=1,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_MINS',
#             rownum=2,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_MINS',
#             rownum=3,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_MINS',
#             rownum=4,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_MET',
#             rownum=0,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_MET',
#             rownum=1,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_MET',
#             rownum=2,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_MET',
#             rownum=3,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_MET',
#             rownum=4,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocColumnLabels(columns=None),
#             grpname=None,
#             colname='_row_num_',
#             rownum=None,
#             colnum=None,
#             styles=[CellStyleText(color='gray20', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocColumnLabels(columns=None),
#             grpname=None,
#             colname='ID',
#             rownum=None,
#             colnum=None,
#             styles=[CellStyleText(color='gray20', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocColumnLabels(columns=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_W',
#             rownum=None,
#             colnum=None,
#             styles=[CellStyleText(color='gray20', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocColumnLabels(columns=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_HPD',
#             rownum=None,
#             colnum=None,
#             styles=[CellStyleText(color='gray20', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocColumnLabels(columns=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_MPD',
#             rownum=None,
#             colnum=None,
#             styles=[CellStyleText(color='gray20', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocColumnLabels(columns=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_D',
#             rownum=None,
#             colnum=None,
#             styles=[CellStyleText(color='gray20', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocColumnLabels(columns=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_MINS',
#             rownum=None,
#             colnum=None,
#             styles=[CellStyleText(color='gray20', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocColumnLabels(columns=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_MET',
#             rownum=None,
#             colnum=None,
#             styles=[CellStyleText(color='gray20', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='_row_num_',
#             rownum=0,
#             colnum=None,
#             styles=[CellStyleBorders(sides=['top', 'bottom'], color='#E9E9E', style='solid', weight='1px')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='_row_num_',
#             rownum=1,
#             colnum=None,
#             styles=[CellStyleBorders(sides=['top', 'bottom'], color='#E9E9E', style='solid', weight='1px')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='_row_num_',
#             rownum=2,
#             colnum=None,
#             styles=[CellStyleBorders(sides=['top', 'bottom'], color='#E9E9E', style='solid', weight='1px')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='_row_num_',
#             rownum=3,
#             colnum=None,
#             styles=[CellStyleBorders(sides=['top', 'bottom'], color='#E9E9E', style='solid', weight='1px')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='_row_num_',
#             rownum=4,
#             colnum=None,
#             styles=[CellStyleBorders(sides=['top', 'bottom'], color='#E9E9E', style='solid', weight='1px')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='ID',
#             rownum=0,
#             colnum=None,
#             styles=[CellStyleBorders(sides=['top', 'bottom'], color='#E9E9E', style='solid', weight='1px')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='ID',
#             rownum=1,
#             colnum=None,
#             styles=[CellStyleBorders(sides=['top', 'bottom'], color='#E9E9E', style='solid', weight='1px')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='ID',
#             rownum=2,
#             colnum=None,
#             styles=[CellStyleBorders(sides=['top', 'bottom'], color='#E9E9E', style='solid', weight='1px')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='ID',
#             rownum=3,
#             colnum=None,
#             styles=[CellStyleBorders(sides=['top', 'bottom'], color='#E9E9E', style='solid', weight='1px')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='ID',
#             rownum=4,
#             colnum=None,
#             styles=[CellStyleBorders(sides=['top', 'bottom'], color='#E9E9E', style='solid', weight='1px')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_W',
#             rownum=0,
#             colnum=None,
#             styles=[CellStyleBorders(sides=['top', 'bottom'], color='#E9E9E', style='solid', weight='1px')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_W',
#             rownum=1,
#             colnum=None,
#             styles=[CellStyleBorders(sides=['top', 'bottom'], color='#E9E9E', style='solid', weight='1px')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_W',
#             rownum=2,
#             colnum=None,
#             styles=[CellStyleBorders(sides=['top', 'bottom'], color='#E9E9E', style='solid', weight='1px')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_W',
#             rownum=3,
#             colnum=None,
#             styles=[CellStyleBorders(sides=['top', 'bottom'], color='#E9E9E', style='solid', weight='1px')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_W',
#             rownum=4,
#             colnum=None,
#             styles=[CellStyleBorders(sides=['top', 'bottom'], color='#E9E9E', style='solid', weight='1px')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_HPD',
#             rownum=0,
#             colnum=None,
#             styles=[CellStyleBorders(sides=['top', 'bottom'], color='#E9E9E', style='solid', weight='1px')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_HPD',
#             rownum=1,
#             colnum=None,
#             styles=[CellStyleBorders(sides=['top', 'bottom'], color='#E9E9E', style='solid', weight='1px')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_HPD',
#             rownum=2,
#             colnum=None,
#             styles=[CellStyleBorders(sides=['top', 'bottom'], color='#E9E9E', style='solid', weight='1px')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_HPD',
#             rownum=3,
#             colnum=None,
#             styles=[CellStyleBorders(sides=['top', 'bottom'], color='#E9E9E', style='solid', weight='1px')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_HPD',
#             rownum=4,
#             colnum=None,
#             styles=[CellStyleBorders(sides=['top', 'bottom'], color='#E9E9E', style='solid', weight='1px')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_MPD',
#             rownum=0,
#             colnum=None,
#             styles=[CellStyleBorders(sides=['top', 'bottom'], color='#E9E9E', style='solid', weight='1px')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_MPD',
#             rownum=1,
#             colnum=None,
#             styles=[CellStyleBorders(sides=['top', 'bottom'], color='#E9E9E', style='solid', weight='1px')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_MPD',
#             rownum=2,
#             colnum=None,
#             styles=[CellStyleBorders(sides=['top', 'bottom'], color='#E9E9E', style='solid', weight='1px')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_MPD',
#             rownum=3,
#             colnum=None,
#             styles=[CellStyleBorders(sides=['top', 'bottom'], color='#E9E9E', style='solid', weight='1px')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_MPD',
#             rownum=4,
#             colnum=None,
#             styles=[CellStyleBorders(sides=['top', 'bottom'], color='#E9E9E', style='solid', weight='1px')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_D',
#             rownum=0,
#             colnum=None,
#             styles=[CellStyleBorders(sides=['top', 'bottom'], color='#E9E9E', style='solid', weight='1px')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_D',
#             rownum=1,
#             colnum=None,
#             styles=[CellStyleBorders(sides=['top', 'bottom'], color='#E9E9E', style='solid', weight='1px')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_D',
#             rownum=2,
#             colnum=None,
#             styles=[CellStyleBorders(sides=['top', 'bottom'], color='#E9E9E', style='solid', weight='1px')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_D',
#             rownum=3,
#             colnum=None,
#             styles=[CellStyleBorders(sides=['top', 'bottom'], color='#E9E9E', style='solid', weight='1px')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_D',
#             rownum=4,
#             colnum=None,
#             styles=[CellStyleBorders(sides=['top', 'bottom'], color='#E9E9E', style='solid', weight='1px')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_MINS',
#             rownum=0,
#             colnum=None,
# ...
#                 CellStyleFill(color='#FFC1C159'),
#                 CellStyleBorders(sides=['left', 'right'], color='black', style='solid', weight='2px')
#             ]
#         ),
#         StyleInfo(
#             locname=LocBody(columns='G227_IPAQ_WALK_MPD', rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_MPD',
#             rownum=4,
#             colnum=None,
#             styles=[
#                 CellStyleText(color='#B22222', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None),
#                 CellStyleFill(color='#FFC1C159'),
#                 CellStyleBorders(sides=['left', 'right'], color='black', style='solid', weight='2px')
#             ]
#         ),
#         StyleInfo(
#             locname=LocColumnLabels(columns='G227_IPAQ_WALK_MPD'),
#             grpname=None,
#             colname='G227_IPAQ_WALK_MPD',
#             rownum=None,
#             colnum=None,
#             styles=[CellStyleBorders(sides=['left', 'right'], color='black', style='solid', weight='2px')]
#         )
#     ],
#     _locale=<great_tables._gt_data.Locale object at 0x0000017581EBC230>,
#     _formats=[<great_tables._gt_data.FormatInfo object at 0x00000175FE8604D0>],
#     _substitutions=[],
#     _options=Options(
#         table_id=OptionsInfo(scss=True, category='table', type='value', value='pb_preview_tbl'),
#         table_caption=OptionsInfo(scss=False, category='table', type='value', value=None),
#         table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'),
#         table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'),
#         table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'),
#         table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'),
#         table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'),
#         table_additional_css=OptionsInfo(
#             scss=False,
#             category='table',
#             type='values',
#             value=[
#                 "@import url('https://fonts.googleapis.com/css2?family=IBM+Plex+Sans&display=swap');",
#                 "@import url('https://fonts.googleapis.com/css2?family=IBM+Plex+Mono&display=swap');",
#                 "@import url('https://fonts.googleapis.com/css2?family=IBM+Plex+Mono&display=swap');",
#                 "@import url('https://fonts.googleapis.com/css2?family=IBM+Plex+Mono&display=swap');"
#             ]
#         ),
#         table_font_names=OptionsInfo(
#             scss=False,
#             category='table',
#             type='values',
#             value=['IBM Plex Sans', '-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']
#         ),
#         table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'),
#         table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'),
#         table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'),
#         table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'),
#         table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'),
#         table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True),
#         table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'),
#         table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'),
#         table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'),
#         table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'),
#         table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'),
#         table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'),
#         table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True),
#         table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'),
#         table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'),
#         table_border_bottom_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'),
#         table_border_left_style=OptionsInfo(scss=True, category='table', type='value', value='none'),
#         table_border_left_width=OptionsInfo(scss=True, category='table', type='px', value='2px'),
#         table_border_left_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'),
#         heading_background_color=OptionsInfo(scss=True, category='heading', type='value', value=None),
#         heading_align=OptionsInfo(scss=True, category='heading', type='value', value='left'),
#         heading_title_font_size=OptionsInfo(scss=True, category='heading', type='px', value='125%'),
#         heading_title_font_weight=OptionsInfo(scss=True, category='heading', type='value', value='initial'),
#         heading_subtitle_font_size=OptionsInfo(scss=True, category='heading', type='px', value='85%'),
#         heading_subtitle_font_weight=OptionsInfo(scss=True, category='heading', type='value', value='initial'),
#         heading_padding=OptionsInfo(scss=True, category='heading', type='px', value='4px'),
#         heading_padding_horizontal=OptionsInfo(scss=True, category='heading', type='px', value='5px'),
#         heading_border_bottom_style=OptionsInfo(scss=True, category='heading', type='value', value='solid'),
#         heading_border_bottom_width=OptionsInfo(scss=True, category='heading', type='px', value='2px'),
#         heading_border_bottom_color=OptionsInfo(scss=True, category='heading', type='value', value='#D3D3D3'),
#         heading_border_lr_style=OptionsInfo(scss=True, category='heading', type='value', value='none'),
#         heading_border_lr_width=OptionsInfo(scss=True, category='heading', type='px', value='1px'),
#         heading_border_lr_color=OptionsInfo(scss=True, category='heading', type='value', value='#D3D3D3'),
#         column_labels_background_color=OptionsInfo(scss=True, category='column_labels', type='value', value=None),
#         column_labels_font_size=OptionsInfo(scss=True, category='column_labels', type='px', value='100%'),
#         column_labels_font_weight=OptionsInfo(scss=True, category='column_labels', type='value', value='normal'),
#         column_labels_text_transform=OptionsInfo(scss=True, category='column_labels', type='value', value='inherit'),
#         column_labels_padding=OptionsInfo(scss=True, category='column_labels', type='px', value='5px'),
#         column_labels_padding_horizontal=OptionsInfo(scss=True, category='column_labels', type='px', value='5px'),
#         column_labels_vlines_style=OptionsInfo(scss=True, category='table_body', type='value', value='solid'),
#         column_labels_vlines_width=OptionsInfo(scss=True, category='table_body', type='px', value='1px'),
#         column_labels_vlines_color=OptionsInfo(scss=True, category='table_body', type='value', value='#F2F2F2'),
#         column_labels_border_top_style=OptionsInfo(scss=True, category='column_labels', type='value', value='solid'),
#         column_labels_border_top_width=OptionsInfo(scss=True, category='column_labels', type='px', value='2px'),
#         column_labels_border_top_color=OptionsInfo(scss=True, category='column_labels', type='value', value='#D3D3D3'),
#         column_labels_border_bottom_style=OptionsInfo(scss=True, category='column_labels', type='value', value='solid'),
#         column_labels_border_bottom_width=OptionsInfo(scss=True, category='column_labels', type='px', value='2px'),
#         column_labels_border_bottom_color=OptionsInfo(scss=True, category='column_labels', type='value', value='#D3D3D3'),
#         column_labels_border_lr_style=OptionsInfo(scss=True, category='column_labels', type='value', value='none'),
#         column_labels_border_lr_width=OptionsInfo(scss=True, category='column_labels', type='px', value='1px'),
#         column_labels_border_lr_color=OptionsInfo(scss=True, category='column_labels', type='value', value='#D3D3D3'),
#         column_labels_hidden=OptionsInfo(scss=False, category='column_labels', type='boolean', value=False),
#         row_group_background_color=OptionsInfo(scss=True, category='row_group', type='value', value=None),
#         row_group_font_size=OptionsInfo(scss=True, category='row_group', type='px', value='100%'),
#         row_group_font_weight=OptionsInfo(scss=True, category='row_group', type='value', value='initial'),
#         row_group_text_transform=OptionsInfo(scss=True, category='row_group', type='value', value='inherit'),
#         row_group_padding=OptionsInfo(scss=True, category='row_group', type='px', value='8px'),
#         row_group_padding_horizontal=OptionsInfo(scss=True, category='row_group', type='px', value='5px'),
#         row_group_border_top_style=OptionsInfo(scss=True, category='row_group', type='value', value='solid'),
#         row_group_border_top_width=OptionsInfo(scss=True, category='row_group', type='px', value='2px'),
#         row_group_border_top_color=OptionsInfo(scss=True, category='row_group', type='value', value='#D3D3D3'),
#         row_group_border_right_style=OptionsInfo(scss=True, category='row_group', type='value', value='none'),
#         row_group_border_right_width=OptionsInfo(scss=True, category='row_group', type='px', value='1px'),
#         row_group_border_right_color=OptionsInfo(scss=True, category='row_group', type='value', value='#D3D3D3'),
#         row_group_border_bottom_style=OptionsInfo(scss=True, category='row_group', type='value', value='solid'),
#         row_group_border_bottom_width=OptionsInfo(scss=True, category='row_group', type='px', value='2px'),
#         row_group_border_bottom_color=OptionsInfo(scss=True, category='row_group', type='value', value='#D3D3D3'),
#         row_group_border_left_style=OptionsInfo(scss=True, category='row_group', type='value', value='none'),
#         row_group_border_left_width=OptionsInfo(scss=True, category='row_group', type='px', value='1px'),
#         row_group_border_left_color=OptionsInfo(scss=True, category='row_group', type='value', value='#D3D3D3'),
#         row_group_as_column=OptionsInfo(scss=False, category='row_group', type='boolean', value=False),
#         table_body_hlines_style=OptionsInfo(scss=True, category='table_body', type='value', value='solid'),
#         table_body_hlines_width=OptionsInfo(scss=True, category='table_body', type='px', value='1px'),
#         table_body_hlines_color=OptionsInfo(scss=True, category='table_body', type='value', value='#D3D3D3'),
#         table_body_vlines_style=OptionsInfo(scss=True, category='table_body', type='value', value='solid'),
#         table_body_vlines_width=OptionsInfo(scss=True, category='table_body', type='px', value='1px'),
#         table_body_vlines_color=OptionsInfo(scss=True, category='table_body', type='value', value='#E9E9E9'),
#         table_body_border_top_style=OptionsInfo(scss=True, category='table_body', type='value', value='solid'),
#         table_body_border_top_width=OptionsInfo(scss=True, category='table_body', type='px', value='2px'),
#         table_body_border_top_color=OptionsInfo(scss=True, category='table_body', type='value', value='#D3D3D3'),
#         table_body_border_bottom_style=OptionsInfo(scss=True, category='table_body', type='value', value='solid'),
#         table_body_border_bottom_width=OptionsInfo(scss=True, category='table_body', type='px', value='2px'),
#         table_body_border_bottom_color=OptionsInfo(scss=True, category='table_body', type='value', value='#D3D3D3'),
#         data_row_padding=OptionsInfo(scss=True, category='data_row', type='px', value='8px'),
#         data_row_padding_horizontal=OptionsInfo(scss=True, category='data_row', type='px', value='5px'),
#         stub_background_color=OptionsInfo(scss=True, category='stub', type='value', value=None),
#         stub_font_size=OptionsInfo(scss=True, category='stub', type='px', value='100%'),
#         stub_font_weight=OptionsInfo(scss=True, category='stub', type='value', value='initial'),
#         stub_text_transform=OptionsInfo(scss=True, category='stub', type='value', value='inherit'),
#         stub_border_style=OptionsInfo(scss=True, category='stub', type='value', value='solid'),
#         stub_border_width=OptionsInfo(scss=True, category='stub', type='px', value='2px'),
#         stub_border_color=OptionsInfo(scss=True, category='stub', type='value', value='#D3D3D3'),
#         stub_row_group_background_color=OptionsInfo(scss=True, category='stub', type='value', value=None),
#         stub_row_group_font_size=OptionsInfo(scss=True, category='stub', type='px', value='100%'),
#         stub_row_group_font_weight=OptionsInfo(scss=True, category='stub', type='value', value='initial'),
#         stub_row_group_text_transform=OptionsInfo(scss=True, category='stub', type='value', value='inherit'),
#         stub_row_group_border_style=OptionsInfo(scss=True, category='stub', type='value', value='solid'),
#         stub_row_group_border_width=OptionsInfo(scss=True, category='stub', type='px', value='2px'),
#         stub_row_group_border_color=OptionsInfo(scss=True, category='stub', type='value', value='#D3D3D3'),
#         source_notes_padding=OptionsInfo(scss=True, category='source_notes', type='px', value='4px'),
#         source_notes_padding_horizontal=OptionsInfo(scss=True, category='source_notes', type='px', value='5px'),
#         source_notes_background_color=OptionsInfo(scss=True, category='source_notes', type='value', value=None),
#         source_notes_font_size=OptionsInfo(scss=True, category='source_notes', type='px', value='90%'),
#         source_notes_border_bottom_style=OptionsInfo(scss=True, category='source_notes', type='value', value='none'),
#         source_notes_border_bottom_width=OptionsInfo(scss=True, category='source_notes', type='px', value='2px'),
#         source_notes_border_bottom_color=OptionsInfo(scss=True, category='source_notes', type='value', value='#D3D3D3'),
#         source_notes_border_lr_style=OptionsInfo(scss=True, category='source_notes', type='value', value='none'),
#         source_notes_border_lr_width=OptionsInfo(scss=True, category='source_notes', type='px', value='2px'),
#         source_notes_border_lr_color=OptionsInfo(scss=True, category='source_notes', type='value', value='#D3D3D3'),
#         source_notes_multiline=OptionsInfo(scss=False, category='source_notes', type='boolean', value=True),
#         source_notes_sep=OptionsInfo(scss=False, category='source_notes', type='value', value=' '),
#         row_striping_background_color=OptionsInfo(scss=True, category='row', type='value', value='rgba(128,128,128,0.05)'),
#         row_striping_include_stub=OptionsInfo(scss=False, category='row', type='boolean', value=False),
#         row_striping_include_table_body=OptionsInfo(scss=False, category='row', type='boolean', value=False),
#         container_width=OptionsInfo(scss=False, category='container', type='px', value='auto'),
#         container_height=OptionsInfo(scss=False, category='container', type='px', value='auto'),
#         container_padding_x=OptionsInfo(scss=False, category='container', type='px', value='0px'),
#         container_padding_y=OptionsInfo(scss=False, category='container', type='px', value='10px'),
#         container_overflow_x=OptionsInfo(scss=False, category='container', type='overflow', value='auto'),
#         container_overflow_y=OptionsInfo(scss=False, category='container', type='overflow', value='auto'),
#         quarto_disable_processing=OptionsInfo(scss=False, category='quarto', type='logical', value=True),
#         quarto_use_bootstrap=OptionsInfo(scss=False, category='quarto', type='logical', value=False)
#     ),
#     _has_built=False
# )

# %%
harmonised_validation.get_step_report(i=46, columns_subset=pb.matches(r"ID|WALK"))
# Out:
# GT(
#     _tbl_data=shape: (1, 8)
# ┌───────────┬─────────┬────────────┬────────────┬────────────┬────────────┬────────────┬───────────┐
# │ _row_num_ ┆ ID      ┆ G227_IPAQ_ ┆ G227_IPAQ_ ┆ G227_IPAQ_ ┆ G227_IPAQ_ ┆ G227_IPAQ_ ┆ G227_IPAQ │
# │ ---       ┆ ---     ┆ WALK_W     ┆ WALK_HPD   ┆ WALK_MPD   ┆ WALK_D     ┆ WALK_MINS  ┆ _WALK_MET │
# │ u32       ┆ f64     ┆ ---        ┆ ---        ┆ ---        ┆ ---        ┆ ---        ┆ ---       │
# │           ┆         ┆ f64        ┆ f64        ┆ f64        ┆ f64        ┆ f64        ┆ f64       │
# ╞═══════════╪═════════╪════════════╪════════════╪════════════╪════════════╪════════════╪═══════════╡
# │ 7         ┆ 16550.0 ┆ -1.0       ┆ 1.0        ┆ null       ┆ null       ┆ null       ┆ null      │
# └───────────┴─────────┴────────────┴────────────┴────────────┴────────────┴────────────┴───────────┘,
#     _body=<great_tables._gt_data.Body object at 0x0000017581FCF610>,
#     _boxhead=Boxhead([ColInfo(var='_row_num_', type=<ColInfoTypeEnum.default: 1>, column_label='', column_align='right', column_width='17.8px'), ColInfo(var='ID', type=<ColInfoTypeEnum.default: 1>, column_label=Html(text="<div><div style='white-space: nowrap; text-overflow: ellipsis; overflow: hidden; padding-bottom: 2px; margin-bottom: 2px;'>ID</div><div style='white-space: nowrap; text-overflow: ellipsis; overflow: hidden; padding-top: 2px; margin-top: 2px;'><em>Float64</em></div></div>"), column_align='right', column_width='65px'), ColInfo(var='G227_IPAQ_WALK_W', type=<ColInfoTypeEnum.default: 1>, column_label=Html(text="<div><div style='white-space: nowrap; text-overflow: ellipsis; overflow: hidden; padding-bottom: 2px; margin-bottom: 2px;'>G227_IPAQ_WALK_W</div><div style='white-space: nowrap; text-overflow: ellipsis; overflow: hidden; padding-top: 2px; margin-top: 2px;'><em>Float64</em></div></div>"), column_align='right', column_width='135px'), ColInfo(var='G227_IPAQ_WALK_HPD', type=<ColInfoTypeEnum.default: 1>, column_label=Html(text="<div><div style='white-space: nowrap; text-overflow: ellipsis; overflow: hidden; padding-bottom: 2px; margin-bottom: 2px;'>G227_IPAQ_WALK_HPD</div><div style='white-space: nowrap; text-overflow: ellipsis; overflow: hidden; padding-top: 2px; margin-top: 2px;'><em>Float64</em></div></div>"), column_align='right', column_width='150px'), ColInfo(var='G227_IPAQ_WALK_MPD', type=<ColInfoTypeEnum.default: 1>, column_label=Html(text="<div><div style='white-space: nowrap; text-overflow: ellipsis; overflow: hidden; padding-bottom: 2px; margin-bottom: 2px;'>G227_IPAQ_WALK_MPD</div><div style='white-space: nowrap; text-overflow: ellipsis; overflow: hidden; padding-top: 2px; margin-top: 2px;'><em>Float64</em></div></div>"), column_align='right', column_width='150px'), ColInfo(var='G227_IPAQ_WALK_D', type=<ColInfoTypeEnum.default: 1>, column_label=Html(text="<div><div style='white-space: nowrap; text-overflow: ellipsis; overflow: hidden; padding-bottom: 2px; margin-bottom: 2px;'>G227_IPAQ_WALK_D</div><div style='white-space: nowrap; text-overflow: ellipsis; overflow: hidden; padding-top: 2px; margin-top: 2px;'><em>Float64</em></div></div>"), column_align='right', column_width='135px'), ColInfo(var='G227_IPAQ_WALK_MINS', type=<ColInfoTypeEnum.default: 1>, column_label=Html(text="<div><div style='white-space: nowrap; text-overflow: ellipsis; overflow: hidden; padding-bottom: 2px; margin-bottom: 2px;'>G227_IPAQ_WALK_MINS</div><div style='white-space: nowrap; text-overflow: ellipsis; overflow: hidden; padding-top: 2px; margin-top: 2px;'><em>Float64</em></div></div>"), column_align='right', column_width='158px'), ColInfo(var='G227_IPAQ_WALK_MET', type=<ColInfoTypeEnum.default: 1>, column_label=Html(text="<div><div style='white-space: nowrap; text-overflow: ellipsis; overflow: hidden; padding-bottom: 2px; margin-bottom: 2px;'>G227_IPAQ_WALK_MET</div><div style='white-space: nowrap; text-overflow: ellipsis; overflow: hidden; padding-top: 2px; margin-top: 2px;'><em>Float64</em></div></div>"), column_align='right', column_width='150px')]),
#     _stub=<great_tables._gt_data.Stub object at 0x00000175FE851FD0>,
#     _spanners=Spanners([]),
#     _heading=Heading(
#         title=Md(
#             text="<p>Report for Validation Step 46<div style='font-size: 13.6px; '><div style='padding-top: 7px;'>ASSERTION <span style='border-style: solid; border-width: thin; border-color: lightblue; padding-left: 2px; padding-right: 2px;'><code style='color: #303030; background-color: transparent; position: relative; bottom: 1px;'><code style='color: #303030; font-family: monospace; font-size: smaller;'>G227_IPAQ_WALK_HPD is Null</code></code></span></div><div style='padding-top: 7px;'><strong>1</strong> / <strong>20</strong> TEST UNIT FAILURES IN COLUMN <strong>13</strong> </div><div>EXTRACT OF ALL <strong>1</strong> ROWS (WITH <span style='color: #B22222;'>TEST UNIT FAILURES IN RED</span>):</div></div></p>\n"
#         ),
#         subtitle=None,
#         preheader=None
#     ),
#     _stubhead=None,
#     _source_notes=[],
#     _footnotes=[],
#     _styles=[
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='_row_num_',
#             rownum=0,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='ID',
#             rownum=0,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_W',
#             rownum=0,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_HPD',
#             rownum=0,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_MPD',
#             rownum=0,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_D',
#             rownum=0,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_MINS',
#             rownum=0,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_MET',
#             rownum=0,
#             colnum=None,
#             styles=[CellStyleCss(rule='height: 14px; padding: 4px; white-space: nowrap; text-overflow: ellipsis; overflow: hidden;')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='_row_num_',
#             rownum=0,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='ID',
#             rownum=0,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_W',
#             rownum=0,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_HPD',
#             rownum=0,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_MPD',
#             rownum=0,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_D',
#             rownum=0,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_MINS',
#             rownum=0,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_MET',
#             rownum=0,
#             colnum=None,
#             styles=[CellStyleText(color='black', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocColumnLabels(columns=None),
#             grpname=None,
#             colname='_row_num_',
#             rownum=None,
#             colnum=None,
#             styles=[CellStyleText(color='gray20', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocColumnLabels(columns=None),
#             grpname=None,
#             colname='ID',
#             rownum=None,
#             colnum=None,
#             styles=[CellStyleText(color='gray20', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocColumnLabels(columns=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_W',
#             rownum=None,
#             colnum=None,
#             styles=[CellStyleText(color='gray20', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocColumnLabels(columns=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_HPD',
#             rownum=None,
#             colnum=None,
#             styles=[CellStyleText(color='gray20', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocColumnLabels(columns=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_MPD',
#             rownum=None,
#             colnum=None,
#             styles=[CellStyleText(color='gray20', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocColumnLabels(columns=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_D',
#             rownum=None,
#             colnum=None,
#             styles=[CellStyleText(color='gray20', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocColumnLabels(columns=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_MINS',
#             rownum=None,
#             colnum=None,
#             styles=[CellStyleText(color='gray20', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocColumnLabels(columns=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_MET',
#             rownum=None,
#             colnum=None,
#             styles=[CellStyleText(color='gray20', font='IBM Plex Mono', size='12px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None)]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='_row_num_',
#             rownum=0,
#             colnum=None,
#             styles=[CellStyleBorders(sides=['top', 'bottom'], color='#E9E9E', style='solid', weight='1px')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='ID',
#             rownum=0,
#             colnum=None,
#             styles=[CellStyleBorders(sides=['top', 'bottom'], color='#E9E9E', style='solid', weight='1px')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_W',
#             rownum=0,
#             colnum=None,
#             styles=[CellStyleBorders(sides=['top', 'bottom'], color='#E9E9E', style='solid', weight='1px')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_HPD',
#             rownum=0,
#             colnum=None,
#             styles=[CellStyleBorders(sides=['top', 'bottom'], color='#E9E9E', style='solid', weight='1px')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_MPD',
#             rownum=0,
#             colnum=None,
#             styles=[CellStyleBorders(sides=['top', 'bottom'], color='#E9E9E', style='solid', weight='1px')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_D',
#             rownum=0,
#             colnum=None,
#             styles=[CellStyleBorders(sides=['top', 'bottom'], color='#E9E9E', style='solid', weight='1px')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_MINS',
#             rownum=0,
#             colnum=None,
#             styles=[CellStyleBorders(sides=['top', 'bottom'], color='#E9E9E', style='solid', weight='1px')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns=None, rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_MET',
#             rownum=0,
#             colnum=None,
#             styles=[CellStyleBorders(sides=['top', 'bottom'], color='#E9E9E', style='solid', weight='1px')]
#         ),
#         StyleInfo(
#             locname=LocBody(columns='_row_num_', rows=None, mask=None),
#             grpname=None,
#             colname='_row_num_',
#             rownum=0,
#             colnum=None,
#             styles=[
#                 CellStyleText(color='gray', font='IBM Plex Mono', size='10px', align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None),
#                 CellStyleBorders(sides='right', color='#6699CC80', style='solid', weight='2px')
#             ]
#         ),
#         StyleInfo(
#             locname=LocBody(columns='G227_IPAQ_WALK_HPD', rows=None, mask=None),
#             grpname=None,
#             colname='G227_IPAQ_WALK_HPD',
#             rownum=0,
#             colnum=None,
#             styles=[
#                 CellStyleText(color='#B22222', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None),
#                 CellStyleFill(color='#FFC1C159'),
#                 CellStyleBorders(sides=['left', 'right'], color='black', style='solid', weight='2px')
#             ]
#         ),
#         StyleInfo(
#             locname=LocColumnLabels(columns='G227_IPAQ_WALK_HPD'),
#             grpname=None,
#             colname='G227_IPAQ_WALK_HPD',
#             rownum=None,
#             colnum=None,
#             styles=[CellStyleBorders(sides=['left', 'right'], color='black', style='solid', weight='2px')]
#         )
#     ],
#     _locale=<great_tables._gt_data.Locale object at 0x0000017581FCE3A0>,
#     _formats=[<great_tables._gt_data.FormatInfo object at 0x00000175FE853FB0>],
#     _substitutions=[],
#     _options=Options(
#         table_id=OptionsInfo(scss=True, category='table', type='value', value='pb_preview_tbl'),
#         table_caption=OptionsInfo(scss=False, category='table', type='value', value=None),
#         table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'),
#         table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'),
#         table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'),
#         table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'),
#         table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'),
#         table_additional_css=OptionsInfo(
#             scss=False,
#             category='table',
#             type='values',
#             value=[
#                 "@import url('https://fonts.googleapis.com/css2?family=IBM+Plex+Sans&display=swap');",
#                 "@import url('https://fonts.googleapis.com/css2?family=IBM+Plex+Mono&display=swap');",
#                 "@import url('https://fonts.googleapis.com/css2?family=IBM+Plex+Mono&display=swap');",
#                 "@import url('https://fonts.googleapis.com/css2?family=IBM+Plex+Mono&display=swap');"
#             ]
#         ),
#         table_font_names=OptionsInfo(
#             scss=False,
#             category='table',
#             type='values',
#             value=['IBM Plex Sans', '-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']
#         ),
#         table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'),
#         table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'),
#         table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'),
#         table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'),
#         table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'),
#         table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True),
#         table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'),
#         table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'),
#         table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'),
#         table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'),
#         table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'),
#         table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'),
#         table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True),
#         table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'),
#         table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'),
#         table_border_bottom_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'),
#         table_border_left_style=OptionsInfo(scss=True, category='table', type='value', value='none'),
#         table_border_left_width=OptionsInfo(scss=True, category='table', type='px', value='2px'),
#         table_border_left_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'),
#         heading_background_color=OptionsInfo(scss=True, category='heading', type='value', value=None),
#         heading_align=OptionsInfo(scss=True, category='heading', type='value', value='left'),
#         heading_title_font_size=OptionsInfo(scss=True, category='heading', type='px', value='125%'),
#         heading_title_font_weight=OptionsInfo(scss=True, category='heading', type='value', value='initial'),
#         heading_subtitle_font_size=OptionsInfo(scss=True, category='heading', type='px', value='85%'),
#         heading_subtitle_font_weight=OptionsInfo(scss=True, category='heading', type='value', value='initial'),
#         heading_padding=OptionsInfo(scss=True, category='heading', type='px', value='4px'),
#         heading_padding_horizontal=OptionsInfo(scss=True, category='heading', type='px', value='5px'),
#         heading_border_bottom_style=OptionsInfo(scss=True, category='heading', type='value', value='solid'),
#         heading_border_bottom_width=OptionsInfo(scss=True, category='heading', type='px', value='2px'),
#         heading_border_bottom_color=OptionsInfo(scss=True, category='heading', type='value', value='#D3D3D3'),
#         heading_border_lr_style=OptionsInfo(scss=True, category='heading', type='value', value='none'),
#         heading_border_lr_width=OptionsInfo(scss=True, category='heading', type='px', value='1px'),
#         heading_border_lr_color=OptionsInfo(scss=True, category='heading', type='value', value='#D3D3D3'),
#         column_labels_background_color=OptionsInfo(scss=True, category='column_labels', type='value', value=None),
#         column_labels_font_size=OptionsInfo(scss=True, category='column_labels', type='px', value='100%'),
#         column_labels_font_weight=OptionsInfo(scss=True, category='column_labels', type='value', value='normal'),
#         column_labels_text_transform=OptionsInfo(scss=True, category='column_labels', type='value', value='inherit'),
#         column_labels_padding=OptionsInfo(scss=True, category='column_labels', type='px', value='5px'),
#         column_labels_padding_horizontal=OptionsInfo(scss=True, category='column_labels', type='px', value='5px'),
#         column_labels_vlines_style=OptionsInfo(scss=True, category='table_body', type='value', value='solid'),
#         column_labels_vlines_width=OptionsInfo(scss=True, category='table_body', type='px', value='1px'),
#         column_labels_vlines_color=OptionsInfo(scss=True, category='table_body', type='value', value='#F2F2F2'),
#         column_labels_border_top_style=OptionsInfo(scss=True, category='column_labels', type='value', value='solid'),
#         column_labels_border_top_width=OptionsInfo(scss=True, category='column_labels', type='px', value='2px'),
#         column_labels_border_top_color=OptionsInfo(scss=True, category='column_labels', type='value', value='#D3D3D3'),
#         column_labels_border_bottom_style=OptionsInfo(scss=True, category='column_labels', type='value', value='solid'),
#         column_labels_border_bottom_width=OptionsInfo(scss=True, category='column_labels', type='px', value='2px'),
#         column_labels_border_bottom_color=OptionsInfo(scss=True, category='column_labels', type='value', value='#D3D3D3'),
#         column_labels_border_lr_style=OptionsInfo(scss=True, category='column_labels', type='value', value='none'),
#         column_labels_border_lr_width=OptionsInfo(scss=True, category='column_labels', type='px', value='1px'),
#         column_labels_border_lr_color=OptionsInfo(scss=True, category='column_labels', type='value', value='#D3D3D3'),
#         column_labels_hidden=OptionsInfo(scss=False, category='column_labels', type='boolean', value=False),
#         row_group_background_color=OptionsInfo(scss=True, category='row_group', type='value', value=None),
#         row_group_font_size=OptionsInfo(scss=True, category='row_group', type='px', value='100%'),
#         row_group_font_weight=OptionsInfo(scss=True, category='row_group', type='value', value='initial'),
#         row_group_text_transform=OptionsInfo(scss=True, category='row_group', type='value', value='inherit'),
#         row_group_padding=OptionsInfo(scss=True, category='row_group', type='px', value='8px'),
#         row_group_padding_horizontal=OptionsInfo(scss=True, category='row_group', type='px', value='5px'),
#         row_group_border_top_style=OptionsInfo(scss=True, category='row_group', type='value', value='solid'),
#         row_group_border_top_width=OptionsInfo(scss=True, category='row_group', type='px', value='2px'),
#         row_group_border_top_color=OptionsInfo(scss=True, category='row_group', type='value', value='#D3D3D3'),
#         row_group_border_right_style=OptionsInfo(scss=True, category='row_group', type='value', value='none'),
#         row_group_border_right_width=OptionsInfo(scss=True, category='row_group', type='px', value='1px'),
#         row_group_border_right_color=OptionsInfo(scss=True, category='row_group', type='value', value='#D3D3D3'),
#         row_group_border_bottom_style=OptionsInfo(scss=True, category='row_group', type='value', value='solid'),
#         row_group_border_bottom_width=OptionsInfo(scss=True, category='row_group', type='px', value='2px'),
#         row_group_border_bottom_color=OptionsInfo(scss=True, category='row_group', type='value', value='#D3D3D3'),
#         row_group_border_left_style=OptionsInfo(scss=True, category='row_group', type='value', value='none'),
#         row_group_border_left_width=OptionsInfo(scss=True, category='row_group', type='px', value='1px'),
#         row_group_border_left_color=OptionsInfo(scss=True, category='row_group', type='value', value='#D3D3D3'),
#         row_group_as_column=OptionsInfo(scss=False, category='row_group', type='boolean', value=False),
#         table_body_hlines_style=OptionsInfo(scss=True, category='table_body', type='value', value='solid'),
#         table_body_hlines_width=OptionsInfo(scss=True, category='table_body', type='px', value='1px'),
#         table_body_hlines_color=OptionsInfo(scss=True, category='table_body', type='value', value='#D3D3D3'),
#         table_body_vlines_style=OptionsInfo(scss=True, category='table_body', type='value', value='solid'),
#         table_body_vlines_width=OptionsInfo(scss=True, category='table_body', type='px', value='1px'),
#         table_body_vlines_color=OptionsInfo(scss=True, category='table_body', type='value', value='#E9E9E9'),
#         table_body_border_top_style=OptionsInfo(scss=True, category='table_body', type='value', value='solid'),
#         table_body_border_top_width=OptionsInfo(scss=True, category='table_body', type='px', value='2px'),
#         table_body_border_top_color=OptionsInfo(scss=True, category='table_body', type='value', value='#D3D3D3'),
#         table_body_border_bottom_style=OptionsInfo(scss=True, category='table_body', type='value', value='solid'),
#         table_body_border_bottom_width=OptionsInfo(scss=True, category='table_body', type='px', value='2px'),
#         table_body_border_bottom_color=OptionsInfo(scss=True, category='table_body', type='value', value='#D3D3D3'),
#         data_row_padding=OptionsInfo(scss=True, category='data_row', type='px', value='8px'),
#         data_row_padding_horizontal=OptionsInfo(scss=True, category='data_row', type='px', value='5px'),
#         stub_background_color=OptionsInfo(scss=True, category='stub', type='value', value=None),
#         stub_font_size=OptionsInfo(scss=True, category='stub', type='px', value='100%'),
#         stub_font_weight=OptionsInfo(scss=True, category='stub', type='value', value='initial'),
#         stub_text_transform=OptionsInfo(scss=True, category='stub', type='value', value='inherit'),
#         stub_border_style=OptionsInfo(scss=True, category='stub', type='value', value='solid'),
#         stub_border_width=OptionsInfo(scss=True, category='stub', type='px', value='2px'),
#         stub_border_color=OptionsInfo(scss=True, category='stub', type='value', value='#D3D3D3'),
#         stub_row_group_background_color=OptionsInfo(scss=True, category='stub', type='value', value=None),
#         stub_row_group_font_size=OptionsInfo(scss=True, category='stub', type='px', value='100%'),
#         stub_row_group_font_weight=OptionsInfo(scss=True, category='stub', type='value', value='initial'),
#         stub_row_group_text_transform=OptionsInfo(scss=True, category='stub', type='value', value='inherit'),
#         stub_row_group_border_style=OptionsInfo(scss=True, category='stub', type='value', value='solid'),
#         stub_row_group_border_width=OptionsInfo(scss=True, category='stub', type='px', value='2px'),
#         stub_row_group_border_color=OptionsInfo(scss=True, category='stub', type='value', value='#D3D3D3'),
#         source_notes_padding=OptionsInfo(scss=True, category='source_notes', type='px', value='4px'),
#         source_notes_padding_horizontal=OptionsInfo(scss=True, category='source_notes', type='px', value='5px'),
#         source_notes_background_color=OptionsInfo(scss=True, category='source_notes', type='value', value=None),
#         source_notes_font_size=OptionsInfo(scss=True, category='source_notes', type='px', value='90%'),
#         source_notes_border_bottom_style=OptionsInfo(scss=True, category='source_notes', type='value', value='none'),
#         source_notes_border_bottom_width=OptionsInfo(scss=True, category='source_notes', type='px', value='2px'),
#         source_notes_border_bottom_color=OptionsInfo(scss=True, category='source_notes', type='value', value='#D3D3D3'),
#         source_notes_border_lr_style=OptionsInfo(scss=True, category='source_notes', type='value', value='none'),
#         source_notes_border_lr_width=OptionsInfo(scss=True, category='source_notes', type='px', value='2px'),
#         source_notes_border_lr_color=OptionsInfo(scss=True, category='source_notes', type='value', value='#D3D3D3'),
#         source_notes_multiline=OptionsInfo(scss=False, category='source_notes', type='boolean', value=True),
#         source_notes_sep=OptionsInfo(scss=False, category='source_notes', type='value', value=' '),
#         row_striping_background_color=OptionsInfo(scss=True, category='row', type='value', value='rgba(128,128,128,0.05)'),
#         row_striping_include_stub=OptionsInfo(scss=False, category='row', type='boolean', value=False),
#         row_striping_include_table_body=OptionsInfo(scss=False, category='row', type='boolean', value=False),
#         container_width=OptionsInfo(scss=False, category='container', type='px', value='auto'),
#         container_height=OptionsInfo(scss=False, category='container', type='px', value='auto'),
#         container_padding_x=OptionsInfo(scss=False, category='container', type='px', value='0px'),
#         container_padding_y=OptionsInfo(scss=False, category='container', type='px', value='10px'),
#         container_overflow_x=OptionsInfo(scss=False, category='container', type='overflow', value='auto'),
#         container_overflow_y=OptionsInfo(scss=False, category='container', type='overflow', value='auto'),
#         quarto_disable_processing=OptionsInfo(scss=False, category='quarto', type='logical', value=True),
#         quarto_use_bootstrap=OptionsInfo(scss=False, category='quarto', type='logical', value=False)
#     ),
#     _has_built=False
# )
